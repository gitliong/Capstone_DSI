# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
pd.read_csv('multipleChoiceResponses.csv', encoding="ISO-8859-1", low_memory=False)
# Out:
#                                             GenderSelect  \
# 0      Non-binary, genderqueer, or gender non-conforming
# 1                                                 Female
# 2                                                   Male
# 3                                                   Male
# 4                                                   Male
# 5                                                   Male
# 6                                                   Male
# 7                                                 Female
# 8                                                 Female
# 9                                                   Male
# 10                                                Female
# 11                                                  Male
# 12                                                  Male
# 13                                                  Male
# 14                                                  Male
# ...

# %%
df_mcr = pd.read_csv('multipleChoiceResponses.csv', encoding="ISO-8859-1", low_memory=False)

# %%
df_mcr['Country'].value_counts()
# Out:
# United States                  4197
# India                          2704
# Other                          1023
# Russia                          578
# United Kingdom                  535
# People 's Republic of China     471
# Brazil                          465
# Germany                         460
# France                          442
# Canada                          440
# Australia                       421
# Spain                           320
# Japan                           277
# Taiwan                          254
# Italy                           238
# Netherlands                     205
# Ukraine                         196
# South Korea                     194
# Poland                          184
# Singapore                       184
# Pakistan                        161
# Turkey                          144
# Indonesia                       131
# Switzerland                     129
# South Africa                    127
# Mexico                          126
# ...

# %%
df_mcr[df_mcr['Country'] == 'United States']
# Out:
#       GenderSelect        Country   Age  \
# 1           Female  United States  30.0
# 3             Male  United States  56.0
# 6             Male  United States  35.0
# 15            Male  United States  58.0
# 18            Male  United States  26.0
# 20            Male  United States  49.0
# 21            Male  United States  25.0
# 22            Male  United States  33.0
# 24            Male  United States   NaN
# 34            Male  United States  35.0
# 39            Male  United States  43.0
# 40            Male  United States  33.0
# 41            Male  United States  30.0
# 43          Female  United States  22.0
# 48            Male  United States  27.0
# 55            Male  United States  63.0
# 59            Male  United States  32.0
# 75            Male  United States  40.0
# 80            Male  United States  25.0
# 84            Male  United States  47.0
# 86          Female  United States  31.0
# 87          Female  United States   NaN
# ...

# %%
US_Data_Scientist = df_mcr[df_mcr['Country'] == 'United States']

# %%
US_Data_Scientist
# Out:
#       GenderSelect        Country   Age  \
# 1           Female  United States  30.0
# 3             Male  United States  56.0
# 6             Male  United States  35.0
# 15            Male  United States  58.0
# 18            Male  United States  26.0
# 20            Male  United States  49.0
# 21            Male  United States  25.0
# 22            Male  United States  33.0
# 24            Male  United States   NaN
# 34            Male  United States  35.0
# 39            Male  United States  43.0
# 40            Male  United States  33.0
# 41            Male  United States  30.0
# 43          Female  United States  22.0
# 48            Male  United States  27.0
# 55            Male  United States  63.0
# 59            Male  United States  32.0
# 75            Male  United States  40.0
# 80            Male  United States  25.0
# 84            Male  United States  47.0
# 86          Female  United States  31.0
# 87          Female  United States   NaN
# ...

# %%
# pd.DataFrame(some_thing).to_csv('filepath.csv', index=False)
# US_Data_Scientist.to_csv('filepath.csv', index=False)

# %%
# pd.Series(list).value_counts()

# %%
# pd.DataFrame(some_thing).to_csv('filepath.csv', index=False)
US_Data_Scientist.to_csv('USData_Scientist.csv', index=False)

# %%
pd.read_csv('USData_Scientist.csv')
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (124) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#      GenderSelect        Country   Age  \
# 0          Female  United States  30.0
# 1            Male  United States  56.0
# 2            Male  United States  35.0
# 3            Male  United States  58.0
# 4            Male  United States  26.0
# 5            Male  United States  49.0
# 6            Male  United States  25.0
# 7            Male  United States  33.0
# 8            Male  United States   NaN
# 9            Male  United States  35.0
# 10           Male  United States  43.0
# 11           Male  United States  33.0
# 12           Male  United States  30.0
# 13         Female  United States  22.0
# 14           Male  United States  27.0
# 15           Male  United States  63.0
# 16           Male  United States  32.0
# ...

# %%
df_US = pd.read_csv('USData_Scientist.csv')
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (124) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_US.shape
# Out:
# (5702, 228)

# %%
df_US.isnull().sum()
# Out:
# GenderSelect                                 10
# Country                                       8
# Age                                         102
# EmploymentStatus                             10
# StudentStatus                              5476
# LearningDataScience                        5475
# CodeWriter                                  740
# CareerSwitcher                             5048
# CurrentJobTitleSelect                      1080
# TitleFit                                   1151
# CurrentEmployerType                        1122
# MLToolNextYearSelect                       1417
# MLMethodNextYearSelect                     1448
# LanguageRecommendationSelect               1408
# PublicDatasetsSelect                       1470
# LearningPlatformSelect                     1322
# LearningPlatformUsefulnessArxiv            3611
# LearningPlatformUsefulnessBlogs            2929
# LearningPlatformUsefulnessCollege          4738
# LearningPlatformUsefulnessCompany          3865
# ...

# %%
df_US[df_US['CareerSwitcher'] == 'No']
# Out:
#      GenderSelect        Country   Age  \
# 23           Male  United States  44.0
# 32           Male  United States  50.0
# 56           Male  United States  53.0
# 62           Male  United States  59.0
# 74         Female  United States  52.0
# 95           Male  United States  28.0
# 100          Male  United States  34.0
# 120        Female  United States  18.0
# 151          Male  United States  23.0
# 154          Male  United States  23.0
# 157          Male  United States  22.0
# 211        Female  United States  42.0
# 258          Male  United States  35.0
# 260        Female  United States  27.0
# 273        Female  United States  24.0
# 275          Male  United States  19.0
# 276          Male  United States  59.0
# 295          Male  United States  68.0
# 320        Female  United States  35.0
# 326          Male  United States  30.0
# 345          Male  United States  47.0
# 378          Male  United States  48.0
# 380        Female  United States  47.0
# ...

# %%
df_US[df_US['CareerSwitcher'] == 'Yes'].count()
# Out:
# GenderSelect                               406
# Country                                    407
# Age                                        400
# EmploymentStatus                           407
# StudentStatus                                0
# LearningDataScience                          0
# CodeWriter                                 407
# CareerSwitcher                             407
# CurrentJobTitleSelect                      385
# TitleFit                                   376
# CurrentEmployerType                        381
# MLToolNextYearSelect                       349
# MLMethodNextYearSelect                     337
# LanguageRecommendationSelect               338
# PublicDatasetsSelect                       336
# LearningPlatformSelect                     343
# LearningPlatformUsefulnessArxiv             34
# LearningPlatformUsefulnessBlogs            127
# LearningPlatformUsefulnessCollege          101
# LearningPlatformUsefulnessCompany           16
# ...

# %%
df_US[df_US['CareerSwitcher'] == 'Yes']['LearningCategorySelftTaught']
# Out:
# 5        20.0
# 33       50.0
# 38      100.0
# 39       45.0
# 40       30.0
# 48       20.0
# 55       30.0
# 82       40.0
# 87       95.0
# 91       50.0
# 92       50.0
# 96        0.0
# 98       10.0
# 101      10.0
# 106       0.0
# 110      33.0
# 118      90.0
# 119      30.0
# 129      15.0
# 134      50.0
# 168      30.0
# 183      15.0
# 188      10.0
# 189      60.0
# 199       0.0
# 202       0.0
# 209      50.0
# 216       0.0
# 239      20.0
# 248      40.0
#         ...
# 5377     50.0
# 5399    100.0
# 5420     50.0
# 5433      0.0
# 5437     10.0
# 5462     20.0
# 5470      0.0
# 5474     20.0
# 5483     40.0
# 5494      NaN
# 5507     40.0
# 5520      NaN
# 5528     85.0
# 5534      NaN
# 5551     20.0
# 5571     50.0
# 5578      NaN
# 5579     20.0
# 5580     30.0
# 5590      NaN
# 5596      NaN
# 5616      NaN
# 5631      NaN
# 5641      0.0
# 5656      NaN
# 5667      NaN
# 5669      NaN
# 5676      NaN
# 5682     25.0
# 5698      0.0
# ...

# %%
careerswitcher = df_US[df_US['CareerSwitcher'] == 'Yes']

# %%
careerswitcher.sum()
# Out:
# LearningCategorySelftTaught      11317.0
# LearningCategoryOnlineCourses    14185.0
# LearningCategoryWork              1867.0
# LearningCategoryUniversity        7040.0
# LearningCategoryKaggle            1611.0
# LearningCategoryOther              680.0
# TimeGatheringData                    0.0
# TimeModelBuilding                    0.0
# TimeProduction                       0.0
# TimeVisualizing                      0.0
# TimeFindingInsights                  0.0
# TimeOtherSelect                      0.0
# dtype: float64

# %%
 careerswitcher.to_csv('careerswitcher.csv', index=False)

# %%
df_US[df_US['CareerSwitcher'] == 'Yes'].count()
# Out:
# GenderSelect                               406
# Country                                    407
# Age                                        400
# EmploymentStatus                           407
# StudentStatus                                0
# LearningDataScience                          0
# CodeWriter                                 407
# CareerSwitcher                             407
# CurrentJobTitleSelect                      385
# TitleFit                                   376
# CurrentEmployerType                        381
# MLToolNextYearSelect                       349
# MLMethodNextYearSelect                     337
# LanguageRecommendationSelect               338
# PublicDatasetsSelect                       336
# LearningPlatformSelect                     343
# LearningPlatformUsefulnessArxiv             34
# LearningPlatformUsefulnessBlogs            127
# LearningPlatformUsefulnessCollege          101
# LearningPlatformUsefulnessCompany           16
# ...

# %%
careerswitcher
# Out:
#      GenderSelect        Country   Age  \
# 5            Male  United States  49.0
# 33         Female  United States  20.0
# 38           Male  United States  31.0
# 39           Male  United States  35.0
# 40           Male  United States  20.0
# 48         Female  United States  21.0
# 55           Male  United States  19.0
# 82           Male  United States  27.0
# 87           Male  United States  38.0
# 91           Male  United States  30.0
# 92           Male  United States  24.0
# 96         Female  United States  29.0
# 98         Female  United States  18.0
# 101          Male  United States  41.0
# 106          Male  United States  53.0
# 110          Male  United States  23.0
# 118          Male  United States  42.0
# 119          Male  United States  24.0
# 129          Male  United States  36.0
# 134          Male  United States  23.0
# 168          Male  United States  42.0
# 183          Male  United States  19.0
# 188          Male  United States  25.0
# ...

# %%
#Next Steps
#Look at specific career switcher data
