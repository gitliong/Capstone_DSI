# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('careerswitcher.csv')

# %%
df.shape
# Out:
# (407, 66)

# %%
df = df.loc[:, df.isnull().mean() < .5]

# %%
df.isnull().sum().count
# Out:
# <bound method Series.count of Unnamed: 0                             0
# Unnamed: 0.1                           0
# GenderSelect                           1
# Country                                0
# Age                                    7
# EmploymentStatus                       0
# CodeWriter                             0
# CareerSwitcher                         0
# CurrentJobTitleSelect                 22
# TitleFit                              31
# CurrentEmployerType                   26
# MLToolNextYearSelect                  58
# MLMethodNextYearSelect                70
# LanguageRecommendationSelect          69
# PublicDatasetsSelect                  71
# LearningPlatformSelect                64
# LearningPlatformUsefulnessCourses    203
# BlogsPodcastsNewslettersSelect       179
# LearningDataScienceTime               74
# JobSkillImportanceBigData            110
# JobSkillImportanceDegree             104
# JobSkillImportanceStats               98
# ...

# %%
df.shape
# Out:
# (407, 66)

# %%
df
# Out:
#      Unnamed: 0  Unnamed: 0.1 GenderSelect        Country   Age  \
# 0             0             0         Male  United States  49.0
# 1             1             1       Female  United States  20.0
# 2             2             2         Male  United States  31.0
# 3             3             3         Male  United States  35.0
# 4             4             4         Male  United States  20.0
# 5             5             5       Female  United States  21.0
# 6             6             6         Male  United States  19.0
# 7             7             7         Male  United States  27.0
# 8             8             8         Male  United States  38.0
# 9             9             9         Male  United States  30.0
# 10           10            10         Male  United States  24.0
# 11           11            11       Female  United States  29.0
# 12           12            12       Female  United States  18.0
# 13           13            13         Male  United States  41.0
# ...

# %%
df.to_csv('careerswitcher2.csv')

# %%
pd.read_csv('careerswitcher2.csv')
# Out:
#      Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1 GenderSelect        Country  \
# 0             0             0               0         Male  United States
# 1             1             1               1       Female  United States
# 2             2             2               2         Male  United States
# 3             3             3               3         Male  United States
# 4             4             4               4         Male  United States
# 5             5             5               5       Female  United States
# 6             6             6               6         Male  United States
# 7             7             7               7         Male  United States
# 8             8             8               8         Male  United States
# 9             9             9               9         Male  United States
# 10           10            10              10         Male  United States
# 11           11            11              11       Female  United States
# ...

# %%
df.shape
# Out:
# (407, 66)
