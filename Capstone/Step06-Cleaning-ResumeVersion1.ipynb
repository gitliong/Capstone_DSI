# %% [markdown]
# ## Step06 - Cleaning Resume Version 1 ##
#
# In this section we will upload Resume Version 1 (which has been pre-processed to be in a CSV format).
#
# Note the use of the encoding function.

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction import stop_words

cvec = CountVectorizer(stop_words = stop_words.ENGLISH_STOP_WORDS)

# %%
pd.read_csv('Resumes/GlennResumeCSV.csv', encoding="ISO-8859-1", low_memory=False)
# Out:
#                            Glenn E. Itliong, MBA, PMP
# 0                                 Phone: 650-207-0395
# 1                       Email:glenn.itliong@gmail.com
# 2                         Reach me professionally at:
# 3   http://www.linkedin.com/pub/glenn-itliong-mba-...
# 4                                        Tweet Me At:
# 5                                            @pmp4rpo
# 6                    Chronological Career Progression
# 7                              Data Scientist Student
# 8    General Assembly _Data Science Immersive Program
# 9                                                2018
# 10  General Assembly provides courses in mobile an...
# 11  * 600 Hours of immersive data science training...
# 12   o Course conducted almost exclusively in Python.
# 13                o Extensive use of Python libraries
# 14                                       * Matplotlib
# 15                                     * Scikit-Learn
# 16                                            * Numpy
# 17                                           * Pandas
# 18                                            * PyMC3
# 19  o Strong emphasis on machine learning througho...
# 20  o Worked on multiple lab projects whose emphas...
# 21                   * EDA (Exploratory Data Analysis
# 22                  * Data Analysis and Visualization
# 23         * Modeling and measuring model performance
# 24                 * Tree Based Classification Models
# 25             * Supervised and Unsupervised Learning
# 26                      * Natural Language Processing
# 27  o Capstone Project: ñMaximizing resume match p...
# 28                   Senior Manager - Implementation
# 29                           Allegis Global Solutions
# ..                                                ...
# 47  * Lead a recruitment team supporting multiple ...
# 48  * Analyzed data provided by analytics team to ...
# 49  * Presented proposals to ownership on strategi...
# 50  * Developed metrics and reports for global rec...
# 51                 Futurestep _ A Korn /Ferry Company
# 52                                 Solution Architect
# 53                                          2003-2012
# 54                    Client: Cummins Diesel Engines
# 55                      Client: Fosters Wine Estates
# 56                                  Client: Wal-Mart
# 57  Project:  Client required a global ATS platfor...
# 58  * Global implementation experience from planni...
# 59  * Lead the identification of stakeholders for ...
# 60  * Lead business requirements meeting to unders...
# 61  * Re-engineer and transform clients recruiting...
# 62  * Assisted in the configuration Taleo recruiti...
# 63  * Created test scripts and scenarios. Led UAT ...
# 64  * Defined reports based on client requirements...
# 65  * Developed and delivered Taleo training mater...
# 66                       Education and Certifications
# 67                                   General Assembly
# 68                     Data Science Immersive Program
# 69                   Saint MaryÍs College, California
# 70                         Executive Trans Global MBA
# 71            Saint JosephÍs University, Pennsylvania
# 72       BA International Relations; Minor Philosophy
# 73                       Project Management Institute
# 74              PMP _ Project Management Professional
# 75                         Glenn E. Itliong, MBA, PMP
# 76                                               2018
#
# [77 rows x 1 columns]

# %%
gresume_df = pd.read_csv('Resumes/GlennResumeCSV.csv', encoding="ISO-8859-1", low_memory=False)

# %%
gresume_df.shape
# Out:
# (77, 1)

# %%
#Change Column Name
gresume_df.rename(columns={'Glenn E. Itliong, MBA, PMP': 'Text'}, inplace=True)

# %%
gresume_df
# Out:
#                                                  Text
# 0                                 Phone: 650-207-0395
# 1                       Email:glenn.itliong@gmail.com
# 2                         Reach me professionally at:
# 3   http://www.linkedin.com/pub/glenn-itliong-mba-...
# 4                                        Tweet Me At:
# 5                                            @pmp4rpo
# 6                    Chronological Career Progression
# 7                              Data Scientist Student
# 8    General Assembly _Data Science Immersive Program
# 9                                                2018
# 10  General Assembly provides courses in mobile an...
# 11  * 600 Hours of immersive data science training...
# 12   o Course conducted almost exclusively in Python.
# 13                o Extensive use of Python libraries
# 14                                       * Matplotlib
# 15                                     * Scikit-Learn
# 16                                            * Numpy
# 17                                           * Pandas
# 18                                            * PyMC3
# 19  o Strong emphasis on machine learning througho...
# 20  o Worked on multiple lab projects whose emphas...
# 21                   * EDA (Exploratory Data Analysis
# 22                  * Data Analysis and Visualization
# 23         * Modeling and measuring model performance
# 24                 * Tree Based Classification Models
# 25             * Supervised and Unsupervised Learning
# 26                      * Natural Language Processing
# 27  o Capstone Project: ñMaximizing resume match p...
# 28                   Senior Manager - Implementation
# 29                           Allegis Global Solutions
# ..                                                ...
# 47  * Lead a recruitment team supporting multiple ...
# 48  * Analyzed data provided by analytics team to ...
# 49  * Presented proposals to ownership on strategi...
# 50  * Developed metrics and reports for global rec...
# 51                 Futurestep _ A Korn /Ferry Company
# 52                                 Solution Architect
# 53                                          2003-2012
# 54                    Client: Cummins Diesel Engines
# 55                      Client: Fosters Wine Estates
# 56                                  Client: Wal-Mart
# 57  Project:  Client required a global ATS platfor...
# 58  * Global implementation experience from planni...
# 59  * Lead the identification of stakeholders for ...
# 60  * Lead business requirements meeting to unders...
# 61  * Re-engineer and transform clients recruiting...
# 62  * Assisted in the configuration Taleo recruiti...
# 63  * Created test scripts and scenarios. Led UAT ...
# 64  * Defined reports based on client requirements...
# 65  * Developed and delivered Taleo training mater...
# 66                       Education and Certifications
# 67                                   General Assembly
# 68                     Data Science Immersive Program
# 69                   Saint MaryÍs College, California
# 70                         Executive Trans Global MBA
# 71            Saint JosephÍs University, Pennsylvania
# 72       BA International Relations; Minor Philosophy
# 73                       Project Management Institute
# 74              PMP _ Project Management Professional
# 75                         Glenn E. Itliong, MBA, PMP
# 76                                               2018
#
# [77 rows x 1 columns]

# %%
gresume_df['Text'][11]
# Out:
# '* 600 Hours of immersive data science training. (5 Days / 12 Weeks)'

# %%
gresume_df['Text'][13]
# Out:
# 'o Extensive use of Python libraries'

# %%
gresume_df['Text'].map(lambda x: x.replace('*', ''))#.replace('o', ''))
# Out:
# 0                                   Phone: 650-207-0395
# 1                         Email:glenn.itliong@gmail.com
# 2                           Reach me professionally at:
# 3     http://www.linkedin.com/pub/glenn-itliong-mba-...
# 4                                          Tweet Me At:
# 5                                              @pmp4rpo
# 6                      Chronological Career Progression
# 7                                Data Scientist Student
# 8      General Assembly _Data Science Immersive Program
# 9                                                  2018
# 10    General Assembly provides courses in mobile an...
# 11     600 Hours of immersive data science training....
# 12     o Course conducted almost exclusively in Python.
# 13                  o Extensive use of Python libraries
# 14                                           Matplotlib
# 15                                         Scikit-Learn
# 16                                                Numpy
# 17                                               Pandas
# 18                                                PyMC3
# 19    o Strong emphasis on machine learning througho...
# 20    o Worked on multiple lab projects whose emphas...
# 21                       EDA (Exploratory Data Analysis
# 22                      Data Analysis and Visualization
# 23             Modeling and measuring model performance
# 24                     Tree Based Classification Models
# 25                 Supervised and Unsupervised Learning
# 26                          Natural Language Processing
# 27    o Capstone Project: ñMaximizing resume match p...
# 28                     Senior Manager - Implementation
# 29                             Allegis Global Solutions
#                             ...
# 47     Lead a recruitment team supporting multiple c...
# 48     Analyzed data provided by analytics team to i...
# 49     Presented proposals to ownership on strategic...
# 50     Developed metrics and reports for global recr...
# 51                   Futurestep _ A Korn /Ferry Company
# 52                                   Solution Architect
# 53                                            2003-2012
# 54                      Client: Cummins Diesel Engines
# 55                        Client: Fosters Wine Estates
# 56                                    Client: Wal-Mart
# 57    Project:  Client required a global ATS platfor...
# 58     Global implementation experience from plannin...
# 59     Lead the identification of stakeholders for t...
# 60     Lead business requirements meeting to underst...
# 61     Re-engineer and transform clients recruiting ...
# 62     Assisted in the configuration Taleo recruitin...
# 63     Created test scripts and scenarios. Led UAT (...
# 64     Defined reports based on client requirements ...
# 65     Developed and delivered Taleo training materi...
# 66                         Education and Certifications
# 67                                     General Assembly
# 68                       Data Science Immersive Program
# 69                     Saint MaryÍs College, California
# 70                           Executive Trans Global MBA
# 71              Saint JosephÍs University, Pennsylvania
# 72         BA International Relations; Minor Philosophy
# 73                         Project Management Institute
# 74                PMP _ Project Management Professional
# 75                           Glenn E. Itliong, MBA, PMP
# 76                                                 2018
# Name: Text, Length: 77, dtype: object

# %% [markdown]
# **Using the lambda function to clean up the resume data**

# %%
gresume_df = gresume_df['Text'].map(lambda x: x.replace('*', ''))

# %%
gresume_df.map(lambda x: x.replace('Õ', ''))
# Out:
# 0                                   Phone: 650-207-0395
# 1                         Email:glenn.itliong@gmail.com
# 2                           Reach me professionally at:
# 3     http://www.linkedin.com/pub/glenn-itliong-mba-...
# 4                                          Tweet Me At:
# 5                                              @pmp4rpo
# 6                      Chronological Career Progression
# 7                                Data Scientist Student
# 8      General Assembly _Data Science Immersive Program
# 9                                                  2018
# 10    General Assembly provides courses in mobile an...
# 11     600 Hours of immersive data science training....
# 12     o Course conducted almost exclusively in Python.
# 13                  o Extensive use of Python libraries
# 14                                           Matplotlib
# 15                                         Scikit-Learn
# 16                                                Numpy
# 17                                               Pandas
# 18                                                PyMC3
# 19    o Strong emphasis on machine learning througho...
# 20    o Worked on multiple lab projects whose emphas...
# 21                       EDA (Exploratory Data Analysis
# 22                      Data Analysis and Visualization
# 23             Modeling and measuring model performance
# 24                     Tree Based Classification Models
# 25                 Supervised and Unsupervised Learning
# 26                          Natural Language Processing
# 27    o Capstone Project: ñMaximizing resume match p...
# 28                     Senior Manager - Implementation
# 29                             Allegis Global Solutions
#                             ...
# 47     Lead a recruitment team supporting multiple c...
# 48     Analyzed data provided by analytics team to i...
# 49     Presented proposals to ownership on strategic...
# 50     Developed metrics and reports for global recr...
# 51                   Futurestep _ A Korn /Ferry Company
# 52                                   Solution Architect
# 53                                            2003-2012
# 54                      Client: Cummins Diesel Engines
# 55                        Client: Fosters Wine Estates
# 56                                    Client: Wal-Mart
# 57    Project:  Client required a global ATS platfor...
# 58     Global implementation experience from plannin...
# 59     Lead the identification of stakeholders for t...
# 60     Lead business requirements meeting to underst...
# 61     Re-engineer and transform clients recruiting ...
# 62     Assisted in the configuration Taleo recruitin...
# 63     Created test scripts and scenarios. Led UAT (...
# 64     Defined reports based on client requirements ...
# 65     Developed and delivered Taleo training materi...
# 66                         Education and Certifications
# 67                                     General Assembly
# 68                       Data Science Immersive Program
# 69                     Saint MaryÍs College, California
# 70                           Executive Trans Global MBA
# 71              Saint JosephÍs University, Pennsylvania
# 72         BA International Relations; Minor Philosophy
# 73                         Project Management Institute
# 74                PMP _ Project Management Professional
# 75                           Glenn E. Itliong, MBA, PMP
# 76                                                 2018
# Name: Text, Length: 77, dtype: object

# %%
gresume_df = gresume_df.map(lambda x: x.replace('Õ', ''))

# %%
gresume_df = gresume_df.map(lambda x: x.replace('Ò', ''))

# %%
gresume_df = gresume_df.map(lambda x: x.replace('Ð', ''))

# %%
gresume_df = gresume_df.map(lambda x: x.replace('itliong', ''))

# %%
gresume_df = gresume_df.map(lambda x: x.replace('glenn', ''))

# %%
gresume_df = gresume_df.map(lambda x: x.replace('Glenn E. Itliong,', ''))

# %%
gresume_df = gresume_df.map(lambda x: x.replace('o ', ''))

# %%
gresume_df = gresume_df.map(lambda x: x.replace('650-207-0395', ''))

# %%
#Saving Cleaned Up Baseline Resume DataFrame

gresume_df.to_csv('Baseline Resume-Cleaned.csv')

# %%
df = pd.read_csv('Baseline Resume-Cleaned.csv')
