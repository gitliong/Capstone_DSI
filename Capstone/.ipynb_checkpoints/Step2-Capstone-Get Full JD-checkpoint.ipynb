# %%
import requests
import bs4
from bs4 import BeautifulSoup
from time import sleep
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
cvec = CountVectorizer()

# %%
pd.read_csv('Capstone_v1')
# Out:
#      Unnamed: 0                                    location  \
# 0             0            Atlanta, GA 30309 (Midtown area)
# 1             1                                 Atlanta, GA
# 2             2        Atlanta, GA 30303 (Five Points area)
# 3             3    Atlanta, GA 30308 (Old Fourth Ward area)
# 4             4                                 Atlanta, GA
# 5             5                                 Atlanta, GA
# 6             6                                 Atlanta, GA
# 7             7                                 Atlanta, GA
# 8             8            Atlanta, GA 30309 (Midtown area)
# 9             9           Atlanta, GA 30301 (Buckhead area)
# 10           10                       Johns Creek, GA 30097
# 11           11                                 Atlanta, GA
# 12           12                           Atlanta, GA 30339
# 13           13                                Kennesaw, GA
# 14           14                                 Atlanta, GA
# 15           15                                 Atlanta, GA
# 16           16            Atlanta, GA 30309 (Midtown area)
# 17           17                                 Atlanta, GA
# 18           18                                 Atlanta, GA
# 19           19                                 Atlanta, GA
# 20           20  Atlanta, GA 30306 (Virginia-Highland area)
# 21           21                                 Atlanta, GA
# 22           22                                 Atlanta, GA
# 23           23            Atlanta, GA 30309 (Midtown area)
# 24           24                                 Atlanta, GA
# 25           25        Atlanta, GA 30303 (Five Points area)
# 26           26                              Alpharetta, GA
# 27           27    Atlanta, GA 30308 (Old Fourth Ward area)
# 28           28                                 Atlanta, GA
# 29           29                        Alpharetta, GA 30022
# ..          ...                                         ...
# 441         441           Atlanta, GA 30318 (Rockdale area)
# 442         442           Atlanta, GA 30318 (Rockdale area)
# 443         443           Atlanta, GA 30318 (Rockdale area)
# 444         444                                 Atlanta, GA
# 445         445           Atlanta, GA 30326 (Buckhead area)
# 446         446                                 Atlanta, GA
# 447         447                                 Atlanta, GA
# 448         448           Atlanta, GA 30318 (Rockdale area)
# 449         449           Atlanta, GA 30318 (Rockdale area)
# 450         450           Atlanta, GA 30318 (Rockdale area)
# 451         451                                 Atlanta, GA
# 452         452                              Alpharetta, GA
# 453         453           Atlanta, GA 30318 (Rockdale area)
# 454         454                                 Atlanta, GA
# 455         455           Atlanta, GA 30318 (Rockdale area)
# 456         456           Atlanta, GA 30318 (Rockdale area)
# 457         457           Atlanta, GA 30318 (Rockdale area)
# 458         458           Atlanta, GA 30318 (Rockdale area)
# 459         459           Atlanta, GA 30318 (Rockdale area)
# 460         460           Atlanta, GA 30318 (Rockdale area)
# 461         461                          Norcross, GA 30092
# 462         462           Atlanta, GA 30318 (Rockdale area)
# 463         463           Atlanta, GA 30318 (Rockdale area)
# 464         464                           Atlanta, GA 30319
# 465         465           Atlanta, GA 30318 (Rockdale area)
# 466         466           Atlanta, GA 30318 (Rockdale area)
# 467         467           Atlanta, GA 30318 (Rockdale area)
# 468         468                                 Atlanta, GA
# 469         469                           Atlanta, GA 30328
# 470         470                                Norcross, GA
#
#                                                  title  \
# 0                                       Data Scientist
# 1                                       Data Scientist
# 2                                       Data Scientist
# 3                                     Data Scientist I
# 4                                       Data Scientist
# 5                                       Data Scientist
# 6                                       Data Scientist
# 7                 Data Scientist 1 – AP Forensics Team
# 8                                       Data Scientist
# 9                                       Data Scientist
# 10                     Data Scientist (PYTHON, HADOOP)
# 11                                      Data Scientist
# 12                               Senior Data Scientist
# 13                                      Data Scientist
# 14                            Associate Data Scientist
# 15                                      Data Scientist
# 16   Fall 2018 Data Scientist/Machine Learning Inte...
# 17                    Data Scientist, Keying & Linking
# 18   Data Scientist - Technical Lead - Phone OR Sky...
# 19                                      Data Scientist
# 20                                   Sr Data Scientist
# 21                                      DATA SCIENTIST
# 22   Business Intelligence Data Scientist - Supply ...
# 23                          Data Scientist - Marketing
# 24                       Chief Deep Learning Scientist
# 25                                        Data Analyst
# 26                                      Data Scientist
# 27                             Advanced Data Scientist
# 28                 DATA SCIENTIST - SPACE OPTIMIZATION
# 29                                      Data Scientist
# ..                                                 ...
# 441                    Senior FPGA Researcher - CIPHER
# 442                              Test Engineer - ELSYS
# 443                             System Engineer- ELSYS
# 444         Machine Learning Lead - Deloitte Platforms
# 445  Implementation Engineer (Machine Learning/Data...
# 446  Junior DevOps Software Engineer – Secureworks ...
# 447              Sr. Manager, Data Science Forecasting
# 448                            DevOps Engineer - ELSYS
# 449              Signal Processing Engineer Jr. - EOSL
# 450              Signal Modeling - Jr. Engineer - EOSL
# 451  Team Lead – Informatics. Sensus USA Inc. Atlan...
# 452    Senior-Big Data Software Eng - Machine Learning
# 453  Digital Simulation and Modeling - Jr. Engineer...
# 454               Senior Business Intelligence Analyst
# 455             Test Engineer (Advanced Degree) -ELSYS
# 456                         Software Engineer - CIPHER
# 457          System Engineer (Advanced Degree) - ELSYS
# 458   Full Stack Developer - GC Insights, New Ventures
# 459  Branch Head for FPGA Hardware Research and Dev...
# 460                Senior Software Researcher - CIPHER
# 461                                  Software Engineer
# 462           Senior FPGA Hardware Researcher - CIPHER
# 463  Missile Warning System (MWS)/Sensor System Ana...
# 464                            Staff Software Engineer
# 465                Electrical/Computer Engineer - EOSL
# 466  Systems Engineer (Research focused - Senior) -...
# 467               Signal Processing Engineer Sr - EOSL
# 468  Post-Doctoral Fellow- Medical Imaging, Machine...
# 469                                     Data Scientist
# 470                       Software Engineer - Big Data
#
#                                  company  salary  \
# 0                                TruckIT     NaN
# 1                                Equifax     NaN
# 2                         Operation HOPE     NaN
# 3                              Honeywell     NaN
# 4                               Cotiviti     NaN
# 5                         Cox Automotive     NaN
# 6                           AnswerRocket     NaN
# 7                         The Home Depot     NaN
# 8                  Norfolk Southern Corp     NaN
# 9                  The Coca-Cola Company     NaN
# 10                     SoftVision - TAMS     NaN
# 11                           Relus Cloud     NaN
# 12                        Softcrylic LLC     NaN
# 13                               Aaron's     NaN
# 14                        Inspire Brands     NaN
# 15                             SalesLoft     NaN
# 16                 Norfolk Southern Corp     NaN
# 17                               Equifax     NaN
# 18                                  DELL     NaN
# 19                            Hiscox Ltd     NaN
# 20                                  360i     NaN
# 21                       Interface, Inc.     NaN
# 22                         Newell Brands     NaN
# 23                             HD Supply     NaN
# 24                    YIWEI Medical Inc.     NaN
# 25                        Operation HOPE     NaN
# 26                      Scientific Games     NaN
# 27                             Honeywell     NaN
# 28                        The Home Depot     NaN
# 29                               Verizon     NaN
# ..                                   ...     ...
# 441      Georgia Tech Research Institute     NaN
# 442      Georgia Tech Research Institute     NaN
# 443      Georgia Tech Research Institute     NaN
# 444                             Deloitte     NaN
# 445                           eHire, LLC     NaN
# 446                                 DELL     NaN
# 447                        Newell Brands     NaN
# 448      Georgia Tech Research Institute     NaN
# 449      Georgia Tech Research Institute     NaN
# 450      Georgia Tech Research Institute     NaN
# 451                                Xylem     NaN
# 452                                 AT&T     NaN
# 453      Georgia Tech Research Institute     NaN
# 454                       The Home Depot     NaN
# 455      Georgia Tech Research Institute     NaN
# 456      Georgia Tech Research Institute     NaN
# 457      Georgia Tech Research Institute     NaN
# 458                   McKinsey & Company     NaN
# 459      Georgia Tech Research Institute     NaN
# 460      Georgia Tech Research Institute     NaN
# 461                   Intuitive Surgical     NaN
# 462      Georgia Tech Research Institute     NaN
# 463      Georgia Tech Research Institute     NaN
# 464                     General Electric     NaN
# 465      Georgia Tech Research Institute     NaN
# 466      Georgia Tech Research Institute     NaN
# 467      Georgia Tech Research Institute     NaN
# 468                     Emory University     NaN
# 469                     Matrix Resources     NaN
# 470                CareerBuilder Careers     NaN
#
#                                                summary           age  \
# 0                The Big Data and Machine Learning ...  30+ days ago
# 1                Developing data driven models to q...    5 days ago
# 2                Able to understand various data st...  30+ days ago
# 3    Data mining (including data auditing, aggregat...   19 days ago
# 4                This is a pioneering data scientis...   14 days ago
# 5                Cox Automotive is hiring a Data Sc...   13 days ago
# 6                Strong knowledge/experience with d...  30+ days ago
# 7    Data Visualization skills. Extensive work expe...    2 days ago
# 8                Analysist, statistician, data scie...  30+ days ago
# 9                Excellent data wrangling skills; S...  30+ days ago
# 10               3-5 years of experience building l...  30+ days ago
# 11               Experience using Python and/or R. ...  30+ days ago
# 12               Experience in statistical and data...    6 days ago
# 13               Demonstrates proficiency in severa...   16 days ago
# 14   Data cleansing/processing work with IT to crea...  30+ days ago
# 15               We are looking for a Data Scientis...  30+ days ago
# 16               You will have the opportunity of w...   27 days ago
# 17   Data Scientist, Keying & Linking. The Data Sci...  30+ days ago
# 18   Data Scientist - Technical Lead*. Extract data...    5 days ago
# 19               What you’ll be doing as a Data Sci...  30+ days ago
# 20               Advanced R or Python programming s...   12 days ago
# 21               The Data Scientist will analyze bu...  30+ days ago
# 22   Data Scientist – Business Intelligence. Direct...   19 days ago
# 23               Architect custom data environments...  30+ days ago
# 24               Combine medical imaging models int...  14 hours ago
# 25               Able to understand various data st...  30+ days ago
# 26               The Data Scientist offers expertis...   24 days ago
# 27               The Advanced Data Scientist role i...  30+ days ago
# 28               Extensive work experience in Appli...    7 days ago
# 29               Expertise in data management and d...  30+ days ago
# ..                                                 ...           ...
# 441              Real-time data processing and disp...   27 days ago
# 442  Python or similar scripting language. Experien...   27 days ago
# 443              Experience processing and analyzin...   27 days ago
# 444  Python, R, SQL, and Java. Gathering data from ...  30+ days ago
# 445              Developing plugin modules e.g. for...  30+ days ago
# 446              Experience with Python. Collaborat...   13 days ago
# 447              Director, Data Science. Reporting ...  30+ days ago
# 448              Strong scripting skills especially...   10 days ago
# 449              Programming/scripting in Matlab, P...   27 days ago
# 450              Experience with Python computer la...   27 days ago
# 451              Supervise 4-6 peer Data Scientists...  30+ days ago
# 452              Interacts with data scientists and...  30+ days ago
# 453              Experience with Python computer la...   27 days ago
# 454              VBA, Python, R, SAS, .NET, C++, Ja...   29 days ago
# 455  Python or similar scripting language. Experien...   27 days ago
# 456  Python, Java, C languages, R. Experience with ...   27 days ago
# 457              Experience processing and analyzin...   27 days ago
# 458              Expert in Python, Ruby, JavaScript...   10 days ago
# 459              Design experience with high-speed ...   17 days ago
# 460              Demonstrated experience with algor...   27 days ago
# 461              Test and maintain large databases ...   23 days ago
# 462              Design experience with high-speed ...   27 days ago
# 463              Experience with Python computer la...   27 days ago
# 464              Architects, Data Scientists, Busin...    6 days ago
# 465              Programming/scripting in Matlab, P...   27 days ago
# 466              Proficient in the use of SAS JMP, ...   27 days ago
# 467              Programming/scripting in Matlab, P...   27 days ago
# 468              Proficiency in programming using M...  30+ days ago
# 469              Experience with Python. A healthca...  30+ days ago
# 470              Experience with Python. Working wi...  30+ days ago
#
#                                                  slugs
# 0    /company/TruckIT/jobs/Data-Scientist-1574a00fd...
# 1    /rc/clk?jk=04f8b1a515e0db62&fccid=34c446722f3c...
# 2    /company/Operation-Hope/jobs/Data-Scientist-a5...
# 3    /rc/clk?jk=0fb71d2045dd029d&fccid=50208b5bf45e...
# 4    /rc/clk?jk=39fcbcceb4f60dd7&fccid=341483645418...
# 5    /rc/clk?jk=784c5a83633dec17&fccid=7e465a3d521b...
# 6    /company/AnswerRocket/jobs/Data-Scientist-ac33...
# 7    /rc/clk?jk=f4f78389d83d6c6e&fccid=82e58e9861d4...
# 8    /rc/clk?jk=77f9a60cc7638509&fccid=2fc6cbacc711...
# 9    /rc/clk?jk=1761018962b52cb3&fccid=681e47a680e0...
# 10   /rc/clk?jk=f346febd67aa1e7b&fccid=8e4ade64e8fe...
# 11   /rc/clk?jk=c9f6c48154ce1aab&fccid=72a09225e708...
# 12   /company/Softcrylic-LLC/jobs/Senior-Data-Scien...
# 13   /rc/clk?jk=3a7aed76e2cb52a7&fccid=f617425cf716...
# 14   /rc/clk?jk=95accded62a0b1c6&fccid=1b082641b237...
# 15   /rc/clk?jk=be06770fb79b4ce2&fccid=de4fd2d39ebd...
# 16   /rc/clk?jk=105f1bdc8b3513d3&fccid=2fc6cbacc711...
# 17   /rc/clk?jk=eb30d3c0023a2b32&fccid=34c446722f3c...
# 18   /company/IntellyK/jobs/Data-Scientist-a9f23beb...
# 19   /rc/clk?jk=c430f2244f15b3f8&fccid=9700fa012753...
# 20   /rc/clk?jk=89af6b2b5ee5b903&fccid=3f9dca3dd1f8...
# 21   /rc/clk?jk=02e825cc6de11f7c&fccid=649907072be3...
# 22   /rc/clk?jk=58e14f4cccbb3b6c&fccid=959fbc7b7aeb...
# 23   /rc/clk?jk=34bfe2b102f0701d&fccid=a19e63c0dc2e...
# 24   /company/YIWEI-Medical-Technology-Co.,-Ltd/job...
# 25   /company/Operation-Hope/jobs/Data-Analyst-6866...
# 26   /rc/clk?jk=fe8f5a93ffc0e62c&fccid=c84a7d17b9b1...
# 27   /rc/clk?jk=4e5ab824ffe5b9c2&fccid=50208b5bf45e...
# 28   /rc/clk?jk=240b3dd6b3d53601&fccid=82e58e9861d4...
# 29   /rc/clk?jk=f6f37524dac91e36&fccid=f7029f63fe5c...
# ..                                                 ...
# 441  /rc/clk?jk=2cea4f5d674449da&fccid=db25687464a9...
# 442  /rc/clk?jk=a5987b317f2f2971&fccid=db25687464a9...
# 443  /rc/clk?jk=3ad86f86a02d0830&fccid=db25687464a9...
# 444  /rc/clk?jk=39aebb6d3f61e39e&fccid=9e215d88a6b3...
# 445  /rc/clk?jk=49923a6dabff2511&fccid=2d05fe1a595c...
# 446  /rc/clk?jk=c0e6659aaab82237&fccid=0918a251e690...
# 447  /rc/clk?jk=71083753453ab8d5&fccid=959fbc7b7aeb...
# 448  /rc/clk?jk=df02277ea9397006&fccid=db25687464a9...
# 449  /rc/clk?jk=8c8eaf1d8b95e3ef&fccid=db25687464a9...
# 450  /rc/clk?jk=682497d57469e742&fccid=db25687464a9...
# 451  /rc/clk?jk=4b217b5c630e09c8&fccid=68ec8a8ee6cf...
# 452  /rc/clk?jk=97d1bb7f6ba0209a&fccid=25b5166547bb...
# 453  /rc/clk?jk=380747de05497340&fccid=db25687464a9...
# 454  /rc/clk?jk=51f79014ccf5171c&fccid=82e58e9861d4...
# 455  /rc/clk?jk=4782840cb94d0988&fccid=db25687464a9...
# 456  /rc/clk?jk=77af9c4ac1e06c08&fccid=db25687464a9...
# 457  /rc/clk?jk=2203debe80b889d2&fccid=db25687464a9...
# 458  /rc/clk?jk=60bb4d2f44006847&fccid=6576e7250aa7...
# 459  /rc/clk?jk=0b0b738334779695&fccid=db25687464a9...
# 460  /rc/clk?jk=c8809d7ef3e5153b&fccid=db25687464a9...
# 461  /rc/clk?jk=98feaaf96466e372&fccid=485155ca34f4...
# 462  /rc/clk?jk=6dd8dd885c22888a&fccid=db25687464a9...
# 463  /rc/clk?jk=8b6989e904aa26e7&fccid=db25687464a9...
# 464  /rc/clk?jk=3572ddd7632cc28b&fccid=53c1573dc4db...
# 465  /rc/clk?jk=9f2b4f2db9957544&fccid=db25687464a9...
# 466  /rc/clk?jk=501a8c129ff45082&fccid=db25687464a9...
# 467  /rc/clk?jk=a7b2787a758b56c5&fccid=db25687464a9...
# 468  /rc/clk?jk=6d8c755b3a8a4572&fccid=efe5e2d22a1d...
# 469  /rc/clk?jk=ae86cea979aa8597&fccid=22b65342d3dd...
# 470  /rc/clk?jk=914d2d48aa6dc162&fccid=0d56ca7b1c76...
#
# [471 rows x 8 columns]

# %%
df = pd.read_csv('Capstone_v1')

# %%
df.sort_values(by=['age'], ascending=True)
# Out:
#      Unnamed: 0                                    location  \
# 57           57           Atlanta, GA 30318 (Rockdale area)
# 204         204                                         NaN
# 253         253           Atlanta, GA 30318 (Rockdale area)
# 108         108                                         NaN
# 301         301                                         NaN
# 31           31                                 Atlanta, GA
# 448         448           Atlanta, GA 30318 (Rockdale area)
# 398         398                                         NaN
# 111         111                                         NaN
# 160         160           Atlanta, GA 30318 (Rockdale area)
# 41           41                                 Atlanta, GA
# 260         260           Atlanta, GA 30318 (Rockdale area)
# 211         211                                         NaN
# 350         350                                         NaN
# 458         458           Atlanta, GA 30318 (Rockdale area)
# 307         307                                         NaN
# 64           64           Atlanta, GA 30318 (Rockdale area)
# 409         409                                         NaN
# 356         356                                         NaN
# 154         154           Atlanta, GA 30318 (Rockdale area)
# 45           45                           Atlanta, GA 30319
# 20           20  Atlanta, GA 30306 (Virginia-Highland area)
# 106         106                                         NaN
# 446         446                                 Atlanta, GA
# 5             5                                 Atlanta, GA
# 425         425           Atlanta, GA 30342 (Buckhead area)
# 354         354                                         NaN
# 62           62                                 Atlanta, GA
# 305         305                                         NaN
# 209         209                                         NaN
# ..          ...                                         ...
# 194         194                                         NaN
# 225         225                                         NaN
# 205         205                                         NaN
# 130         130           Atlanta, GA 30326 (Buckhead area)
# 82           82                                         NaN
# 178         178                                         NaN
# 326         326                                         NaN
# 227         227           Atlanta, GA 30326 (Buckhead area)
# 375         375                                         NaN
# 1             1                                 Atlanta, GA
# 424         424           Atlanta, GA 30326 (Buckhead area)
# 277         277                                         NaN
# 18           18                                 Atlanta, GA
# 12           12                           Atlanta, GA 30339
# 311         311                                         NaN
# 464         464                           Atlanta, GA 30319
# 164         164                           Atlanta, GA 30319
# 410         410                                         NaN
# 215         215                                         NaN
# 360         360                                         NaN
# 121         121                                         NaN
# 264         264                           Atlanta, GA 30319
# 68           68                           Atlanta, GA 30319
# 28           28                                 Atlanta, GA
# 30           30                                 Atlanta, GA
# 129         129                                 Atlanta, GA
# 32           32                                 Atlanta, GA
# 276         276                                         NaN
# 325         325                                         NaN
# 374         374                                         NaN
#
#                                                  title  \
# 57                             DevOps Engineer - ELSYS
# 204                            DevOps Engineer - ELSYS
# 253                            DevOps Engineer - ELSYS
# 108                            DevOps Engineer - ELSYS
# 301                            DevOps Engineer - ELSYS
# 31         Data Scientist - CONSULTANT Level - Atlanta
# 448                            DevOps Engineer - ELSYS
# 398                            DevOps Engineer - ELSYS
# 111   Full Stack Developer - GC Insights, New Ventures
# 160   Full Stack Developer - GC Insights, New Ventures
# 41              Data Scientist / Analytic Consultant 3
# 260   Full Stack Developer - GC Insights, New Ventures
# 211   Full Stack Developer - GC Insights, New Ventures
# 350                            DevOps Engineer - ELSYS
# 458   Full Stack Developer - GC Insights, New Ventures
# 307   Full Stack Developer - GC Insights, New Ventures
# 64    Full Stack Developer - GC Insights, New Ventures
# 409   Full Stack Developer - GC Insights, New Ventures
# 356   Full Stack Developer - GC Insights, New Ventures
# 154                            DevOps Engineer - ELSYS
# 45   Tech Fall 2018 Intern - TDC Consumer Analytics...
# 20                                   Sr Data Scientist
# 106  Junior DevOps Software Engineer – Secureworks ...
# 446  Junior DevOps Software Engineer – Secureworks ...
# 5                                       Data Scientist
# 425              Mid Data Scientist - Machine Learning
# 354  Junior DevOps Software Engineer – Secureworks ...
# 62   Junior DevOps Software Engineer – Secureworks ...
# 305  Junior DevOps Software Engineer – Secureworks ...
# 209  Junior DevOps Software Engineer – Secureworks ...
# ..                                                 ...
# 194                Senior Quantitative Finance Analyst
# 225                       Software Engineer - Big Data
# 205    Senior-Big Data Software Eng - Machine Learning
# 130   Advanced Analytics Consultant - Machine Learning
# 82    Advanced Analytics Consultant - Machine Learning
# 178   Advanced Analytics Consultant - Machine Learning
# 326   Advanced Analytics Consultant - Machine Learning
# 227   Advanced Analytics Consultant - Machine Learning
# 375   Advanced Analytics Consultant - Machine Learning
# 1                                       Data Scientist
# 424   Advanced Analytics Consultant - Machine Learning
# 277   Advanced Analytics Consultant - Machine Learning
# 18   Data Scientist - Technical Lead - Phone OR Sky...
# 12                               Senior Data Scientist
# 311                            Staff Software Engineer
# 464                            Staff Software Engineer
# 164                            Staff Software Engineer
# 410                            Staff Software Engineer
# 215                            Staff Software Engineer
# 360                            Staff Software Engineer
# 121                            Staff Software Engineer
# 264                            Staff Software Engineer
# 68                             Staff Software Engineer
# 28                 DATA SCIENTIST - SPACE OPTIMIZATION
# 30                            Senior Data Scientist II
# 129                   Statistical Quantitative Analyst
# 32              Flight Safety Data Analysis Fall Co-Op
# 276                   Statistical Quantitative Analyst
# 325                   Statistical Quantitative Analyst
# 374                   Statistical Quantitative Analyst
#
#                                  company  salary  \
# 57       Georgia Tech Research Institute     NaN
# 204      Georgia Tech Research Institute     NaN
# 253      Georgia Tech Research Institute     NaN
# 108      Georgia Tech Research Institute     NaN
# 301      Georgia Tech Research Institute     NaN
# 31                             Capgemini     NaN
# 448      Georgia Tech Research Institute     NaN
# 398      Georgia Tech Research Institute     NaN
# 111                   McKinsey & Company     NaN
# 160                   McKinsey & Company     NaN
# 41                           Wells Fargo     NaN
# 260                   McKinsey & Company     NaN
# 211                   McKinsey & Company     NaN
# 350      Georgia Tech Research Institute     NaN
# 458                   McKinsey & Company     NaN
# 307                   McKinsey & Company     NaN
# 64                    McKinsey & Company     NaN
# 409                   McKinsey & Company     NaN
# 356                   McKinsey & Company     NaN
# 154      Georgia Tech Research Institute     NaN
# 45                                Turner     NaN
# 20                                  360i     NaN
# 106                                 DELL     NaN
# 446                                 DELL     NaN
# 5                         Cox Automotive     NaN
# 425                 Elev8 Hire Solutions     NaN
# 354                                 DELL     NaN
# 62                                  DELL     NaN
# 305                                 DELL     NaN
# 209                                 DELL     NaN
# ..                                   ...     ...
# 194                      Bank of America     NaN
# 225                CareerBuilder Careers     NaN
# 205                                 AT&T     NaN
# 130                    Slalom Consulting     NaN
# 82                     Slalom Consulting     NaN
# 178                    Slalom Consulting     NaN
# 326                    Slalom Consulting     NaN
# 227                    Slalom Consulting     NaN
# 375                    Slalom Consulting     NaN
# 1                                Equifax     NaN
# 424                    Slalom Consulting     NaN
# 277                    Slalom Consulting     NaN
# 18                                  DELL     NaN
# 12                        Softcrylic LLC     NaN
# 311                     General Electric     NaN
# 464                     General Electric     NaN
# 164                     General Electric     NaN
# 410                     General Electric     NaN
# 215                     General Electric     NaN
# 360                     General Electric     NaN
# 121                     General Electric     NaN
# 264                     General Electric     NaN
# 68                      General Electric     NaN
# 28                        The Home Depot     NaN
# 30                            Travelport     NaN
# 129                             SunTrust     NaN
# 32                       Delta Air Lines     NaN
# 276                             SunTrust     NaN
# 325                             SunTrust     NaN
# 374                             SunTrust     NaN
#
#                                                summary           age  \
# 57               Strong scripting skills especially...   10 days ago
# 204              Strong scripting skills especially...   10 days ago
# 253              Strong scripting skills especially...   10 days ago
# 108              Strong scripting skills especially...   10 days ago
# 301              Strong scripting skills especially...   10 days ago
# 31               (Includes Data Modeler, Data Miner...   10 days ago
# 448              Strong scripting skills especially...   10 days ago
# 398              Strong scripting skills especially...   10 days ago
# 111              Expert in Python, Ruby, JavaScript...   10 days ago
# 160              Expert in Python, Ruby, JavaScript...   10 days ago
# 41               The Data Management and Insights o...   10 days ago
# 260              Expert in Python, Ruby, JavaScript...   10 days ago
# 211              Expert in Python, Ruby, JavaScript...   10 days ago
# 350              Strong scripting skills especially...   10 days ago
# 458              Expert in Python, Ruby, JavaScript...   10 days ago
# 307              Expert in Python, Ruby, JavaScript...   10 days ago
# 64               Expert in Python, Ruby, JavaScript...   10 days ago
# 409              Expert in Python, Ruby, JavaScript...   10 days ago
# 356              Expert in Python, Ruby, JavaScript...   10 days ago
# 154              Strong scripting skills especially...   10 days ago
# 45               Turner Data Cloud, Consumer Analyt...   12 days ago
# 20               Advanced R or Python programming s...   12 days ago
# 106              Experience with Python. Collaborat...   13 days ago
# 446              Experience with Python. Collaborat...   13 days ago
# 5                Cox Automotive is hiring a Data Sc...   13 days ago
# 425              Mid Data Scientist. Currently 1 ot...   13 days ago
# 354              Experience with Python. Collaborat...   13 days ago
# 62               Experience with Python. Collaborat...   13 days ago
# 305              Experience with Python. Collaborat...   13 days ago
# 209              Experience with Python. Collaborat...   13 days ago
# ..                                                 ...           ...
# 194              Ability to appraise imperfect data...  30+ days ago
# 225              Experience with Python. Working wi...  30+ days ago
# 205              Interacts with data scientists and...  30+ days ago
# 130              Finding deep insights in mountains...    5 days ago
# 82               Finding deep insights in mountains...    5 days ago
# 178              Finding deep insights in mountains...    5 days ago
# 326              Finding deep insights in mountains...    5 days ago
# 227              Finding deep insights in mountains...    5 days ago
# 375              Finding deep insights in mountains...    5 days ago
# 1                Developing data driven models to q...    5 days ago
# 424              Finding deep insights in mountains...    5 days ago
# 277              Finding deep insights in mountains...    5 days ago
# 18   Data Scientist - Technical Lead*. Extract data...    5 days ago
# 12               Experience in statistical and data...    6 days ago
# 311              Architects, Data Scientists, Busin...    6 days ago
# 464              Architects, Data Scientists, Busin...    6 days ago
# 164              Architects, Data Scientists, Busin...    6 days ago
# 410              Architects, Data Scientists, Busin...    6 days ago
# 215              Architects, Data Scientists, Busin...    6 days ago
# 360              Architects, Data Scientists, Busin...    6 days ago
# 121              Architects, Data Scientists, Busin...    6 days ago
# 264              Architects, Data Scientists, Busin...    6 days ago
# 68               Architects, Data Scientists, Busin...    6 days ago
# 28               Extensive work experience in Appli...    7 days ago
# 30               Leads the evaluation of data techn...    7 days ago
# 129              Programming skills (SAS, R, Python...    9 days ago
# 32               The successful candidate will be r...    9 days ago
# 276              Programming skills (SAS, R, Python...    9 days ago
# 325              Programming skills (SAS, R, Python...    9 days ago
# 374              Programming skills (SAS, R, Python...    9 days ago
#
#                                                  slugs
# 57   /rc/clk?jk=df02277ea9397006&fccid=db25687464a9...
# 204  /rc/clk?jk=df02277ea9397006&fccid=db25687464a9...
# 253  /rc/clk?jk=df02277ea9397006&fccid=db25687464a9...
# 108  /rc/clk?jk=df02277ea9397006&fccid=db25687464a9...
# 301  /rc/clk?jk=df02277ea9397006&fccid=db25687464a9...
# 31   /rc/clk?jk=505e66ae209dbd8b&fccid=105ecfd0283f...
# 448  /rc/clk?jk=df02277ea9397006&fccid=db25687464a9...
# 398  /rc/clk?jk=df02277ea9397006&fccid=db25687464a9...
# 111  /rc/clk?jk=60bb4d2f44006847&fccid=6576e7250aa7...
# 160  /rc/clk?jk=60bb4d2f44006847&fccid=6576e7250aa7...
# 41   /rc/clk?jk=0faa4ca7250236ed&fccid=78bbcd26e396...
# 260  /rc/clk?jk=60bb4d2f44006847&fccid=6576e7250aa7...
# 211  /rc/clk?jk=60bb4d2f44006847&fccid=6576e7250aa7...
# 350  /rc/clk?jk=df02277ea9397006&fccid=db25687464a9...
# 458  /rc/clk?jk=60bb4d2f44006847&fccid=6576e7250aa7...
# 307  /rc/clk?jk=60bb4d2f44006847&fccid=6576e7250aa7...
# 64   /rc/clk?jk=60bb4d2f44006847&fccid=6576e7250aa7...
# 409  /rc/clk?jk=60bb4d2f44006847&fccid=6576e7250aa7...
# 356  /rc/clk?jk=60bb4d2f44006847&fccid=6576e7250aa7...
# 154  /rc/clk?jk=df02277ea9397006&fccid=db25687464a9...
# 45   /rc/clk?jk=9a02152e23c4236b&fccid=92b6ad9b1bd8...
# 20   /rc/clk?jk=89af6b2b5ee5b903&fccid=3f9dca3dd1f8...
# 106  /rc/clk?jk=c0e6659aaab82237&fccid=0918a251e690...
# 446  /rc/clk?jk=c0e6659aaab82237&fccid=0918a251e690...
# 5    /rc/clk?jk=784c5a83633dec17&fccid=7e465a3d521b...
# 425  /rc/clk?jk=5323c3342991d761&fccid=918f9b74accb...
# 354  /rc/clk?jk=c0e6659aaab82237&fccid=0918a251e690...
# 62   /rc/clk?jk=c0e6659aaab82237&fccid=0918a251e690...
# 305  /rc/clk?jk=c0e6659aaab82237&fccid=0918a251e690...
# 209  /rc/clk?jk=c0e6659aaab82237&fccid=0918a251e690...
# ..                                                 ...
# 194  /rc/clk?jk=cb2d52a492bd2e0e&fccid=5bd99dfa21c8...
# 225  /rc/clk?jk=914d2d48aa6dc162&fccid=0d56ca7b1c76...
# 205  /rc/clk?jk=97d1bb7f6ba0209a&fccid=25b5166547bb...
# 130  /rc/clk?jk=2b480477ae738fe4&fccid=a321096b9f1b...
# 82   /rc/clk?jk=2b480477ae738fe4&fccid=a321096b9f1b...
# 178  /rc/clk?jk=2b480477ae738fe4&fccid=a321096b9f1b...
# 326  /rc/clk?jk=2b480477ae738fe4&fccid=a321096b9f1b...
# 227  /rc/clk?jk=2b480477ae738fe4&fccid=a321096b9f1b...
# 375  /rc/clk?jk=2b480477ae738fe4&fccid=a321096b9f1b...
# 1    /rc/clk?jk=04f8b1a515e0db62&fccid=34c446722f3c...
# 424  /rc/clk?jk=2b480477ae738fe4&fccid=a321096b9f1b...
# 277  /rc/clk?jk=2b480477ae738fe4&fccid=a321096b9f1b...
# 18   /company/IntellyK/jobs/Data-Scientist-a9f23beb...
# 12   /company/Softcrylic-LLC/jobs/Senior-Data-Scien...
# 311  /rc/clk?jk=3572ddd7632cc28b&fccid=53c1573dc4db...
# 464  /rc/clk?jk=3572ddd7632cc28b&fccid=53c1573dc4db...
# 164  /rc/clk?jk=3572ddd7632cc28b&fccid=53c1573dc4db...
# 410  /rc/clk?jk=3572ddd7632cc28b&fccid=53c1573dc4db...
# 215  /rc/clk?jk=3572ddd7632cc28b&fccid=53c1573dc4db...
# 360  /rc/clk?jk=3572ddd7632cc28b&fccid=53c1573dc4db...
# 121  /rc/clk?jk=3572ddd7632cc28b&fccid=53c1573dc4db...
# 264  /rc/clk?jk=3572ddd7632cc28b&fccid=53c1573dc4db...
# 68   /rc/clk?jk=3572ddd7632cc28b&fccid=53c1573dc4db...
# 28   /rc/clk?jk=240b3dd6b3d53601&fccid=82e58e9861d4...
# 30   /rc/clk?jk=2b281b748d3e425e&fccid=423797cd2904...
# 129  /rc/clk?jk=fcc04631fc8bf6f5&fccid=131f8387a45b...
# 32   /rc/clk?jk=8fe4025946bb4187&fccid=af0caae05772...
# 276  /rc/clk?jk=fcc04631fc8bf6f5&fccid=131f8387a45b...
# 325  /rc/clk?jk=fcc04631fc8bf6f5&fccid=131f8387a45b...
# 374  /rc/clk?jk=fcc04631fc8bf6f5&fccid=131f8387a45b...
#
# [471 rows x 8 columns]

# %%
slugs = df['slugs']

# %%
slugs[:10]
# Out:
# 0    /company/TruckIT/jobs/Data-Scientist-1574a00fd...
# 1    /rc/clk?jk=04f8b1a515e0db62&fccid=34c446722f3c...
# 2    /company/Operation-Hope/jobs/Data-Scientist-a5...
# 3    /rc/clk?jk=0fb71d2045dd029d&fccid=50208b5bf45e...
# 4    /rc/clk?jk=39fcbcceb4f60dd7&fccid=341483645418...
# 5    /rc/clk?jk=784c5a83633dec17&fccid=7e465a3d521b...
# 6    /company/AnswerRocket/jobs/Data-Scientist-ac33...
# 7    /rc/clk?jk=f4f78389d83d6c6e&fccid=82e58e9861d4...
# 8    /rc/clk?jk=77f9a60cc7638509&fccid=2fc6cbacc711...
# 9    /rc/clk?jk=1761018962b52cb3&fccid=681e47a680e0...
# Name: slugs, dtype: object

# %%
extended_descriptions = []

list_of_dicts = []

# %%
for r in slugs[:100]:
    new_url = 'http://www.indeed.com' + r
    print('Requesting content from ' + new_url) # you can add + '...' 
    res = requests.get(new_url)
    # print('Converting content from the res object.')
    soup = BeautifulSoup(res.content, 'lxml')
    extended_descriptions.append(soup)
    sleep(3)
    print('Appending soup...')
# Out:
# Requesting content from http://www.indeed.com/company/TruckIT/jobs/Data-Scientist-1574a00fdeee048f?fccid=f3df6aca7d0f79d2&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=04f8b1a515e0db62&fccid=34c446722f3cf576&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/company/Operation-Hope/jobs/Data-Scientist-a5c0540250e41a45?fccid=63e09b63b5df262b&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=0fb71d2045dd029d&fccid=50208b5bf45ee3b8&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=39fcbcceb4f60dd7&fccid=3414836454185cb4&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=784c5a83633dec17&fccid=7e465a3d521b3ac3&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/company/AnswerRocket/jobs/Data-Scientist-ac337e34a5c0c098?fccid=86724ccf452a5636&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=f4f78389d83d6c6e&fccid=82e58e9861d48566&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=77f9a60cc7638509&fccid=2fc6cbacc7119b63&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=1761018962b52cb3&fccid=681e47a680e081c9&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=f346febd67aa1e7b&fccid=8e4ade64e8feb2ea&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=c9f6c48154ce1aab&fccid=72a09225e7084301&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/company/Softcrylic-LLC/jobs/Senior-Data-Scientist-1570a9c17b86fd09?fccid=e205055418e146aa&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=3a7aed76e2cb52a7&fccid=f617425cf716b431&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=95accded62a0b1c6&fccid=1b082641b237d96b&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=be06770fb79b4ce2&fccid=de4fd2d39ebd948a&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=105f1bdc8b3513d3&fccid=2fc6cbacc7119b63&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=eb30d3c0023a2b32&fccid=34c446722f3cf576&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/company/IntellyK/jobs/Data-Scientist-a9f23beb2f88b4a2?fccid=e15b306a2f9a30fe&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=c430f2244f15b3f8&fccid=9700fa0127532ea5&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=89af6b2b5ee5b903&fccid=3f9dca3dd1f81c69&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=02e825cc6de11f7c&fccid=649907072be36d94&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=58e14f4cccbb3b6c&fccid=959fbc7b7aeb5d18&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=34bfe2b102f0701d&fccid=a19e63c0dc2e301a&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/company/YIWEI-Medical-Technology-Co.,-Ltd/jobs/Chief-Deep-Learning-Scientist-bc95488eabc9fdb9?fccid=0a53b49c9302ad78&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/company/Operation-Hope/jobs/Data-Analyst-6866fbc693d5279b?fccid=63e09b63b5df262b&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=fe8f5a93ffc0e62c&fccid=c84a7d17b9b1910b&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=4e5ab824ffe5b9c2&fccid=50208b5bf45ee3b8&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=240b3dd6b3d53601&fccid=82e58e9861d48566&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=f6f37524dac91e36&fccid=f7029f63fe5c906e&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=2b281b748d3e425e&fccid=423797cd29045c3e&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=505e66ae209dbd8b&fccid=105ecfd0283f415f&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=8fe4025946bb4187&fccid=af0caae05772d1fa&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=cdbf7b45694e5fa7&fccid=50597ebf467edd46&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=fdcfb95c09832170&fccid=2fc6cbacc7119b63&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=d74c853ce28a92cd&fccid=f617425cf716b431&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=32a2f674e6094a4a&fccid=92b6ad9b1bd886b6&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=74e9c9246f6aea68&fccid=3414836454185cb4&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=32906cf7fca6f8af&fccid=82e58e9861d48566&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=a7de7c88e2ed3fe2&fccid=2fc6cbacc7119b63&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=cd4fc1cdefd89a94&fccid=0bc8a6533b9d1918&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=0faa4ca7250236ed&fccid=78bbcd26e39621f5&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=5f4d561c227c9d4e&fccid=485155ca34f4e0c7&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/company/Varian-Medical-Systems/jobs/Data-Scientist-bde445f0ee93c9b1?fccid=8fd9ec46a3e1e11a&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=50a93a24ad24af5d&fccid=105ecfd0283f415f&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=9a02152e23c4236b&fccid=92b6ad9b1bd886b6&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=742442527b0475a7&fccid=efe5e2d22a1d29e5&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=2889caa34bb4f168&fccid=105ecfd0283f415f&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=2764dc3bc99c233e&fccid=db25687464a9ecf6&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=8c8f9aa4c32828c5&fccid=db25687464a9ecf6&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=a5987b317f2f2971&fccid=db25687464a9ecf6&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=3ad86f86a02d0830&fccid=db25687464a9ecf6&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=39aebb6d3f61e39e&fccid=9e215d88a6b33622&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=49923a6dabff2511&fccid=2d05fe1a595cb99f&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=682497d57469e742&fccid=db25687464a9ecf6&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=380747de05497340&fccid=db25687464a9ecf6&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=8c8eaf1d8b95e3ef&fccid=db25687464a9ecf6&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=df02277ea9397006&fccid=db25687464a9ecf6&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=97d1bb7f6ba0209a&fccid=25b5166547bbf543&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=4782840cb94d0988&fccid=db25687464a9ecf6&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=77af9c4ac1e06c08&fccid=db25687464a9ecf6&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=71083753453ab8d5&fccid=959fbc7b7aeb5d18&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=c0e6659aaab82237&fccid=0918a251e6902f97&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=2203debe80b889d2&fccid=db25687464a9ecf6&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=60bb4d2f44006847&fccid=6576e7250aa78c3c&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=4b217b5c630e09c8&fccid=68ec8a8ee6cf5ac6&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=0b0b738334779695&fccid=db25687464a9ecf6&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=c8809d7ef3e5153b&fccid=db25687464a9ecf6&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=3572ddd7632cc28b&fccid=53c1573dc4db9cab&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=51f79014ccf5171c&fccid=82e58e9861d48566&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=98feaaf96466e372&fccid=485155ca34f4e0c7&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=6dd8dd885c22888a&fccid=db25687464a9ecf6&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=8b6989e904aa26e7&fccid=db25687464a9ecf6&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=9f2b4f2db9957544&fccid=db25687464a9ecf6&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=501a8c129ff45082&fccid=db25687464a9ecf6&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=a7b2787a758b56c5&fccid=db25687464a9ecf6&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=6d8c755b3a8a4572&fccid=efe5e2d22a1d29e5&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=ae86cea979aa8597&fccid=22b65342d3dd0d93&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=914d2d48aa6dc162&fccid=0d56ca7b1c7605d7&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=edeceaae5767fcb5&fccid=53c1573dc4db9cab&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=d7798a65ed1cea6a&fccid=2dd390c3a48a7ed0&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=b172b14c8fa2a081&fccid=5bd99dfa21c8a490&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=2b480477ae738fe4&fccid=a321096b9f1b3c50&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=8ddd1cb63bbb1a22&fccid=db25687464a9ecf6&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=5194a4048ea1e42c&fccid=969588d3048aa92a&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=39cca1e02aaade45&fccid=34c446722f3cf576&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=5fb4e0916a079671&fccid=105ecfd0283f415f&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=4e42bf083b09d891&fccid=82e58e9861d48566&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/company/UST-Global/jobs/Data-Analytic-Engineer-d3f7b9c364363489?fccid=8009d67e70703a78&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=6873777ae9347be6&fccid=db25687464a9ecf6&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=fbcce5b2bfb3ddab&fccid=db25687464a9ecf6&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=624edc80630a1ba5&fccid=3b4e0f2c2deb87d6&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=d2ff1fd645ef3c9c&fccid=2dd390c3a48a7ed0&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=5875a38dbb8fef43&fccid=2dd390c3a48a7ed0&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=0efc56077a085092&fccid=db25687464a9ecf6&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=cadabf21d9021246&fccid=db25687464a9ecf6&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=cb2d52a492bd2e0e&fccid=5bd99dfa21c8a490&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=2cea4f5d674449da&fccid=db25687464a9ecf6&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=8c8f9aa4c32828c5&fccid=db25687464a9ecf6&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=a5987b317f2f2971&fccid=db25687464a9ecf6&vjs=3
# Appending soup...

# %%
list_of_dicts
# Out:
# []

# %%
len(extended_descriptions)
# Out:
# 100

# %%
for each in extended_descriptions:
    print(type(each))
# Out:
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>

# %%
for page in extended_descriptions:
    for each in page.find_all('b'):
        print(each.get_text())
# Out:
# Data Scientist
# Truck IT, LLC
# BuiltWorlds
# Data Scientist
# ROLE
# ABOUT THE TEAM
# WHAT’S IN IT FOR YOU
# FOCUS
# Required Qualifications
# Preferred Qualifications
# Data Scientist
# Job Number:
# Position Title:
# External Description:
#
# Primary Location:
# Function:
# Schedule:
# City:
# Location_formattedLocationLong:
# State:
# Community / Marketing Title:
# Company Profile:
# Requisition Number:
# EEO Employer Verbiage:
# Data Scientist
# DEPARTMENT
# POSITION LOCATIONS
# :
# ACCOUNTABILITY
# :
# JOB SUMMARY
# DUTIES AND RESPONSIBILITIES
# REQUIRED SKILLS AND EDUCATION
# EEO
# STATEMENT
# Data Scientist I
# YOU MUST HAVE
# WE VALUE
# INCLUDES
# ADDITIONAL INFORMATION
# Job ID:
# Category:
# Location:
# Data Scientist
# Data Scientist
#
# Who You Are
# What You Will be Doing
#
# Requirements:
# Preferred Qualifications:
# Data Scientist
# Description
#
# Technology We Use:
#
# Your Role:
#
# Responsibilities:
#
# Qualifications
# Required Experience (minimum):
#
# What We Look For (preferred):
#
# About Cox Automotive
#
# Organization:
# Primary Location:
# Employee Status:
# Job Level:
# Shift:
# Travel:
# Schedule:
# Unposting Date:
# Data Scientist
# Data Scientist
# Responsibilities:
# Requirements:
# Extra Awesome
# What We Offer
# About AnswerRocket
# Data Scientist
# Principal Duties:
# Job Related Experience:
# Education:
# Licenses / Certifications:
# Technical Skills:
# Skills and Abilities:
# Work Conditions
# Company Overview
# Data Scientist
# Job ID:
# Position Overview:
# Function Specific Activities:
# Scale/Scope/Duties:
# Related Work Experience/Skills :
# Working knowledge of machine learning algorithms:
# Preferred technology stack:
# Educational Requirements:
# Travel Requirements:
# Relocation Assistance:
# Job Requirements:
# Years of Experience:
# Leadership Behaviors:
# DRIVE INNOVATION:
# COLLABORATE WITH SYSTEM, CUSTOMERS, AND OTHER STAKEHOLDERS:
# ACT LIKE AN OWNER:
# INSPIRE OTHERS:
# DEVELOP SELF AND OTHERS:
# Growth Behaviors:
# GROWTH MINDSET:
# SMART RISK:
# EXTERNALLY FOCUSED:
# PERFORMANCE DRIVEN AND ACCOUNTABLE:
# FAST/AGILE:
# EMPOWERED:
# Data Scientist (PYTHON, HADOOP)
# Data Scientist
# DATA SCIENTIST
# SUMMARY:
# WHAT YOU'LL DO:
#
# OUR IDEAL CANDIDATE HAS:
#
# BENEFITS:
# COMPANY SUMMARY:
# Senior Data Scientist
# Data Scientist
# Job Description:
# Data Scientist
# Duties and Responsibilities:
# Education and Experience:
# Required Skills:
# Associate Data Scientist
# RESPONSIBILITIES:
# EDUCATION QUALIFICATION:
# Required Minimum:
# EXPERIENCE QUALIFICATION:
# Required Minimum:
# REQUIRED KNOWLEDGE, SKILLS OR ABILITIES:
# Data Scientist
# Responsibilities:
# Requirements:
# Fall 2018 Data Scientist/Machine Learning Internship
# A Day in the Life of an Operations Research Intern
# What Makes a Successful Co-Op/Intern?
# Education/Experience
# Compensation
# Company Overview
# Data Scientist, Keying & Linking
# Job Number:
# Position Title:
# External Description:
# Data Scientist
# Essential Job Functions:
#
# Requirements:
#
# Primary Location:
# Function:
# Schedule:
# City:
# Location_formattedLocationLong:
# State:
# Community / Marketing Title:
# Company Profile:
# Requisition Number:
# EEO Employer Verbiage:
# Data Scientist - Technical Lead - Phone OR Skype - GC and Citizens Only
# Data Scientist - Technical Lead
# Atlanta, GA
# 3+ Months
# DELL
# Phone OR Skype
# Job Description:
# Data Scientist
# Position:
# Reporting to:
# Location:
# About the Business Intelligence Team:
# . What you’ll be doing as a Data Scientist:
# Our must-haves:
# Skills:
# Courage:
# Quality:
# Integrity:
# Excellence in Execution:
# Human:
# Sr Data Scientist
# Overview
#
# Qualifications
#
# DATA SCIENTIST
# Position Summary:
# Essential Duties:
# Qualification:
# Requirements
# Additional Skills / Knowledge
# Post: 3/20/18
# Remove: 3/27/18
# Business Intelligence Data Scientist - Supply Chain
# Location:
# Reports to:
# Key Responsibilities:
# Key Qualifications:
# Newell Brands (NYSE:
# Data Scientist - Marketing
# HD Supply (NASDAQ:
# Chief Deep Learning Scientist
# Job
# r*
# Requirement
# Data Analyst
# DEPARTMENT
# POSITION LOCATIONS
# :
# ACCOUNTABILITY
# :
# JOB SUMMARY
# DUTIES AND RESPONSIBILITIES
# REQUIRED SKILLS AND EDUCATION
# EEO
# STATEMENT
# Data Scientist
# Key Responsibilities:
# Required Skills and Experience:
# Advanced Data Scientist
# YOU MUST HAVE
# WE VALUE
# INCLUDES
# ADDITIONAL INFORMATION
# Job ID:
# Category:
# Location:
# DATA SCIENTIST - SPACE OPTIMIZATION
# Environment:
# Travel:
# Education Required:
# Years of Relevant Work Experience:
# Physical Requirements:
# Additional Qualifications:
# Preferred Qualifications:
# Data Scientist
# What you’ll be doing...
#
# What we’re looking for...
#
# When you join Verizon...
#
# Equal Employment Opportunity
# Senior Data Scientist II
# Main Accountabilities:
# Basic Qualifications:
#
# Preferred Qualifications:
# Data Scientist - CONSULTANT Level - Atlanta
# Overview:
# Role & Responsibilities:
# Requirements:
# Qualifications
# About Capgemini
# Flight Safety Data Analysis Fall Co-Op
# Core Responsibilities:
# Data Scientist - Supply Chain Optimization
# Data Scientist - Supply Chain Optimization
#
# TITLE: Data Scientist – Supply Chain Optimization
# LOCATION: United States, GA, Atlanta
# GRADE: 13
# NCR Corporation
# KEY AREAS OF RESPONSIBILITY:
#
# BASIC QUALIFICATIONS:
# EEO Statement
#
# Statement to Third Party Agencies
# Senior Data Scientist
# Principal Duties:
# Job Related Experience:
# Education:
# Licenses / Certifications:
# Technical Skills:
# Skills and Abilities:
# Work Conditions
# Company Overview
# Data Scientist-Prin-Mgr
# Duties and Responsibilities:
# Education and Experience:
# Required Skills:
# Senior Data Scientist
# About Turner
# Our Story
# What part will you play?
# What will you be doing?
#
# What do we require from you?
# But wait, there’s more!
#
# See what it’s like to work at Turner!
# Senior Data Scientist
# Data Scientist
#
# Who You Are
# What You Will be Doing
#
# Requirements:
# Preferred Qualifications:
# Data Scientist Supply Chain
# Environment:
# Travel:
# Additional Environmental Job Requirements:
# Education Required:
# Years of Relevant Work Experience:
# Physical Requirements:
# Additional Qualifications:
# Preferred Qualifications:
# Lead Data Scientist
# Join a growing Data Science and Advanced Analytics team at Norfolk Southern Corporation. The team is using latest cutting edge tools and technologies to develop analytics and solutions to solve business problems from various fields such as engineering, mechanical, communications, marketing & finance.
# Principal Duties:
# Job Related Experience:
# Education:
# Licenses / Certifications:
# Technical Skills:
# Skills and Abilities:
# Work Conditions
# Company Overview
# Imaging Scientist
# Duties and Responsibilities:
# Basic Qualifications:
# Minimum Qualifications:
# Data Scientist / Analytic Consultant 3
# Wells Fargo’s Chief Administrative Office (CAO)
# Key Responsibilities Include
#
# :
#
#
# Machine Learning Scientist
# Job:
# Primary Location:
# Schedule:
# Requisition ID:
# Description
# Company Description:
# Primary Function of Position:
# Qualifications
# Skill/Job Requirements:
# Data Scientist
# Data Scientist Manager -Atlanta
# Manager
# Overview:
#
# Qualifications
# About Capgemini
# Tech Fall 2018 Intern - TDC Consumer Analytics Data Scientist
# The Turner Story
# See what it’s like to work at Turner!
# What does our department do?
# What will you be doing?
# What do we require from you?
# What’s so great about this internship?
# Scientist, Asst Bioinformatics
# DESCRIPTION
#
# ADDITIONAL DETAILS
#
# Manager - Data Scientist !
# Overview:
# Role & Responsibilities:
# Requirements:
# Required Skills and Experience:
# Imaging Scientist/Engineer Jr. - EOSL
#
# Education & Length of Experience
# Research Engineer/Scientist I
# Research Engineer/Scientist II
#
# U.S. Citizenship Requirements
#
# Clearance Type Required
#
# Diversity & Inclusion
# Systems Engineer (Research focused) - ELSYS
#
# Education & Length of Experience
# Research Engineer/Scientist I
# Research Engineer/Scientist II
# Required Minimum Qualifications
#
# U.S. Citizenship Requirements
#
# Clearance Type Required
#
# Diversity & Inclusion
# Test Engineer - ELSYS
#
# EDUCATION & LENGTH OF EXPERIENCE
# Research Engineer/Scientist I
# REQUIRED MINIMUM QUALIFICATIONS
#
# PREFERRED QUALIFICATIONS
#
# U.S. CITIZENSHIP REQUIREMENTS
#
# CLEARANCE TYPE REQUIRED
#
# Diversity & Inclusion
# System Engineer- ELSYS
#
# Education & Length of Experience
# Research Engineer/Scientist I
# Required Minimum Qualifications
#
# PREFERRED QUALIFICATIONS
#
# U.S. CITIZENSHIP REQUIREMENTS
#
# Clearance Type Required
#
# Diversity & Inclusion
# Machine Learning Lead - Deloitte Platforms
# Machine Learning Lead - Deloitte Platforms
# Job Description
# About Deloitte Consulting’s Platforms Practice
# Job Responsibilities:
# Description:
# Basic Required skills:
# Additional Preferred Skills:
# How You’ll Grow
#
# Benefits
#
# Deloitte’s Culture
#
# Corporate Citizenship
#
# Recruiter Tips
# Implementation Engineer (Machine Learning/Data Analytics)
# Responsibilities:
# Signal Modeling - Jr. Engineer - EOSL
#
# Education & Length of Experience
# Research Engineer/Scientist
#  I
# Research Engineer/Scientist II
# Required Minimum Qualifications
# Preferred Qualifications
# U.S. Citizenship Requirements
#
# Clearance Type Required
#
# Diversity & Inclusion
# Digital Simulation and Modeling - Jr. Engineer - EOSL
#
# Education & Length of Experience
# Research Engineer/Scientist/Technologist/Associate I
# Research Engineer/Scientist/Technologist/Associate II
# Required Minimum Qualifications
# Preferred Qualifications
# U.S. Citizenship Requirements
#
# Clearance Type Required
#
# Diversity & Inclusion
# Signal Processing Engineer Jr. - EOSL
# Experience:
# DevOps Engineer - ELSYS
#
# Education & Length of Experience
# Research Engineer/Scientist/Technologist/Associate I
#
# Research Engineer/Scientist/Technologist/Associate II
#
# Required Minimum Qualifications
#
# Preferred Qualifications
#
# U.S. Citizenship Requirements
#
# Clearance Type Required
#
# Diversity & Inclusion
# Senior-Big Data Software Eng - Machine Learning
#
# Key Roles and Responsibilities
# Additional Information:
#
# Key Skills
#
# Preferred Skills
# Test Engineer (Advanced Degree) -ELSYS
#
# EDUCATION & LENGTH OF EXPERIENCE
# Research Engineer/Scientist II
# Senior Research Engineer/Scientist
# REQUIRED MINIMUM QUALIFICATIONS
#
# PREFERRED QUALIFICATIONS
#
# U.S. CITIZENSHIP REQUIREMENTS
#
# CLEARANCE TYPE REQUIRED
#
# Diversity & Inclusion
# Software Engineer - CIPHER
#
# Education & Length of Experience
# Research Engineer/Scientist/Technologist/Associate I
# Research Engineer/Scientist/Technologist/Associate II
# Required Minimum Qualifications
# Preferred Qualifications
# U.S. Citizenship Requirements
#
# Clearance Type Required
#
# Diversity & Inclusion
# Sr. Manager, Data Science Forecasting
# Position Title :
# Key Responsibilities:
# Key Qualifications:
# Newell Brands (NYSE:
# Junior DevOps Software Engineer – Secureworks – Atlanta, GA, Austin, TX or Remote
# About Secureworks
#
# Role Overview
#
# Core Responsibilities Include
#
# Required Skills and Experience
#
# Preferred Skills and Experience
# System Engineer (Advanced Degree) - ELSYS
#
# Education & Length of Experience
# Research Engineer/Scientist II
# Senior Research Engineer/Scientist
# Required Minimum Qualifications
#
# PREFERRED QUALIFICATIONS
#
# U.S. Citizenship Requirements
#
# Clearance Type Required
#
# Diversity & Inclusion
# Full Stack Developer - GC Insights, New Ventures
# Qualifications
# Who You'll Work With
# What You'll Do
# Team Lead – Informatics. Sensus USA Inc. Atlanta, Georgia
# Branch Head for FPGA Hardware Research and Development - CIPHER
#
# Education & Length of Experience
# Research Engineer/Scientist II
# Senior Research Engineer/Scientist
# Required Minimum Qualifications
# Preferred Qualifications
# U.S. Citizenship Requirements
#
# Clearance Type Required
#
# Diversity & Inclusion
# Senior Software Researcher - CIPHER
#
# Education & Length of Experience
# Senior Research Engineer/Scientist/Technologist/Associate
# Principal Research Engineer/Scientist/Technologist/Associate
# Required Minimum Qualifications
# Preferred Qualifications
# U.S. Citizenship Requirements
#
# Clearance Type Required
#
# Diversity & Inclusion
# Staff Software Engineer
# About Us:
# Role Summary:
# Essential Responsibilities:
# Qualifications/Requirements:
# Desired Characteristics:
# Locations:
# Senior Business Intelligence Analyst
# Environment:
# Travel:
# Education Required:
# Years of Relevant Work Experience:
# Physical Requirements:
# Additional Qualifications:
# Software Engineer
# Job:
# Primary Location:
# Schedule:
# Requisition ID:
# Description
# Company Description:
# Primary Function of Position:
# Qualifications
# Skill/Job Requirements:
# Senior FPGA Hardware Researcher - CIPHER
#
# Education & Length of Experience
# Senior Research Engineer/Scientist
# Principal Research Engineer/Scientist
# Required Minimum Qualifications
# Preferred Qualifications
# U.S. Citizenship Requirements
#
# Clearance Type Required
#
# Diversity & Inclusion
# Missile Warning System (MWS)/Sensor System Analysis and Modeling - Jr. Engineer
#
# Education & Length of Experience
# Research Engineer/Scientist I
# Research Engineer/Scientist II
# Required Minimum Qualifications
# Preferred Qualifications
# U.S. Citizenship Requirements
#
# Clearance Type Required
#
# Diversity & Inclusion
# Electrical/Computer Engineer - EOSL
#
# Education & Length of Experience
# Research Engineer/Scientist I
# Research Engineer/Scientist II
#
# U.S. Citizenship Requirements
#
# Clearance Type Required
#
# Diversity & Inclusion
# Systems Engineer (Research focused - Senior) - ELSYS
#
# Education & Length of Experience
# Senior Research Engineer/Scientist
# Principal Research Engineer/Scientist
# Required Minimum Qualifications
#
# U.S. Citizenship Requirements
#
# Clearance Type Required
#
# Diversity & Inclusion
# Signal Processing Engineer Sr - EOSL
# Post-Doctoral Fellow- Medical Imaging, Machine Learning and CT Physics
# DESCRIPTION
#
# ADDITIONAL DETAILS
#
# Data Scientist
# Software Engineer - Big Data
#
# Job Description
#
# Responsibilities
# Qualifications
# Preferred Qualifications
# Benefits-We’re All About You!
#
# TSR ID:
# Sr Director - Data & Analytics
# About Us:
# Role Summary:
# Essential Responsibilities:
# Qualifications/Requirements:
# Desired Characteristics:
# Locations:
# Director, Data Scientist -- Financial Services/Insurance
# Corporate Investment Quantitative Finance Analyst
# Job Description:
# Required Skills:
#
# Desired Skills:
# Shift:
# Hours Per Week:
# Advanced Analytics Consultant - Machine Learning
#
# Job Title
#
# What will you be doing at Slalom?
#
# Solving
#
# Being
#
# Developing
#
#
# Finding
#
# Driving
# Working
#
# Who are you?
#
# What technologies will you be using?
#
# Why do we work here?
#
# What does the recruitment process look like?
# Imaging Scientist/Engineer Sr. - EOSL
#
# Education & Length of Experience
# Senior Research Engineer/Scientist
#
# U.S. Citizenship Requirements
#
# Clearance Type Required
#
# Diversity & Inclusion
# Senior Data Engineer, Next Big Sound
# About Next Big Sound
# About the role
# Responsibilities
#
# Requirements
#
# About Pandora
# Big Data Engineer
# Job Number:
# Position Title:
# External Description:
# Job Title: Big Data Engineer
# Position Summary:
#
# Required Skills:
#
# Preferred/Other Skills:
#
# Education:
# Primary Location:
# Function:
# Schedule:
# City:
# Location_formattedLocationLong:
# State:
# Community / Marketing Title:
# Company Profile:
# Requisition Number:
# EEO Employer Verbiage:
# Data Science - Senior Consultant
# Senior Consultant
# Overview:
# Role & Responsibilities
# :
# Requirements
# :
#
# Qualifications
#
# About Capgemini
# SENIOR DATA ANALYST SUPPLY CHAIN
# MAJOR TASKS, RESPONSIBILITES AND KEY ACCOUNTABILITIES:
# ENVIRONMENTAL JOB REQUIREMENTS:
# Environment:
# Travel:
# Education Required:
# Years of Relevant Work Experience:
# Physical Requirements:
# Additional Qualifications:
# Preferred Qualifications:
# Knowledge, Skills, Abilities and Competencies:
# Data Analytics Engineer / Big Data Engineer
# Optical Scientist/Engineer, Sr - EOSL
#
# Education & Length of Experience
# Senior Research Engineer/Scientist
# Required Minimum Qualifications
#
# U.S. Citizenship Requirements
#
# Clearance Type Required
#
# Diversity & Inclusion
# Software Researcher - CIPHER
#
# Education & Length of Experience
# Research Engineer/Scientist I
# Research Engineer/Scientist II
# Required Minimum Qualifications
# Preferred Qualifications
# U.S. Citizenship Requirements
#
# Clearance Type Required
#
# Diversity & Inclusion
# Sr. Data Scientist – Market Research
# Sr. Data Scientist – Market Research
#
# Job Description:
# Requirements:
# Keywords:
# Big Data Software Engineer
# Big Data SW Engineer
# FPGA Hardware Researcher - CIPHER
#
# Education & Length of Experience
# Research Engineer/Scientist I
# Research Engineer/Scientist II
# Required Minimum Qualifications
# Preferred Qualifications
# U.S. Citizenship Requirements
#
# Clearance Type Required
#
# Diversity & Inclusion
# Senior Machine Learning Researcher - CIPHER
#
# Education & Length of Experience
# Senior Research Engineer/Scientist/Technologist/Associate
# Principal Research Engineer/Scientist/Technologist/Associate
# Required Minimum Qualifications
# Preferred Qualifications
# U.S. Citizenship Requirements
#
# Clearance Type Required
#
# Diversity & Inclusion
# Senior Quantitative Finance Analyst
# Job Description:
# Shift:
# Hours Per Week:
# Senior FPGA Researcher - CIPHER
#
# Research Areas:
# Education & Length of Experience
# Senior Research Engineer/Scientist
# Required Minimum Qualifications
# Preferred Qualifications
# U.S. Citizenship Requirements
#
# Clearance Type Required
#
# Diversity & Inclusion
# Systems Engineer (Research focused) - ELSYS
#
# Education & Length of Experience
# Research Engineer/Scientist I
# Research Engineer/Scientist II
# Required Minimum Qualifications
#
# U.S. Citizenship Requirements
#
# Clearance Type Required
#
# Diversity & Inclusion
# Test Engineer - ELSYS
#
# EDUCATION & LENGTH OF EXPERIENCE
# Research Engineer/Scientist I
# REQUIRED MINIMUM QUALIFICATIONS
#
# PREFERRED QUALIFICATIONS
#
# U.S. CITIZENSHIP REQUIREMENTS
#
# CLEARANCE TYPE REQUIRED
#
# Diversity & Inclusion

# %%
list_of_para = []
for page in extended_descriptions:
    for each in page.find_all('p'):
        list_of_para.append(each.get_text())

# %%
list_of_li = []

for page in extended_descriptions:
    for each in page.find_all('li'):
        list_of_li.append(each.get_text())

# %%
list_of_li
# Out:
# ['Location, Location, Location - 1372 Peachtree is three floors of awesome office space in a brand-new WeWork building in Midtown Atlanta, which is conveniently located across from the Midtown Arts Marta Station',
#  'Competitive compensation with incentive opportunities',
#  'Benefits include: Medical, Dental, Vision and Commuter',
#  'Becoming an integral part of a winning team surrounded by bright teammates',
#  'Supportive leadership that recognizes and rewards outstanding performance',
#  'Small company culture where everyone’s contribution matters and is valued',
#  'Ability to participate in a constant offering and variety of lunch and learns along with departmental cross training',
#  'Casual work environment and team outings',
#  'Experience joining a company at a high-growth, inflection point and being a part of building something special',
#  'Collaborate with product management and engineering groups to develop new products and features',
#  "Able to identify customers' needs and desires by specifying the research needed to obtain market information",
#  'Deliver informative and effective findings, results and recommendations from machine learning models to stakeholders',
#  'Create dashboards of important statistics and metrics',
#  'Develop and implement scalable and efficient modeling algorithms that can work with large-scale data in production systems',
#  'Develop predictive models to address various business problems by leveraging advanced statistical modeling, machine learning, or data mining techniques.',
#  'MS or PhD degree in Computer Science or relevant technical fields.',
#  'Proficient in one or more programming languages such as Python, Java, C and etc.',
#  'Familiar with one or more machine learning or statistics tools/packages such as R, SciKitLearn, SparkML(MLlib), Tensorflow and etc.',
#  'Knowledge and experience of machine learning, statistical modeling, or AI techniques',
#  'Knowledge and experience of relational databases and SQL',
#  'Strong analytical and quantitative problem-solving ability.',
#  'Experience with big data techniques (such as Hadoop, MapReduce, Hive, Pig, Spark)',
#  'Knowledge of cloud platforms (such as AWS or Azure) and experience of developing applications on the cloud platforms using various cloud services',
#  'Atlanta, GA 30309',
#  'United States',
#  'Analyzing, processing, evaluating and documenting large data sets',
#  '\nIdentifying/developing appropriate machine learning/data mining/text mining techniques to resolve entities and create relationships',
#  '\nPrototyping tools and techniques to solve complex data problems',
#  '\nDeveloping data driven models to quantify the value of a given data set',
#  '\nApplying, modifying and inventing algorithms to solve challenging business problems',
#  '\nValidating entity resolution and linking capabilities',
#  '\nConducting ROI and benefit analysis',
#  '\nDocumenting and presenting process and performance measurements',
#  "\n3-5 Years' Experience in SQL/HiveQL, Python, Scala, Elasticsearch,",
#  '\nExperienced with advanced entity techniques and linking capabilities',
#  "\nBachelor's Degree",
#  '\nData Scientist jobs in Atlanta, GA\n',
#  '\nJobs at Equifax in Atlanta, GA\n',
#  '\nData Scientist salaries in Atlanta, GA\n',
#  'Work with stakeholders in Quality Assurance and throughout the organization to identify opportunities for leveraging company data to drive services and process improvement solutions',
#  'Provide meaningful data analyses and reports to field operations leadership to assist in service evaluation',
#  'Mine and analyze data from company databases to drive optimization and improvement of product and process performance',
#  'Assess the effectiveness and accuracy of new data sources and data gathering techniques',
#  'Use predictive modeling to increase and optimize client experiences',
#  'Coordinate with different teams to implement models and monitor outcomes',
#  'Develop processes and tools to monitor and analyze model performance and data accuracy',
#  'Initiate and participate in projects in the area of prediction, optimization, and processes using advanced statistical / mathematical approaches',
#  'Implement most recent algorithms and approaches for machine learning in collaboration with our researchers',
#  'Design best architecture and select the most appropriate modeling techniques and data visualization for big data analysis',
#  'Iteratively test, refine and improve the models',
#  'Conduct research and make recommendations on data mining products, protocols, services, and standards in support of procurement and development efforts.',
#  'Learn quickly new mathematical or technical methods',
#  'Ph.D. or MS in Computer Science, Engineering, Statistics, Applied Math or related quantitative topics',
#  'Able to understand various data structures and common methods in data transformation',
#  'Experience in statistical modeling, machine learning, or data mining practice',
#  'Experience in SQL, relational databases, database concepts, dimensional modeling and database design',
#  'Proficient in one or more programming languages such as Java, C++, Python, JavaScript',
#  'Strong analytical and quantitative problem solving ability',
#  'Excellent communication, relationship skills and a strong team player',
#  'Experience with BI softwares',
#  'Proficient in STATA',
#  'STATA: 2 years',
#  'Statistical modeling and data mining: 2 years',
#  'BI softwares: 2 years',
#  'SQL, relational databases, and database design: 2 years',
#  'Programming languages such as Java, C++, Python, JavaScript: 2 years',
#  "Master's",
#  'Atlanta, GA',
#  'United States',
#  'Graduate degree in Engineering, Science or related field at an accredited college or university',
#  '\n1+ yrs of experience in developing Data Science solutions.',
#  '\n1+ yrs of experience in any of the following Data Science technologies:',
#  '\nApplication, statistical, conceptual, mathematical, modeling, and predictive analytic expertise',
#  '\nSystem/Data Integration',
#  '\nHigh level programming skills (Python, R, Matlab, C++ or Java)',
#  '\nMachine Learning Algorithms',
#  '\nData mining (including data auditing, aggregation, validation and reconciliation)',
#  '\nCloud Computing',
#  '\nData Visualization/Presentation',
#  'Impeccable integrity',
#  '\nExperience in working with Hadoop, MapReduce, Hive, HBase and other big data technologies',
#  '\nExperience in working with ETL tools such as Informatica, Talend and/or Pentaho.',
#  '\nGood understanding of cluster and parallel architecture as well as high-scale or distributed RDBMS and/or knowledge on NoSql platforms.',
#  '\nFamiliarity and experience in the automotive industry around bus communications, electronic control units, embedded software, powertrain, engine, and control',
#  '\nExcellent oral and written communication',
#  '\nAbility to embrace the philosophy of taking 100% responsibility for delivering results',
#  '\nThe ability to work in a team environment',
#  '\nFamiliarity and experience with software deployment and support',
#  '\nSuperior presentation and communication skills.',
#  '\nDemonstrated ability to operate effectively in an international functional matrix organizational structure',
#  'Relocation Provided',
#  'Continued Professional Development',
#  'Some Travel Required',
#  'Job ID: req149533\n',
#  'Category: Engineering\n',
#  'Location: 715 Peachtree Street, N.E., Atlanta, GA 30308 USA\n',
#  '\nData Scientist jobs in Atlanta, GA\n',
#  '\nJobs at Honeywell in Atlanta, GA\n',
#  '\nData Scientist salaries in Atlanta, GA\n',
#  'Curious: You enjoy peeling apart a problem and examining the interrelationships between data that may appear superficially unrelated.\n',
#  'Creative: You constantly invent and try new approaches to solving problems, which often times have never been applied in such contexts before.\n',
#  'Practical: You explore theories with an eye to the real world application to the business and the potential for improving performance for clients and customers.\n',
#  "Focused: You're intent on designing and testing a technique over periods of days and weeks, discovering what is successful and what should be optimized further. Furthermore, you learn from the failure and trying again.\n",
#  'Determined: You will have both the challenge and opportunity to help design our analytical backend from the ground-up, and therefore must be comfortable as both a team member and a leader in our data science effort.\n',
#  'Function as Data Scientist which carries the expectation to enhance an SaaS platform that integrates both relational and non-relational databases at scale with both algorithmic logic and front-end interfaces.\n',
#  'Participate in product development with leadership team meetings and communicate with advisors regularly on all matters regarding insights and technology developments.\n',
#  'Define the software architecture of the growing data analytics capability and build substantial portions yourself.',
#  'MS or PhD. Degree in relevant discipline (Math, Statistics, Computer Science, Engineering or Health Sciences) required.\n',
#  '3+ years’ experience in advanced analytics.\n',
#  '3+ years’ experience in a data architecture role with deep understanding of architecture principles & best practices.\n',
#  'Experience delivering solutions in an Agile environment.\n',
#  'Working knowledge of the Hadoop ecosystem (including creating and debugging)\n',
#  'Proficiency in fully architecting and executing complex analytical backends\n',
#  'Proficiency with Node.js and SQL; Expert proficiency in one or more programming languages such as Scala/Spark, Python, et al; Expert proficiency in at least one statistical modeling program like R, MATLAB, or SAS\n',
#  'Experience in machine learning, artificial intelligence and/or artificial neural networks\n',
#  'Proficiency in applying various mathematical and statistical models to include, but not limited to: Discrete Event Simulation, Factor Analysis, Genetic Algorithms, Bayesian Probability Models, Hidden Markov Models and Sensitivity Analysis\n',
#  'Ability to setup and maintain database for extremely large datasets using current database technologies (ex. Hadoop)\n',
#  'Strong experience in using application programming interfaces (API)\n',
#  'Proficient in the big data ecosystem with familiarity with Hadoop, Yarn, Spark, and/or Storm\n',
#  'Proficient in at least one big data store, for example: hBase, Cassandra, Hive, etc.\n',
#  'Demonstrated technical abilities to engineer products that large datasets, with tools that may include: Cluster computing, Grid Computing, Graphical Processing Unit Computing\n',
#  'Commercial Cloud Systems such as Amazon Elastic Cloud Compute EC2',
#  '\nData Scientist jobs in Atlanta, GA\n',
#  '\nJobs at Cotiviti in Atlanta, GA\n',
#  '\nData Scientist salaries in Atlanta, GA\n',
#  '\nContinue enhancing the Manheim Market Report (MMR) related products based on new feature request, clients feedback and performance benchmarking.',
#  '\nLeverage the vehicle build data information to provide vehicle content/option adjustment for the general MMR model.',
#  '\nAnalysis the Vehicle Catalog system, Vehicle Description service and Vehicle Translate system. Provide the insight analysis and data science support for these systems, at the same time, leverage these information to other products, such as the forecast MMR, VIN decoding systems.',
#  '\nIntroduce and implement these cutting-edge technology, innovation method and agile development system, such as the machine learning, artificial intelligence, AWS environment, etc.',
#  '\nDevelop common APIs to deliver the solutions and make it ready to be integrated into other applications.',
#  '\nCollaborate with team members to research and evaluate new valuation methodologies, approaches and solutions.',
#  '\nInterpret and communicate analytic results to analytical and non-analytical business partners and executive decision makers',
#  '\nMust have at least 5+ years’ experience performing advanced quantitative analyses.',
#  '\nGraduate degree in Applied Statistics or Applied Mathematics or other related degrees.',
#  '\nAbility to manipulate, analyzes, and interprets terabytes of data. Ability to organize findings and translate into actionable insights using original or innovative techniques or style.',
#  '\nAbility to apply advanced statistical methodologies such as sampling theory, design of experiments, regression, analysis of variance, correlation techniques, and factor analysis.',
#  '\nMust have intermediate to advanced experience in Statistical Language Software (e.g. R, SAS) and database applications.',
#  '\nMust have intermediate or advanced experience in General Language Software (e.g. Python), and AWS experience are preferred.',
#  '\nMust have relational database experience (e.g. SQL).',
#  '\nA strong passion for empirical research and for answering hard questions with data',
#  '\nDemonstrated experience in organizing, prioritizing, and coordinating complex team efforts',
#  '\nAWS experience',
#  '\nData Scientist jobs in Atlanta, GA\n',
#  '\nJobs at Cox Automotive in Atlanta, GA\n',
#  '\nData Scientist salaries in Atlanta, GA\n',
#  'Leverage Big Data to discover patterns and solve strategic and tactical business problems using massive structured and unstructured data sets across multiple environments',
#  'Understand customer business use cases and be able to translate them to analytical data applications and models with a vision on how to implement a solution',
#  'Develop tools to analyze data accuracy and model performance',
#  'Leverage machine learning, natural language processing, and/or advanced statistical techniques',
#  'Research industry topics impacting opportunities relevant for data analysis projects',
#  'Coordinate across teams (product management, engineering, etc.) timely and effectively',
#  'Strong knowledge/experience with data science pipeline and analytics tools such as Python, R, matlab, octane, clojure, tensorflow, keras, or other AI frameworks',
#  'In-depth understanding of data scrubbing, database management, statistics, and machine learning',
#  'Organized and capable of independently managing complex analytical projects from start to finish',
#  'Excellent interpersonal, written, and oral communication skills',
#  'Strong, out-of-the-box thinking, and a curious mind',
#  'Ability to clearly communicate complex results to technical and non-technical audiences',
#  'At least 3+ years of overall analytics experience',
#  'Degree in Computer Science, Mathematics, Statistics or another quantitative field',
#  'Ability to work full-time, onsite in our Sandy Springs office',
#  'Advanced degree in Computer Science, Mathematics, Statistics, or another quantitative field',
#  '4+ years of experience in consulting with emphasis on specializing in forecasting, linear programming, or machine learning',
#  'Competitive salary and health benefits',
#  'Paid company holidays and up to 15 days of PTO',
#  'Complimentary perks such as an onsite gym, free snacks, and monthly catered lunches',
#  'analytics: 3 years',
#  "Bachelor's",
#  'Atlanta, GA',
#  'United States',
#  'Effectively utilize statistical, data mining, and machine learning techniques, and computer science skills in delivering advanced analytics and decision support systems.',
#  'Collaborates with various departments to identify opportunities for process improvement and developing analytics use-cases.',
#  'Advanced machine learning techniques and algorithms, e.g. gradient boosting, random forests, neural networks, SVMs',
#  'Advanced statistical techniques, e.g. Bayesian, sampling and experimental design',
#  'Excellent knowledge in R and/or Python',
#  'Knowledge of big data and Hadoop-stack technologies, especially: Spark (preferably pyspark) and Hive',
#  'Knowledge of SQL and relational databases',
#  'Experience with sensor/signal data is a plus',
#  'Experience with image processing and Deep Learning is a plus',
#  'Planning and Organizing',
#  'Identifying and Considering Alternatives',
#  'Analytical Thinking',
#  'Communication Skills',
#  'Initiative',
#  '\nData Scientist jobs in Atlanta, GA\n',
#  '\nJobs at Norfolk Southern in Atlanta, GA\n',
#  '\nData Scientist salaries in Atlanta, GA\n',
#  '\nData Scientist jobs in Atlanta, GA\n',
#  '\nJobs at The Coca-Cola Company in Atlanta, GA\n',
#  '\nData Scientist salaries in Atlanta, GA\n',
#  '5-7 years of Data Modeling and Machine Learning Experience',
#  '5-7 years of Python & R- Language Experience',
#  '5-7 years of HADOOP-BIGDATA experience',
#  'Proficiency dealing with extraction and manipulation of relational databases (SQL)',
#  '3 -5 years of experience in advanced statistical techniques such as predictive statistical models, customer profiling, segmentation analysis survey design and analysis and data mining',
#  '3-5 years of experience of learning systems to analyze and filter continuous data flows.',
#  '3-5 years of experience of analyzing large data sets to develop custom models and algorithms to drive business solutions.',
#  '3-5 years of experience building large data sets from multiple sources to build algorithms for predicting future data characteristics.',
#  'Experience developing custom data models to drive recommendations.',
#  'Experience working in a cross-functional environment.',
#  'Excellent Communication Skills',
#  'Good Team Player',
#  'Able to work independently with minimum guidance',
#  '\nData Scientist jobs in Johns Creek, GA\n',
#  '\nJobs at SoftVision in Johns Creek, GA\n',
#  '\nData Scientist salaries in Johns Creek, GA\n',
#  'Understand the customer’s business need and guide them to a solution using Amazon ML and AI services',
#  'Assist customers by being able to deliver a ML/DL project from beginning to end, including understanding the business need, aggregating data, exploring data, building & validating predictive models, and deploying completed models to deliver business impact to the organization',
#  'Use Deep Learning frameworks like MXNet, Caffe 2, Tensorflow, Theano, CNTK, and Keras to help our customers build DL models',
#  'Use SparkML and Amazon Machine Learning (AML) to help our customers build ML models',
#  'Assist customers with identifying model drift and retraining models',
#  'Research and implement novel ML and DL approaches, including using FPGA',
#  "A Bachelor's or Master's Degree in a highly quantitative field (Computer Science, Machine Learning, Operational Research, Statistics, Mathematics, etc.) or equivalent experience",
#  'Previous experience in a ML or data scientist role and a track record of building ML or DL models',
#  'Experience using Python and/or R',
#  'Knowledge of SparkML',
#  'Able to write production level code, which is well-written and explainable',
#  'Experience using ML libraries',
#  'Experience working with GPUs to develop models',
#  'Experience handling terabyte size datasets',
#  'Track record of diving into data to discover hidden patterns',
#  'Familiarity with using data visualization tools',
#  'Knowledge and experience of writing and tuning SQL',
#  'Graduate degree (BS or M.S. required,) in a quantitative discipline',
#  '3 to 5 years professional experience building predictive and descriptive models',
#  'Good experience with statistical packages in Python, R, or SAS',
#  'Experience with Data Visualization using tools like Tableau',
#  'Experience in statistical and data mining techniques',
#  'Understanding of RDBMs and interactive SQL programming skills',
#  'Experience with Big Data technologies like Hadoop, Spark, Hive, NoSQL, etc., and Cloud technologies (AWS, Azure, etc) preferred',
#  'Good communication and presentation skills',
#  'Builds, maintains, and improves complex key decision systems and predictive models',
#  'Explores both internal and external new data sources and utilizes findings to further improve and optimize model performance',
#  'Designs, implements, and reads in-market experiments testing new algorithms, technologies, and processes',
#  'Recommends and supports strategic business changes through rigorous analytics, deep understanding of the business, and creative problem solving',
#  'Identifies, evaluates, and implements emerging advanced analytics technologies and methods',
#  'Uses data visualization techniques to effectively communicate analytical results and support business decisions',
#  'Master’s degree in a quantitative or technical field (Statistics, Mathematics, Economics, Engineering, Business Analytics, Data Science or a related field)',
#  'Experience with implementation of machine learning models using web services preferred',
#  'Possesses skills in data exploration and machine learning tools such as those found in R and/or Python',
#  'Microsoft Azure platform skills preferred',
#  'Demonstrated ability applying advanced statistical modeling techniques to solve problems',
#  'Intermediate skills with querying languages (SQL, etc.)',
#  'Demonstrates proficiency in several areas of data modeling, machine learning algorithms, statistical modeling & analysis, data engineering and data visualization',
#  'Effectively resolves problems and roadblocks as they occur',
#  'Ability to communicate and present highly complex concepts to all levels of management',
#  '\nData Scientist jobs in Kennesaw, GA\n',
#  "\nJobs at Aaron's in Kennesaw, GA\n",
#  '\nData Scientist salaries in Kennesaw, GA\n',
#  '\nAssociate Data Scientist jobs in Atlanta, GA\n',
#  '\nJobs at Inspire Brands in Atlanta, GA\n',
#  '\nAssociate Data Scientist salaries in Atlanta, GA\n',
#  'Apply advanced statistical techniques and concepts to analyze data from the company database (PostgreSQL), with Salesforce, and other unstructured data sources to drive optimization and improvement of product features, marketing messaging, and internal business processes',
#  'Develop custom data models/algorithms',
#  'Develop tools to analyze data accuracy and model performance',
#  'Leverage machine learning, natural language processing, and/or advanced statistical techniques',
#  'Coordinate across teams (product management, engineering, etc) timely and effectively',
#  'Possess a drive to learn and master new technologies and techniques',
#  'Contribute to the rapid growth of the research organization, being flexible in data engineering, algorithmist, and analyst responsibilities as they arise',
#  'Masters or PhD in CS, Mathematics, Statistics, or another quantitative field',
#  'Experience with machine learning, including natural language processing, probabilistic reasoning, and neural networks. Background in contemporary machine learning techniques, such as deep/differential learning, preferred.',
#  'Strong knowledge/experience with a variety of analysis tools, including Python, R, and SQL',
#  'Background in information retrieval, data mining, and ETL techniques for processing data',
#  'Experience working cross-organization to service the data analysis needs of different parts of the business',
#  '\nData Scientist jobs in Atlanta, GA\n',
#  '\nJobs at SalesLoft in Atlanta, GA\n',
#  '\nData Scientist salaries in Atlanta, GA\n',
#  'Proven statistical/mathematical and analytical skills; coursework in Machine Learning and statistics',
#  'Proficiency in R and/or Python',
#  'Knowledge of a general programming language like C++ or Java is a plus',
#  'Knowledge of one or more of the following: Gradient Boosting Machines, Random Forests, Neural Networks, or other classification or regression models',
#  'Excellent communication and interpersonal skills',
#  'Ability to work in a team environment as well as working independently',
#  'Pursuing a Master’s/PhD Degree\nPreferred Degree Paths: Data Science, Operations Research, Computer Science, Management Science and Statistics, and majors in a similar field of study\n',
#  'Preferred Degree Paths: Data Science, Operations Research, Computer Science, Management Science and Statistics, and majors in a similar field of study',
#  'Freshman (27 or fewer credits) - $2,500/month',
#  'Sophomore (28 to 59 credits) - $2,800/month',
#  'Junior (60 to 89 credits) - $3,000 /month',
#  'Senior (90 or more credits) - $3,300/month',
#  'Graduate Student - $3,666/month',
#  'Living stipend of $850/month is available to those who qualify.',
#  '\nJobs at Norfolk Southern in Atlanta, GA\n',
#  '\nAnalyzing, processing, evaluating and documenting large data sets',
#  '\nIdentifying/developing appropriate machine learning/data mining/text mining techniques to resolve entities and create relationships',
#  '\nPrototyping tools and techniques to solve complex data problems',
#  '\nDeveloping data driven models to quantify the value of a given data set',
#  '\nApplying, modifying and inventing algorithms to solve challenging business problems',
#  '\nValidating entity resolution and linking capabilities',
#  '\nConducting ROI and benefit analysis',
#  '\nDocumenting and presenting process and performance measurements',
#  "Bachelor's required, Master's preferred",
#  '\nAdvanced degree in Machine Learning, Computer Science, Electrical Engineering, Physics, Statistics, Applied Math or other quantitative fields',
#  '\nA minimum of 7+ years of working experience in analytics, data mining, data visualization, and/or predictive modeling',
#  '\nStrong business acumen',
#  '\nDemonstrated ability to lead and execute projects from start to finish',
#  '\nAbility to independently support existing products',
#  '\nProven track record in modifying and applying advanced algorithms to address practical problems',
#  '\nExperience with graph and probabilistic technology',
#  '\nProven ability to work independently on development of complex models with extremely large and complex data structures',
#  '\nProficient in more than one of SQL, Python, R, Java, C++, C, Elastic Search and Solr',
#  '\nRobust knowledge and experience with statistical methods and hypothesis testing',
#  '\nExperience with Hadoop and NoSQL related technologies such as Map Reduce, Spark, Hive, Pig, HBase, mongoDB, Cassandra, etc.',
#  '\nExperience with transforming large sets of structured, semi structured and unstructured data into useable information',
#  '\nData Scientist jobs in Atlanta, GA\n',
#  '\nJobs at Equifax in Atlanta, GA\n',
#  '\nData Scientist salaries in Atlanta, GA\n',
#  'Interact with partners, customer business and analytics teams to capture the business requirement',
#  'Extract data from a variety of relational databases, manipulate, explore data using quantitative, statistical and visualization tools.',
#  'Develop statistical approach for generating insights from structured and unstructured customer product data',
#  'Develop and deploy machine learning /statistical solutions for pricing recommendations and translate the analytics finding in form of easy to comprehend actionable insights',
#  'Determine machine learning methodologies; apply such methodologies (e.g. collaborative filtering, matrix factorization, SVMs, Bayesian methods, etc.) on product, pricing & location data etc.',
#  'Design and develop reports and dashboards to present the output of analytics modelling - Proactively recommend and execute strategies to grow the relevant services in existing account and target customers/industries',
#  'Play an advisory role to customers and prospects and provide thought leadership & execution direction',
#  'Have hands on experience on leading analytics solutions and tools like such as R(preferred), SAP Predictive Analytics, Python etc. to develop solutions and also explore new emerging machine learning and AI libraries like Tensor flow, Caffe2 etc.',
#  '\nData Scientist jobs in Atlanta, GA\n',
#  '\nJobs at Hiscox in Atlanta, GA\n',
#  '\nData Scientist salaries in Atlanta, GA\n',
#  '3+ years of experience using advanced analytical techniques to solve business problems or 2+ years of experience with a graduate degree in Computer Science, Mathematics, Management Science or relevant area or a PhD degree in Computer Science, Mathematics, Management Science or relevant area',
#  '\nAdvanced Excel skills with a focus on formula development and model building',
#  '\nAdvanced database query experience, either using SQL architecture or noSQL architecture',
#  '\nAdvanced R or Python programming skills for data manipulation and analysis',
#  '\nDemonstrated background in quantitative analysis, especially concepts related to statistical and/or machine learning analysis. Excellent working knowledge of time series based modeling techniques is essential',
#  '\nAbility to multi-task and communicate effectively across teams in a deadline-driven atmosphere',
#  '\nExperience with cloud-based computing, UNIX, and/or digital marketing is preferred but not required',
#  '\nNumerate degree in Computer Science, Mathematics, Management Science, or relevant area (graduate degree preferred)',
#  '\nSenior Data Scientist jobs in Atlanta, GA\n',
#  '\nSenior Data Scientist salaries in Atlanta, GA\n',
#  'Leverage Big Data to discover patterns and solve strategic and tactical business problems using massive structured and unstructured data sets across multiple environments.',
#  'Develop analytic capabilities (e.g. models and processes) that drive better outcomes for both customers and the company.',
#  'Drive the collection, cleansing, processing and analysis of new and existing data sources.',
#  'Research industry topics impacting opportunities relevant for data analysis projects.',
#  'Executes complex analyses to aid in reporting and interpretation of analytical findings to build a comprehensive solution.',
#  'Demonstrates good judgment and analytical skills to conduct option analysis and present recommendations',
#  'Support and resolve issues related to analyses or deliverables in production',
#  'Works with internal and external clients to understand, clarify, and analyze requirements to understand the business, and potential, impactful solutions',
#  'Mapping of processes to understand opportunities for advanced analytics and product enhancement',
#  'BA or BS degree in business analysis, computer science, economics, data science or Masters preferred.',
#  '5+ years of overall analytics experience\nPredictive Analytics\nStatistical modeling\nMachine Learning is a plus\n',
#  'Predictive Analytics',
#  'Statistical modeling',
#  'Machine Learning is a plus',
#  'Expert level understanding of analytics tools and languages (i.e. R, Python, or C++, etc.)',
#  'Experience in business analysis, requirements definition',
#  'Proven and recent experience working with Sales, Marketing, Supply Chain, and/or Manufacturing Data',
#  'Ability to navigate and access structured and unstructured data environments (ie. Hadoop, Oracle, SQL, etc.)',
#  'Experience utilizing internal and external data sources to identify otherwise hidden industry trends to impact product development.',
#  'Exposure to visualization tools such as Tableau / Qliksense',
#  'Must be solutions-oriented and focused on innovation',
#  'Familiarity with a scripting language: e.g. Perl, Python or a programming language: e.g. Java.',
#  'Self-motivated, highly organized with the ability to multitask and prioritize workload.',
#  'Natural curiosity and passion for problem solving',
#  'Consultative communication skillset; comfortable with working with senior management level personnel both inside and outside the organization',
#  '\nData Scientist jobs in Atlanta, GA\n',
#  '\nJobs at Interface in Atlanta, GA\n',
#  '\nData Scientist salaries in Atlanta, GA\n',
#  'Develop business requirements for a Supply Chain data repository to consolidate multiple ERP data sources into a comprehensive source for analytics',
#  'Partner with the IT organization on the development and implementation of algorithms required to extract and cleanse data into the Supply Chain data repository',
#  'Develop and implement diagnostic tools for use by business users to identify performance oppourtunities and root cause for action planning',
#  'Develop and implement optimization programs to improve planning outputs for manufacturing and distribution operations',
#  'MS in Statistics, Operations Research, or Engineering',
#  '5+ years experience developing and applying statistical and operations techniques within a business environment',
#  'Ability to communicate complex technical concepts to business partners in Supply Chain and Finance communiites.',
#  'Expert level SQL skills with demonstrated experience with large data sets.',
#  'Advanced experince with data visualization tools like Tableau, QlikView, Qlik Sense, etc., deploying BI tools at scale',
#  'Intermediate experience in open source programming languages (R/Python)',
#  'Strong written and verbal communication skills',
#  'Interpersonally savvy',
#  'Ability to work with and connect with all levels of employees',
#  'Strong planning & organizing skills',
#  'Initiative & follow-up, including a strong sense of autonomy',
#  'Strong Character – ability to champion the right decision in difficult situations',
#  'Demonstrated ability to handle multiple tasks and assignments simultaneously',
#  '\nBusiness Intelligence Data Scientist jobs in Atlanta, GA\n',
#  '\nJobs at Newell Brands in Atlanta, GA\n',
#  '\nBusiness Intelligence Data Scientist salaries in Atlanta, GA\n',
#  '\nData Scientist jobs in Atlanta, GA\n',
#  '\nJobs at HD Supply in Atlanta, GA\n',
#  '\nData Scientist salaries in Atlanta, GA\n',
#  'Design and implement AI powered models for medical diagnosis.',
#  'Combine medical imaging models into traditional big data analysis for healthcare.',
#  'Translate new technologies into product solutions for improved clinical care',
#  'Collaborate with clinicians and customers to address unmet clinical needs',
#  "Master's degree or above in Math/Statistics/Computer Science or related fields with working experience. Fresh Ph.D. graduates are welcomed to apply.",
#  'Candidates with solid background in image processing /computer vision or related areas are preferred.',
#  'Strong experience in deep learning and computer vision, including designing and',
#  'Knowledge of Linux programming in python, familiar with at least one of the popular deep learning frameworks, such as tensorflow, keras and caffe.',
#  'Experience of parallel programming, GPU programming, especially in CUDA, is a plus.',
#  'Experience of medical imaging processing with deep learning is preferred.',
#  'Good communication skill and strong team player.',
#  "Master's",
#  'Initiate and participate in data mining and reporting',
#  'Audit and profile the data to assess the impact of poor quality data on the organization’s performance and impacts.',
#  'Conduct A/B testing based on different hypotheses that directly and indirectly impact operational key performance indicators.',
#  'Create and support data visualization through operational and executive dashboards.',
#  'Import/Collect, clean, convert and analyze data for the purpose of find insights and making conclusions.',
#  'Design and develop relational databases for collecting data.',
#  'Monitor the performance of data systems and if there are any issues then respond to the same.',
#  'Keep a track of trends, patterns and correlation in case of complex data sets.',
#  'Prepare concise data reports and data visualizations for the management that will help in decision-making process.',
#  'Assist the data scientist in development of new analytical tools and methods as and when required.',
#  'Bachelor’s Degree',
#  'Two or more years as a data analyst in related field',
#  'Able to understand various data structures and common methods in data transformation',
#  'Experience in basic statistical modeling and reporting',
#  'Experience in SQL, relational databases, database concepts, dimensional modeling and database design',
#  'Proficient in one or more programming languages: R, Python, STATA, SAS',
#  'Experience with Caseworthy, SQL and Tableau',
#  'data analyst in related field: 2 years',
#  'basic statistical modeling and reporting: 2 years',
#  'Programming languages: R, Python, STATA, SAS: 2 years',
#  'SQL, relational databases, database concepts/design: 2 years',
#  'Caseworthy, SQL and Tableau: 1 year',
#  "Bachelor's",
#  'Atlanta, GA',
#  'Develop both descriptive and predictive models to help solve real-world industry problems',
#  'Using the results of analysis and modeling, the Data Scientist must effectively communicate impactful business recommendations on a regular basis',
#  'Apply machine learning and data mining techniques to identify growth opportunities',
#  'Build solutions for but not limited to: customer segmentation and targeting, propensity modeling, churn modeling, lifetime value estimation, forecasting, recommendation systems, modeling response to incentives, and price optimization',
#  'Identify and validate industry Key Performance Indicators (KPIs), metrics, and trends',
#  'Transform and manipulate data in preparation for analysis',
#  'Provide testing techniques and methodologies in order to assess the impact and effectiveness of business initiatives',
#  'Keep up-to-date on relevant tools and algorithms',
#  'Master’s degree in a field with significant quantitative training (e.g. applied statistics, mathematics, economics, finance, computer science, engineering)',
#  'Previous experience with retail CPG analytics is a plus',
#  'Fluency in R and/or Python',
#  '2+ years of experience in supervised and unsupervised machine learning methods including but not limited to clustering techniques (e.g. k-means, DBSCAN, spectral clustering), tree-based ensemble classifiers (random forests, gradient-boosted trees), support vector machines, and neural networks',
#  'Familiarity with: general linear modeling, simulation, feature engineering and selection, hyperparameter tuning, cross-validation, data smoothing methods, ARIMA models, Box-Jenkins methodology, multivariate time series analysis',
#  'Knowledge of SQL with the ability to independently write queries in order to extract necessary data',
#  'Organized and capable of independently managing complex analytical projects from start to finish',
#  'Ability to independently structure analyses and communicate findings to a non-technical audience',
#  'Experience with Excel VBA/macros, Tableau, and/or Alteryx is a plus',
#  '\nData Scientist jobs in Alpharetta, GA\n',
#  '\nJobs at Scientific Games in Alpharetta, GA\n',
#  '\nData Scientist salaries in Alpharetta, GA\n',
#  'Master’s degree in Computer Science, Engineering, or Applied Mathematics',
#  'PhD degree in Computer Science, Engineering, Applied Mathematics or related field',
#  '\nStrong Data Science prototyping experience (Python and/or R tool-stack)',
#  '\nMachine Learning experience of physical systems',
#  '\nExperience with distributed storage and compute tools (e.g. Hive and Spark)',
#  '\nExperience bringing prototypes to production on Hadoop platforms and/or as containerized services.',
#  '\nExperience with Streaming Analytics (i.e. Spark Streaming)',
#  '\nExperience with Recurrent Neural Network architectures',
#  '\nExperience with Natural Language Processing',
#  '\nExperience with Image Analytics',
#  '\nExperience with SQL',
#  '\nExperience with Tableau',
#  '\nExperience working with remote and global teams',
#  '\nResults driven with a positive can do attitude',
#  'Continued Professional Development',
#  'Job ID: HRD30620\n',
#  'Category: Engineering\n',
#  'Location: 715 Peachtree Street, N.E., Atlanta, GA 30308 USA\n',
#  '\nAdvanced Data Scientist jobs in Atlanta, GA\n',
#  '\nJobs at Honeywell in Atlanta, GA\n',
#  '\nAdvanced Data Scientist salaries in Atlanta, GA\n',
#  "Master's in Computer Science, Math or related quantitative field (or BS/BA in Computer Science, Math or related quantitative field and 5 years of data mining experience).",
#  'Work experience with Hadoop, SAS, HBASE, Cassandra or other similar development platforms.',
#  'Expert knowledge in large-scale information retrieval and statistical analysis.',
#  'Ability to build scalable systems that analyze huge data sets and make actionable recommendations',
#  'Strong communication and data presentation skills',
#  'Ability to quickly adapt to new technologies, tools, and techniques',
#  'Flexible and responsive; able to perform in a fast-paced, dynamic work environment and meet aggressive deadlines',
#  'Ability to work with technical and non-technical team members',
#  '\nData Scientist jobs in Atlanta, GA\n',
#  '\nJobs at The Home Depot in Atlanta, GA\n',
#  '\nData Scientist salaries in Atlanta, GA\n',
#  '\nIndependently lead data science projects and deliver innovative technical solutions to solve problems and improve business outcomes.',
#  '\nLead the design and development of machine learning/statistical models and ensure best performance.',
#  '\nWork closely with engineers to deploy models in production both in real time and in batch process and systematically track model performance.',
#  '\nAssist engagement with key business stakeholders in discussion on business strategies and opportunities.',
#  '\nBuild strong working relationship and develop deep partnership with the business.',
#  '\nBe a subject matter expert on machine learning and predictive modeling.',
#  '\nDrive technical innovation through active research and applications of new theories, techniques, and technologies.',
#  '\nBachelor’s degree or four or more years of work experience.',
#  '\nFour or more years of relevant work experience.',
#  '\nMaster’s degree in a quantitative field or equivalent.',
#  '\nA Ph.D. in statistics, Math, Economics, Engineering, Computer Science, Business Analytics, Data Science or a related field.',
#  '\n5+ years of experience in practicing machine learning and data science in business.',
#  '\nSolid foundational quantitative knowledge and skills; extensive training in math, statistics, physical science, engineering, or other related fields.',
#  '\nExperience in leading data science projects and delivering from end to end.',
#  '\nStrong technical expertise in machine learning and statistical modeling.',
#  '\nStrong hands on computing/programming skills; proficiency in Python, R, and Linux shell script.',
#  '\nExpertise in data management and data analysis in relational database and in Hadoop.',
#  '\nStrong communication and interpersonal influencing skills.',
#  '\nExcellent problem solving and critical thinking capabilities.',
#  '\nExperience with NLP and chatbot technology.',
#  '\nExperience with Spark, C++, scala, or Java is preferred; familiarity with SAS.',
#  '\nStrong expertise in SQL and database management.',
#  '\nData Scientist jobs in Alpharetta, GA\n',
#  '\nJobs at Verizon in Alpharetta, GA\n',
#  '\nData Scientist salaries in Alpharetta, GA\n',
#  '\nContribute to creation of roadmaps for data science domain ensuring alignment to Travelport Technology and Business Strategies and drive deployment of the best data science solutions to enable delivery of operational goals for system efficiencies, cost optimization and customer availability.',
#  '\nLeads efforts in artificial intelligence to achieve high quality deliverables that exceed customer expectations.',
#  '\nContribute to thought leadership and drive the execution of diverse data science projects through proactive collaboration with the data science community within Travelport.',
#  '\nAccountability for follow through on design and delivery of assigned aspects of roadmaps.',
#  '\nHave the ability to discover new opportunities where advanced analytical techniques can be leveraged for solving business problems.',
#  '\nUses business acumen to understand what drives the organization, which factors influence strategy, and how the data can contribute to measuring the success of our strategic initiatives.',
#  '\nProvides business metrics for the overall project to show improvements (contribution to the improvement should be monitored initially and over multiple iterations).',
#  '\nLeads the evaluation of data technologies.',
#  '\nLeads the development of proofs of concept.',
#  '\nDelivers complex statistical and machine learning/predictive models from both internal and external data to provide solutions, insights, and new opportunities for business and product.',
#  '\nProactively identify improvement opportunities through systematic and rigorous measurement and analysis.',
#  '\nPerforms tests based on different hypotheses to directly and indirectly impact different Key Performance Indicators.',
#  '\nCommunicate analytical results in a way that is meaningful for business stakeholders and provides actionable insights.',
#  '\nConverses with and creates/delivers presentations to internal business leaders and as well as external groups.',
#  '\nDevelops usage and access control policies and systems in collaboration with COE Architecture, data governance and data & analytics resources and partner in continuous improvement processes impacting data quality in the context of the specific use case.',
#  '\nRemain a subject matter expert in emerging data science practices and technologies and share emerging best practice and innovation with Travelport data science community.',
#  "\nBachelor's degree in a quantitative field required; Advanced degree preferred [Masters preferred]",
#  '\n10+ years experience in Statistics and Quantitative Analysis. Highly advanced domain expertise and experience working across a diverse group of products/applications and related systems identifying key inter-dependencies',
#  '\nGood knowledge of Microsoft Office (Word, Excel PowerPoint) Visio as applicable.',
#  '\nPractical comprehensive knowledge of using Microsoft Project / PPM as a planning tool and working in a Project Server Environment',
#  '\nTechnical skills dependent on role and will range as below;',
#  '\nAdvanced knowledge of DBMS query languages',
#  '\nExpert knowledge of at least one programming language (R, Python, Java, Weka, NumPy)\n',
#  'Working knowledge of additional languages expected.',
#  '\nExpert knowledge of statistical software packages (R, SAS, SPSS)',
#  '\nAdvanced knowledge of big data technologies such as Spark or Hadoop',
#  '\nAdvanced knowledge of data visualization tools such as GGplot, Qlikview, etc.',
#  '\nIntermediate knowledge of machine learning and deep learning framework',
#  '\nMasters Degree in Statistics or related field; prefer a PHD',
#  '\nProficiency in using query languages such as SQL, Hive, or Pig',
#  '\nExperience with NoSQL databases, such as Elastic Search, MongoDB, CouchDB, Cassandra, or HBase',
#  '\nGreat applied statistics skills, such as distributions, statistical testing, or regression',
#  '\nGood scripting and programming skills in Python, Perl, Java, C++, or Scala',
#  '\nRelevant experience in Big Data platforms like Hadoop and its eco-system',
#  '\nSenior Data Scientist jobs in Atlanta, GA\n',
#  '\nJobs at Travelport in Atlanta, GA\n',
#  '\nSenior Data Scientist salaries in Atlanta, GA\n',
#  'Quickly understand client needs, develop solutions, and articulate findings to client executives.',
#  'Provide data-driven recommendations to clients by clearly articulating complex technical concepts through generation and delivery of presentations.',
#  'Analyze and model both structured and unstructured data from a number of distributed client and publicly available sources.',
#  'Perform EDA and feature engineering to both inform the development of statistical models and generate improve model performance and flexibility.',
#  'Design and build scalable machine learning models to meet the needs of given client engagement.',
#  '0-2 year(s) professional work experience as a data scientist or on advanced analytics / statistics projects.',
#  'Master’s degree from top tier college/university in Computer Science, Statistics, Economics, Physics, Engineering, Mathematics, or other closely related field.\n',
#  'PhD preferred.',
#  'Strong understanding and application of statistical methods and skills: distributions, experimental design, variance analysis, A/B testing, and regression.',
#  'Statistical emphasis on data mining techniques, Bayesian Networks Inference, CHAID, CART, association rule, linear and non-linear regression, hierarchical mixed models/multi-level modeling, and ability to answer questions about underlying algorithms and processes.',
#  'Experience with both Bayesian and frequentist methodologies.',
#  'Mastery of statistical software, scripting languages, and packages (e.g. R, Matlab, SAS, Python, Pearl, Scikit-learn, Caffe, SAP Predictive Analytics, KXEN, ect.).',
# ...
#  '\nBasic understanding of statistical and data mining concepts and procedures including: regression, machine learning algorithms, and experimental design',
#  '\nAbility to quickly absorb and synthesize business strategies & processes',
#  '\nAn opportunity to work with a great team that is passionate about the same thing you are!',
#  '\nNetworking opportunities to meet people that you’d like to know!',
#  '\nA speaker series that introduces you to cool executives and what they do for the best brands!',
#  '\nTech Fall Intern jobs in Atlanta, GA\n',
#  '\nJobs at Turner in Atlanta, GA\n',
#  '\nTech Fall Intern salaries in Atlanta, GA\n',
#  '\nUnder minimal supervision, the Assistant Scientist, Bioinformatics performs a wide range of highly technical and complex bioinformatics procedures.',
#  '\nQualification for this position requires demonstrated expertise in designing and developing software, databases, and interfaces for analyzing and manipulating research data applications including expertise with simple programming using Perl/Python or Java, statistical programming, web-development, and database query through SQL.',
#  '\nThis role collaborates with researchers to develop high throughput data processing and analysis capability.',
#  '\nDirects and guides database searches and the computational analysis of resulting data.',
#  '\nProvides direct technical support and helps guide, implement, and maintain further improvements to bioinformatics software, databases, and interfaces and works with the entire bioinformatics team to diagnose and fix related issues.',
#  '\nMay assist in grant and other funding applications, as necessary and appropriate.',
#  '\nDemonstrated ability to function as part of a team.',
#  '\nPerforms other responsibilities as required.',
#  '\nPhD in bioinformatics, computer science, biological or physical science and three years of experience.',
#  '\nExperience prior to achieving the PhD will be considered.',
#  '\nScientist jobs in Atlanta, GA\n',
#  '\nJobs at Emory University in Atlanta, GA\n',
#  '\nScientist salaries in Atlanta, GA\n',
#  'Qualifications: 6-12 years experience, Bachelor’s Degree.',
#  'Must have experience in Software Engineering Techniques, Software Engineering Architecture, Software Engineering Lifecycle and Data Management.',
#  'Should be proficient in Business Analysis, Business Knowledge, Software Engineering Leadership, Architecture Knowledge and Technical Solution Design.',
#  '\nManager jobs in Atlanta, GA\n',
#  '\nJobs at Capgemini in Atlanta, GA\n',
#  '\nManager salaries in Atlanta, GA\n',
#  "A Bachelor's degree in Imaging Science, Electrical and Computer Engineering, Aerospace Engineering, Computer Science, Physics, Mathematics, Geomatics, Civil Engineering.",
#  'A Master’s degree in Imaging Science, Electrical and Computer Engineering, Aerospace Engineering, Computer Science, Physics, Mathematics, Geomatics, Civil Engineering and three (3) years of relevant full-time experience after completion of that degree,',
#  'A Doctoral degree in Imaging Science, Electrical and Computer Engineering, Aerospace Engineering, Computer Science, Physics, Mathematics, Geomatics, Civil Engineering.',
#  '0-7 years of professional or graduate experience',
#  'Satellite/Overhead imagery',
#  'Geomatics/Geospatial Intelligence',
#  'Machine learning, pattern recognition, and clustering',
#  'Sensor data fusion',
#  'EO/IR imaging systems',
#  'Radiometric analysis',
#  'Fourier optics',
#  'Electro-optical/Image signal processing',
#  'Point cloud processing',
#  'Lidar (i.e., topographic, bathymetric, atmospheric)',
#  'Hyperspectral imaging (HSI)',
#  'Analytic geometry and advanced statistics',
#  'Laboratory equipment such as oscilloscopes, spectrum analyzers, and/or data acquisition hardware/software',
#  'Computational tools such as Matlab, Octave, and/or IDL',
#  'Programming languages such as Python and/or C++',
#  'Toolboxes such as CUDA, OpenGL, and Open CV',
#  'ArcGIS',
#  '\nImaging Scientist Engineer Junior jobs in Atlanta, GA\n',
#  '\nJobs at Georgia Tech Research Institute in Atlanta, GA\n',
#  '\nImaging Scientist Engineer Junior salaries in Atlanta, GA\n',
#  "A Bachelor's degree in Aerospace, Computer, Electrical, or Mechanical Engineering, Computer Science, Physics, or Mathematics.",
#  'A Master’s degree in Aerospace, Computer, Electrical, or Mechanical Engineering, Computer Science, Physics, or Mathematics and three (3) years of relevant full-time experience after completion of that degree,',
#  'A Doctoral degree in Aerospace, Computer, Electrical, or Mechanical Engineering, Computer Science, Physics, or Mathematics.',
#  '\nSystem Engineer jobs in Atlanta, GA\n',
#  '\nJobs at Georgia Tech Research Institute in Atlanta, GA\n',
#  '\nSystem Engineer salaries in Atlanta, GA\n',
#  'Develop and update test plans, procedures and report documentation.',
#  'Execute developed test procedures and document results in a formal setting.',
#  'Technically coordinate with a cross-functional team to develop test solutions for our DoD sponsor ensuring all products meet allocated requirements and design through formal testing.',
#  'Maintain and create test scripts, files and data that support formal testing.',
#  'Work in an integrated product team and understand system and unit level requirements in order to create test plans and procedures.',
#  'Utilize existing system specifications, interface definitions, and aircraft avionics in the development of test procedures.',
#  'Ensure that all technical work is performed and documented to appropriate professional standards.',
#  'Develop test estimates for proposed work and status current tasking.',
#  "A Bachelor's degree in Computer Science, Electrical Engineering, Systems Engineering or related field of study.",
#  'Experience in test engineering processes and methodologies applicable to complex military systems development.',
#  'Manual, ad hoc, black and white box testing.',
#  'Strong collaboration, organization, teaming and communication abilities.',
#  'Ability to work well individually or in a group setting.',
#  'Ability to work under pressure and time constraints.',
#  'Ability to create and deliver technical presentations effectively.',
#  'Python or similar scripting language.',
#  'Experience with MIL-STD-1553 data bus, avionics systems, Electronic Warfare systems, tactical data links, military radios, and open systems architectures.',
#  'Experience with system security and safety engineering.',
#  'Experience with configuration management and requirements management systems.',
#  'Experience directing small teams of employees as a task leader',
#  '\nTest Engineer jobs in Atlanta, GA\n',
#  '\nJobs at Georgia Tech Research Institute in Atlanta, GA\n',
#  '\nTest Engineer salaries in Atlanta, GA\n',
#  "Develop system level requirements from sponsor's high level requirements, decompose and allocate the requirements into a system design describing the architecture structure, and allocate the behavior and data interfaces and map to hardware and software components.",
#  'Technically coordinate a cross-functional team to develop technical solutions for our DoD sponsors ensuring all products meet allocated requirements and design.',
#  'Serve as the technical expert on assigned projects and systems including use models, associated products’ capabilities, system interfaces, engineering tools, and the roadmap for current and future updates. The candidate will utilize this expertise to advise the sponsors and promote the sponsor’s position in meetings.',
#  'Manage the product backlog and system deficiency reports.',
#  'Utilize existing system specifications, interface definitions, and aircraft drawings in the development of solutions.',
#  'Ensure that all technical work is performed and documented to appropriate professional standards.',
#  'Design and manage the laboratory configuration for assigned projects.',
#  'Integrate system products in laboratory and fielded settings. Analyze flight and laboratory data to determine if system requirements and project objectives are met; and isolate anomalies to hardware and software components.',
#  'Develop quantitative feasibility analyses on possible solutions toward increasing system effectiveness and ability to integrate new technologies.',
#  "A Bachelor's degree in Computer Science, Electrical Engineering, Systems Engineering or related field of study.",
#  'Experience in system engineering processes and methodologies applicable to complex military systems development.',
#  'Strong collaboration, organization, teaming and communication abilities.',
#  'Ability to work well individually or in a group setting.',
#  'Ability to work under pressure and time constraints.',
#  'Ability to create and deliver technical presentations effectively.',
#  'Experience at companies performing in defense or avionics sector',
#  'Experience processing and analyzing data with tools such as Python or R.',
#  'Experience with MIL-STD-1553 data bus, avionics systems, Electronic Warfare systems, Tactical Data Links (Link-16, TTNT), military radios, and open systems architectures.',
#  'Experience designing systems using SysML.',
#  'Experience with system security and safety engineering.',
#  'Experience with configuration management and requirements management systems.',
#  'Experience directing small teams of employees as a task leader.',
#  'Experience developing avionics systems on military transport (e.g. C-130), fighter planes (F-16, F-22, F-35), and helicopters (H-60)',
#  '\nSystem Engineer jobs in Atlanta, GA\n',
#  '\nJobs at Georgia Tech Research Institute in Atlanta, GA\n',
#  '\nSystem Engineer salaries in Atlanta, GA\n',
#  'Define, develop and prototype cognitive solutions such as Machine Learning, Natural Language Processing (NLP), Linguistics, Information Retrieval, Image Recognition, Deep Learning\n',
#  'Serve as Subject Matter Expert (SME) in the domain of Machine Learning and NLP and help establish a competency in those cognitive areas\n',
#  'Work closely with functional teams to incorporate cognitive and advanced analytics models and algorithms into product, solutions and offerings\n',
#  'Possibility to work in client engagements as Machine Learning SME\n',
#  'Will serve as Thought Leader in Machine Learning and NLP, developing internal and external eminence and intellectual property, as well as support client facing activities and influencing customer facing groups including senior executives, sales, as well as marketing and product development to successfully define, develop and launch new products and solutions\n',
#  'Model and algorithm development and optimization, working with software engineers to implement and productize the models and algorithms, engage in project specific activities as part of product development, as well as perform Machine Learning R&D work, develop tools and assets to support advanced Machine Learning development tasks\n',
#  'Bachelor’s degree.',
#  'Minimum of eight years’ experience of professional post academic work or 5 years’ experience with a Ph.D. or MS in Computer Science, Applied Statistics, Engineering, Mathematics, Physics or other quantitative discipline with specialization',
#  'Experience in Artificial Intelligence, Machine Learning, Natural Language Processing, Cognitive Science or other related areas',
#  'Strong mathematical background with strong knowledge in at least one of the following fields: Machine Learning, Deep Learning, Information Retrieval, Image Recognition',
#  'Experience with languages such as: Python, R, SQL, and Java',
#  'Experience with frameworks and libraries such as: Pytorch, Keras, TensorFlow, scikit-learn, xgboost, pandas, Spark, matplotlib, D3, pytest, flask, Docker etc.',
#  'Experience with Google and Amazon Machine Learning and Cloud tools',
#  'Experience working with both relational and NoSQL databases',
#  'Gathering data from both large information systems\n',
#  'Ability to travel 20% of the time\n',
#  'Preferred Graduate degree (Masters or PhD) in Computer Science, Applied Statistics, Engineering, Mathematics, Physics or other quantitative discipline.\n',
#  'Experience leading teams both on and offshore',
#  'Experience leading project teams and people as well as executing independently',
#  'Excellent verbal and written communication skills with the ability to work with diverse teams',
#  '\nMachine Learning Lead jobs in Atlanta, GA\n',
#  '\nJobs at Deloitte in Atlanta, GA\n',
#  '\nMachine Learning Lead salaries in Atlanta, GA\n',
#  'No commercial experience is necessary, but one or two years’ experience in a technical environment would be an advantage. We are looking for people with the following:',
#  'Experience with Linux, source control, SQL, and one or more programming languages (Java and python preferred) is a strong advantage but not an absolute prerequisite.',
#  'Good degree from a top tier university in a scientific or numerate discipline, e.g. Computer Science, Physics, Mathematics, Engineering',
#  'In-depth familiarity with computers and technology',
#  'Passion to learn new technical skills.',
#  'Ability to handle multiple concurrent projects and prioritize appropriately',
#  'Flexibility and adaptability.',
#  'Ability to communicate well with customers, adapting fluidly to different audiences – ranging from highly technical to non-technical business owners.',
#  'Must enjoy working in a team of like-minded and intelligent people to solve complex problems.',
#  'A focus on personal achievement and responsibilities.',
#  'An indication of passion to learn new skills and technologies.',
#  'Attention to grammatical detail, layout and presentation.',
#  'Enthusiasm.',
#  'And most importantly, a small company attitude: willingness to adapt to a variable role and a great can-do attitude.',
#  'Annual bonus',
#  '20 days PTO annually',
#  'Healthcare package',
#  'Pension plan',
#  'Free Friday lunches',
#  'Regular social outings',
#  'Fridge and cupboards packed full of edible treats',
#  'Annual summer social and Christmas dinner',
#  '\nImplementation Engineer jobs in Atlanta, GA\n',
#  '\nJobs at eHire in Atlanta, GA\n',
#  '\nImplementation Engineer salaries in Atlanta, GA\n',
#  "A Bachelor's degree in electrical engineer, computer science, physics, computer engineering, or related disciplines.",
#  'A Master’s degree in electrical engineer, computer science, physics, computer engineering, or related disciplines and three (3) years of relevant full-time experience after completion of that degree,',
#  'A Doctoral degree n electrical engineer, computer science, physics, computer engineering, or related disciplines.',
#  '0-6 years of relevant work experience',
#  ' Knowledge and familiarity with signal processing',
#  ' Write software to model various EW systems',
#  ' Familiarity with FORTRAN, C, and C++',
#  ' Assist in the design, development, and demonstration of EW simulation experiments',
#  ' Develop and integrate scripts to allow researchers to gather and analyze critical data from the simulation runs',
#  ' Familiarity with Linux and open source tools',
#  ' Document analysis and maintain configuration management of all software and experiments',
#  ' Travel may be involved, as project work may occur in Atlanta or at a location other than Atlanta',
#  'Experience with Python computer language',
#  ' Strong math skills and ability to learn complex engineering concepts',
#  ' Configuration management tools',
#  ' Ability to clearly communicate technical ideas to non-technical audience',
#  ' Ability to work independently as well as in a dynamic team environment',
#  '\nSignal Modeling jobs in Atlanta, GA\n',
#  '\nJobs at Georgia Tech Research Institute in Atlanta, GA\n',
#  '\nSignal Modeling salaries in Atlanta, GA\n',
#  "A Bachelor's degree in electrical engineering, computer science, physics, computer engineering, or related disciplines.",
#  'A Master’s degree in electrical engineering, computer science, physics, computer engineering, or related disciplines and three (3) years of relevant full-time experience after completion of that degree,',
#  ...]

# %%
list_of_para
# Out:
# ['Truck IT, LLC ("Truck IT"), (Headquartered in Midtown Atlanta @ the new and upscale We Work building), is focused on revolutionizing construction transportation for both customers (e.g., contractors, quarries) and haulers through our proprietary mobile and web applications. We’ve been recognized as one of BuiltWorlds "45 companies & technologies paving our future in IoT and connected jobsites"... coming in at #15 and the only company based in Atlanta. Our goal is to become the next $1 billion Tech Services company and we need to add a Data Scientist to move closer to that goal.',
#  'Data is the driver for our future at Truck IT. We’re searching for highly collaborative, analytical, and innovative engineers to build and scale our big data and ML platform. If you are passionate about using data to solve problems and build game changing products, we’d love to work with you.',
#  'ROLE',
#  'Working within a dynamic and fast paced team environment, the Senior Engineer is responsible for the design, construction, and maintenance of mission-critical, highly visible big data and machine learning applications in direct support of Truck IT business objectives. Furthermore, this person is responsible for working with other engineers to develop the technical design by fully understanding the technical details, integration, and functions of multiple applications across their development team. The ideal candidate should have good mentoring and cross-functional skills.',
#  'ABOUT THE TEAM',
#  'The Big Data and Machine Learning team is responsible for building big data pipelines and deriving insights out of the data using advanced analytic techniques, streaming and machine learning at scale.',
#  'WHAT’S IN IT FOR YOU',
#  'FOCUS',
#  'Required Qualifications',
#  'Preferred Qualifications',
#  'Job Type: Full-time',
#  'Location:',
#  'Required work authorization:',
#  'Apply Now',
#  '\n            Please review all application instructions before applying to TruckIT.',
#  '\n(function(){var a=window.indeed;\n            if(!a||!a.ia){\n            var b=window,\n                c=document.location,\n                e=document.getElementsByTagName("head")[0],\n                f=/^https:\\/\\//.test(c.href),\n                g=document.createElement("script"),\n                h=document.getElementById("indeed-apply-js").attributes["data-indeed-apply-qs"],\n                n=h&&h.value?h.value:"";\n            b.indeed=b.indeed||{};b.indeed.ia=b.indeed.ia||{};\n            g.src=(f?\n        "https://apply.indeed.com/indeedapply/env?https=1&iip=1&":"https://apply.indeed.com/indeedapply/env?iip=1&")+"ms="+ +new Date+(n?"&"+n:"");e.appendChild(g)};})();',
#  'Job Number: 18230\n',
#  'Position Title:\n',
#  'External Description:\n',
#  'City: Atlanta\n',
#  'Location_formattedLocationLong: Atlanta, Georgia US\n',
#  'State: Georgia\n',
#  'Community / Marketing Title: Data Scientist\n',
#  'Company Profile:\n',
#  'Requisition Number: J00067915\n',
#  'EEO Employer Verbiage: <p>Equifax is an Equal Employment Opportunity employer and all qualified applicants will receive consideration for employment without regard to race, color, religion, sex, sexual orientation, gender identity, national origin, protected veteran status, or disability status.</p>',
#  'DEPARTMENT: HOPE Research Institute',
#  'POSITION LOCATIONS: Atlanta, GA.',
#  'ACCOUNTABILITY:  Senior VP, HOPE Research Institute',
#  'For 25 years Operation HOPE has been dedicated to empowering underserved communities through financial literacy, now our work encompasses more than financial education. Our work is about instilling knowledge and confidence in those we serve so they can experience, sometimes for the first time in their lives, financial dignity.',
#  'JOB SUMMARY',
#  'Operation HOPE is currently in need of a Data Scientist to join our fast-growing team. The ideal candidate will use his/her analytical, statistical and programming skills to collect, analyze and interpret Operation HOPEâ€™s data sets to help drive improved product performance, increase customer satisfaction and reduce cost of operation. The data scientist will be intricately involved in analyzing programmatic data to inform operational practices, conducting analytical experiments in a methodical manner, and will regularly evaluate alternate models via theoretical approaches.',
#  'The Data Scientist is responsible to help understand operational needs, working with the field supervisors, head of quality and other department leaders as required. Using that knowledge, this position will drive a data-driven solution to solving broad and complex inefficiencies. Additionally, the Data Scientist may be called on to help cross-functional efforts to model large data sets and will work with other technical departments to enhance process control both internally and externally. This is the perfect opportunity for the successful candidate to become a part of an innovative non-profit team that develops analysis tools that will change the world and uplift underserved communities.',
#  'DUTIES AND RESPONSIBILITIES',
#  'REQUIRED SKILLS AND EDUCATION',
#  'EEOSTATEMENT',
#  'Operation HOPE is an Equal Opportunity Employer, all qualified applicants will receive consideration for employment without regard to race, color, religion, sex, age, national origin, protected veteran status, disability status, sexual orientation, gender identity or expression, marital status, genetic information or any other characteristic protected by law.',
#  'Job Type: Full-time',
#  'Experience:',
#  'Education:',
#  'Location:',
#  'Required work authorization:',
#  'Apply Now',
#  '\n            Please review all application instructions before applying to Operation HOPE.',
#  '\n(function(){var a=window.indeed;\n            if(!a||!a.ia){\n            var b=window,\n                c=document.location,\n                e=document.getElementsByTagName("head")[0],\n                f=/^https:\\/\\//.test(c.href),\n                g=document.createElement("script"),\n                h=document.getElementById("indeed-apply-js").attributes["data-indeed-apply-qs"],\n                n=h&&h.value?h.value:"";\n            b.indeed=b.indeed||{};b.indeed.ia=b.indeed.ia||{};\n            g.src=(f?\n        "https://apply.indeed.com/indeedapply/env?https=1&iip=1&":"https://apply.indeed.com/indeedapply/env?iip=1&")+"ms="+ +new Date+(n?"&"+n:"");e.appendChild(g)};})();',
#  'Join a team recognized for leadership, innovation and diversity',
#  'Honeywell is an equal opportunity employer. Qualified applicants will be considered without regard to age, race, creed, color, national origin, ancestry, marital status, affectional or sexual orientation, gender identity or expression, disability, nationality, sex, or veteran status.',
#  '\nINDSOFTWARE',
#  'We know salary is a key component of your decision whether or not to apply for a job. So when the hiring company hasn’t provided a salary for a job, we look at salary data from related companies and locations to come up with a reasonable estimate for what you can expect.',
#  'With over 450,000,000 salaries collected from other jobs and employees, we use one of the biggest salary databases in the world to inform these estimates. And because we are continually adding feedback from users like you, we are able to keep refining our accuracy.',
#  'These salary estimates are not endorsed by the hiring companies and may vary from what’s actually offered, but we have a pretty great record of getting close enough for you to make an informed decision.',
#  'Is this your job listing? Send us feedback to correct an inaccurate salary estimate.',
#  'Cotiviti is looking for an industry leading Data Scientist to join a revolution in Healthcare and build a first-in-market analytics capability. This is a pioneering data scientist who will participate in expanding the new analytics backbone of the company. Cotiviti’s first-in-market analytics capability is powered by social networking technology and enables a more efficient experience for both healthcare providers and customers. As a Data Scientist at Cotiviti you will be given the opportunity to work directly with a team of healthcare professionals including analysts, clinicians, coding specialists, auditors and innovators to set aggressive goals and execute on them with the team. This is for an ambitious technologist with the guts, flexibility, and personal drive to succeed in a dynamic environment.',
#  '\nWho You Are',
#  'What You Will be Doing\n',
#  'You will build innovative tools to provide our clients with insights on how to improve their business. You will have responsibility for architecting and developing best-in-class analytics that create quantifiable value for our business. You will have responsibility for establishing and sustaining processes and practices that support big data and analytics solutions and applications in an open source environment. You should have a passion for creating solutions and driving innovation with an interest in collaborating with team members. This role demands time spent working independently and as part of a team. You will also focus on specific deadlines defined by the management team.',
#  'Requirements:',
#  'Preferred Qualifications:',
#  '\nAbout Cox Automotive',
#  '\nCox Automotive is transforming the way the world buys, sells and owns cars with industry-leading digital marketing, retail, financial and wholesale solutions for consumers, dealers, manufacturers and the overall automotive ecosystem worldwide. The Cox Automotive family includes Autotrader®, Dealer.com®, Dealertrack®, Kelley Blue Book®, Manheim®, NextGear Capital®, vAuto®, VinSolutions®, Xtime®, incadea®, and a host of other brands. With a complete and connected view of the automotive ecosystem, Cox Automotive is a global company connecting people, cars and capabilities with services that link the automotive value chain. Cox Automotive is a subsidiary of Cox Enterprises. For more information about Cox Automotive, visit www.coxautoinc.com.',
#  '\nCox is an Equal Employment Opportunity employer - All qualified applicants/employees will receive consideration for employment without regard to that individual’s age, race, color, religion or creed, national origin or ancestry, sex (including pregnancy), sexual orientation, gender, gender identity, physical or mental disability, veteran status, genetic information, ethnicity, citizenship, or any other characteristic protected by law.',
#  'Data Scientist',
#  'Want to work in a casual, fun startup environment? AnswerRocket has been fundamentally changing the way organizations use data to make decisions every day. Our software uses natural language data discovery and machine learning algorithms to enable business leaders to make better, faster decisions. We are seeking a Data Scientist who will serve as part of our technical team in developing analytics solutions to solve customer business problems and improve processes.',
#  'Responsibilities: ',
#  'Requirements: ',
#  'Extra Awesome',
#  'What We Offer',
#  'About AnswerRocket',
#  'Founded by successful technology entrepreneurs in 2013, our offices are located in metro Atlanta and include a fun work environment with the dynamic vibe for growth. Customers love what we are doing, and Gartner has recently named us a Cool Vendor in analytics. Our team consists of smart and creative people who are motivated by clear goals to deliver “a ha” moments to our customers. We are breaking away from tired, traditional software and are committed to delivering high quality, well-engineered solutions that fit into modern enterprises. AnswerRocket offers the opportunity to grow immensely, both personally and professionally, as we leverage the latest technology to change how companies use big data.',
#  'All qualified applicants will receive consideration for employment without regard to race, color, religion, sex, sexual orientation, gender identity, national origin, age, disability, protected veteran status, or any other legally protected basis, in accordance with applicable law. We are an Equal Opportunity Employer.',
#  'Job Type: Full-time',
#  'Experience:',
#  'Education:',
#  'Location:',
#  'Required work authorization:',
#  'Apply Now',
#  '\n            Please review all application instructions before applying to AnswerRocket.',
#  '\n(function(){var a=window.indeed;\n            if(!a||!a.ia){\n            var b=window,\n                c=document.location,\n                e=document.getElementsByTagName("head")[0],\n                f=/^https:\\/\\//.test(c.href),\n                g=document.createElement("script"),\n                h=document.getElementById("indeed-apply-js").attributes["data-indeed-apply-qs"],\n                n=h&&h.value?h.value:"";\n            b.indeed=b.indeed||{};b.indeed.ia=b.indeed.ia||{};\n            g.src=(f?\n        "https://apply.indeed.com/indeedapply/env?https=1&iip=1&":"https://apply.indeed.com/indeedapply/env?iip=1&")+"ms="+ +new Date+(n?"&"+n:"");e.appendChild(g)};})();',
#  'We know salary is a key component of your decision whether or not to apply for a job. So when the hiring company hasn’t provided a salary for a job, we look at salary data from related companies and locations to come up with a reasonable estimate for what you can expect.',
#  'With over 450,000,000 salaries collected from other jobs and employees, we use one of the biggest salary databases in the world to inform these estimates. And because we are continually adding feedback from users like you, we are able to keep refining our accuracy.',
#  'These salary estimates are not endorsed by the hiring companies and may vary from what’s actually offered, but we have a pretty great record of getting close enough for you to make an informed decision.',
#  'Is this your job listing? Send us feedback to correct an inaccurate salary estimate.',
#  'Indeed has encountered a temporary error and could not complete your request.  Rest assured that right now, emails are being sent and pagers being alerted to the situation.',
#  'If you need assistance you can contact us or visit our home page',
#  'Join a growing Data Science and Advanced Analytics team at Norfolk Southern Corporation. The team is using latest cutting edge tools and technologies to develop analytics and solutions to solve business problems from various fields such as engineering, mechanical, communications, marketing & finance.',
#  'Principal Duties:',
#  'Job Related Experience:',
#  'Minimum Level: 1 year; preferred Level: 2+ years of relevant experience (e.g. analysist, statistician, data scientist, team lead) or proven qualifications',
#  'Education:',
#  'Preferred Level: Ph.D. and M.S',
#  'Preferred Majors: Computer and Information Sciences, Electrical Engineering, Engineering – Statistics, Engineering - Operations Research, Engineering - Systems Engineering, Mathematical Sciences - Applied Mathematics, Physics',
#  'Licenses / Certifications: Required: None listed, Preferred: None listed',
#  'Technical Skills:',
#  'Skills and Abilities:',
#  'Work Conditions\n',
#  'Norfolk Southern Corporation (NYSE: NSC) is one of the nation’s premier transportation companies. Its Norfolk Southern Railway Company subsidiary operates approximately 19,500 route miles in 22 states and the District of Columbia, serves every major container port in the eastern United States, and provides efficient connections to other rail carriers. Norfolk Southern operates the most extensive intermodal network in the East and is a major transporter of coal, automotive, and industrial products.\n\nWe are a team of more than 28,000 employees working together to maintain our reputation as "The Thoroughbred of Transportation". As an industry leader, Norfolk Southern offers a competitive salary and an excellent benefits package.',
#  'Norfolk Southern is an equal opportunity employer including veterans and disabled.',
#  'We know salary is a key component of your decision whether or not to apply for a job. So when the hiring company hasn’t provided a salary for a job, we look at salary data from related companies and locations to come up with a reasonable estimate for what you can expect.',
#  'With over 450,000,000 salaries collected from other jobs and employees, we use one of the biggest salary databases in the world to inform these estimates. And because we are continually adding feedback from users like you, we are able to keep refining our accuracy.',
#  'These salary estimates are not endorsed by the hiring companies and may vary from what’s actually offered, but we have a pretty great record of getting close enough for you to make an informed decision.',
#  'Is this your job listing? Send us feedback to correct an inaccurate salary estimate.',
#  'Apply Now',
#  '\n            Please review all application instructions before applying to Relus Cloud\n .',
#  '\n(function(){var a=window.indeed;\n            if(!a||!a.ia){\n            var b=window,\n                c=document.location,\n                e=document.getElementsByTagName("head")[0],\n                f=/^https:\\/\\//.test(c.href),\n                g=document.createElement("script"),\n                h=document.getElementById("indeed-apply-js").attributes["data-indeed-apply-qs"],\n                n=h&&h.value?h.value:"";\n            b.indeed=b.indeed||{};b.indeed.ia=b.indeed.ia||{};\n            g.src=(f?\n        "https://apply.indeed.com/indeedapply/env?https=1&iip=1&":"https://apply.indeed.com/indeedapply/env?iip=1&")+"ms="+ +new Date+(n?"&"+n:"");e.appendChild(g)};})();',
#  'Softcrylic is looking to add a Data Scientist to our growing team in our Atlanta location. The candidate will be working within our Analytics division providing ample opportunity to learn or further grow your knowledge. The candidate will work with our Fortune 500 clients and have the opportunity to be involved in high exposure product development and services. We are looking for someone who can grow with our business and are able to provide an excellent career path in the Analytics domain.',
#  'Job Description: ',
#  'Job Types: Full-time, Contract',
#  'Apply Now',
#  '\n            Please review all application instructions before applying to Softcrylic LLC.',
#  '\n(function(){var a=window.indeed;\n            if(!a||!a.ia){\n            var b=window,\n                c=document.location,\n                e=document.getElementsByTagName("head")[0],\n                f=/^https:\\/\\//.test(c.href),\n                g=document.createElement("script"),\n                h=document.getElementById("indeed-apply-js").attributes["data-indeed-apply-qs"],\n                n=h&&h.value?h.value:"";\n            b.indeed=b.indeed||{};b.indeed.ia=b.indeed.ia||{};\n            g.src=(f?\n        "https://apply.indeed.com/indeedapply/env?https=1&iip=1&":"https://apply.indeed.com/indeedapply/env?iip=1&")+"ms="+ +new Date+(n?"&"+n:"");e.appendChild(g)};})();',
#  'Requisition 10254: Fall 2018 - Operations Research/Data Scientist',
#  'Posting Start Date: 06/12/2018',
#  'Posting End Date: 08/01/2018',
#  'A Day in the Life of an Operations Research Intern\n',
#  'As a Data Scientist/Machine Learning Intern, you will be working with a team of Data Science professionals who apply various cutting edge machine learning and statistical techniques to real-life use-cases and provide actionable insights to the business. You will have the opportunity of working with Norfolk Southern’s big data analytics platform and mine massive amounts of data using various toolsets like R, Python, Spark, TensorFlow, Keras, OpenCV, Hive, etc.',
#  'What Makes a Successful Co-Op/Intern?',
#  'Education/Experience\n',
#  'Compensation',
#  'Norfolk Southern Corporation (NYSE: NSC) is one of the nation’s premier transportation companies. Its Norfolk Southern Railway Company subsidiary operates approximately 19,500 route miles in 22 states and the District of Columbia, serves every major container port in the eastern United States, and provides efficient connections to other rail carriers. Norfolk Southern operates the most extensive intermodal network in the East and is a major transporter of coal, automotive, and industrial products.\n\nWe are a team of more than 28,000 employees working together to maintain our reputation as "The Thoroughbred of Transportation". As an industry leader, Norfolk Southern offers a competitive salary and an excellent benefits package.',
#  'Norfolk Southern is an equal opportunity employer including veterans and disabled.',
#  'We know salary is a key component of your decision whether or not to apply for a job. So when the hiring company hasn’t provided a salary for a job, we look at salary data from related companies and locations to come up with a reasonable estimate for what you can expect.',
#  'With over 450,000,000 salaries collected from other jobs and employees, we use one of the biggest salary databases in the world to inform these estimates. And because we are continually adding feedback from users like you, we are able to keep refining our accuracy.',
#  'These salary estimates are not endorsed by the hiring companies and may vary from what’s actually offered, but we have a pretty great record of getting close enough for you to make an informed decision.',
#  'Is this your job listing? Send us feedback to correct an inaccurate salary estimate.',
#  'Job Number: 16614\n',
#  'Position Title:\n',
#  'External Description:\n\nThe Data Scientist will perform complex modeling and algorithm development on large data sets to resolve disparate data into a single real world entity and develop relationship structures among entities. Typical solutions will use probabilistic matching, machine learning and graph theory to resolve entities, and very large scale structured and unstructured data sets. Additional responsibilities will be to develop proven processes to enhance data, develop quantitative and qualitative analysis to validate recommendations and create clear presentations.\n\nEssential Job Functions:\n',
#  'City: Atlanta\n',
#  'Location_formattedLocationLong: Atlanta, Georgia US\n',
#  'State: Georgia\n',
#  'Community / Marketing Title: Data Scientist, Keying & Linking\n',
#  'Company Profile:\n',
#  'Requisition Number: J00061970\n',
#  'EEO Employer Verbiage: <p>Equifax is an Equal Employment Opportunity employer and all qualified applicants will receive consideration for employment without regard to race, color, religion, sex, sexual orientation, gender identity, national origin, protected veteran status, or disability status.</p>',
#  'Title: Data Scientist - Technical Lead',
#  'Location: Atlanta, GA',
#  'Duration: 3+ Months',
#  'Client: DELL',
#  'Interview mode: Phone OR Skype',
#  'Job Description: ',
#  'Job Type: Contract',
#  'Apply Now',
#  '\n            Please review all application instructions before applying to DELL.',
#  '\n(function(){var a=window.indeed;\n            if(!a||!a.ia){\n            var b=window,\n                c=document.location,\n                e=document.getElementsByTagName("head")[0],\n                f=/^https:\\/\\//.test(c.href),\n                g=document.createElement("script"),\n                h=document.getElementById("indeed-apply-js").attributes["data-indeed-apply-qs"],\n                n=h&&h.value?h.value:"";\n            b.indeed=b.indeed||{};b.indeed.ia=b.indeed.ia||{};\n            g.src=(f?\n        "https://apply.indeed.com/indeedapply/env?https=1&iip=1&":"https://apply.indeed.com/indeedapply/env?iip=1&")+"ms="+ +new Date+(n?"&"+n:"");e.appendChild(g)};})();',
#  'Interface is seeking a Data Scientist in Atlanta, GA.',
#  'Position Summary:',
#  'The Data Scientist will analyze business level data to produce actionable insights utilizing analytics tools and languages such as R, Python and/or C++, etc.',
#  'Essential Duties:',
#  'The Data Scientist will serve as this organization’s though-leader, helping to grow their data science initiative from a green state. He / She will also be responsible for advancement of analytical projects from inception to delivery and beyond.',
#  'Requirements',
#  'Additional Skills / Knowledge',
#  'Post: 3/20/18',
#  'Remove: 3/27/18',
#  'We are a VEVRAA Federal Contractor.\nWe desire priority referrals of Protected Veterans for job openings at all locations within the State of Georgia.\nAn Equal Opportunity Employer including Veterans and Disabled.',
#  '#interface',
#  "We are looking for talented, driven and autonomous candidates who are professional for deep learning develop for medical imaging such as Alzheimerâ€™s diseases (AD), Parkinson's disease (PD), stroke, Autism, attention deficit hyperactivity disorder (ADHD) etc. You will work in a multidisciplinary team, helping to review, maintain, design, and develop AI algorithm for medical imaging analysis. Our team consists of world leading radiologists, scientists and engineers dedicated to revolutionizing medical imaging with significantly improved image quality, safety and efficiency.",
#  'Job r*esponsibilities*',
#  'Requirement',
#  'implementing deep convolutional neural networks',
#  'Job Type: Full-time',
#  'Education:',
#  'Apply Now',
#  '\n            Please review all application instructions before applying to YIWEI Medical Inc..',
#  '\n(function(){var a=window.indeed;\n            if(!a||!a.ia){\n            var b=window,\n                c=document.location,\n                e=document.getElementsByTagName("head")[0],\n                f=/^https:\\/\\//.test(c.href),\n                g=document.createElement("script"),\n                h=document.getElementById("indeed-apply-js").attributes["data-indeed-apply-qs"],\n                n=h&&h.value?h.value:"";\n            b.indeed=b.indeed||{};b.indeed.ia=b.indeed.ia||{};\n            g.src=(f?\n        "https://apply.indeed.com/indeedapply/env?https=1&iip=1&":"https://apply.indeed.com/indeedapply/env?iip=1&")+"ms="+ +new Date+(n?"&"+n:"");e.appendChild(g)};})();',
#  'DEPARTMENT: Program Operations',
#  'POSITION LOCATIONS: Atlanta, GA.',
#  'ACCOUNTABILITY:  President of Program Operations',
#  'For 25 years Operation HOPE has been dedicated to empowering underserved communities through financial literacy, now our work encompasses more than financial education. Our work is about instilling knowledge and confidence in those we serve so they can experience, sometimes for the first time in their lives, financial dignity.',
#  'JOB SUMMARY',
#  'The data analyst collects, organizes, mines, analyzes, and audits large sets of data for impact reporting and operational optimization. The Data Analyst participates as a team member responsible for maintaining the integrity of client database information and provides executable and actionable recommendations for data migration best practices and field operations based on analytical findings.',
#  'DUTIES AND RESPONSIBILITIES',
#  'REQUIRED SKILLS AND EDUCATION',
#  'EEOSTATEMENT',
#  'Operation HOPE is an Equal Opportunity Employer, all qualified applicants will receive consideration for employment without regard to race, color, religion, sex, age, national origin, protected veteran status, disability status, sexual orientation, gender identity or expression, marital status, genetic information or any other characteristic protected by law.',
#  'Job Type: Full-time',
#  'Salary: $50,000.00 to $60,000.00 /year',
#  'Experience:',
#  'Education:',
#  'Location:',
#  'Apply Now',
#  '\n            Please review all application instructions before applying to Operation HOPE.',
#  '\n(function(){var a=window.indeed;\n            if(!a||!a.ia){\n            var b=window,\n                c=document.location,\n                e=document.getElementsByTagName("head")[0],\n                f=/^https:\\/\\//.test(c.href),\n                g=document.createElement("script"),\n                h=document.getElementById("indeed-apply-js").attributes["data-indeed-apply-qs"],\n                n=h&&h.value?h.value:"";\n            b.indeed=b.indeed||{};b.indeed.ia=b.indeed.ia||{};\n            g.src=(f?\n        "https://apply.indeed.com/indeedapply/env?https=1&iip=1&":"https://apply.indeed.com/indeedapply/env?iip=1&")+"ms="+ +new Date+(n?"&"+n:"");e.appendChild(g)};})();',
#  'Driving Infinite Possibilities Within A Diversified, Global Organization',
#  'Honeywell is a Fortune 100 company with global sales surpassing $40B and has been one of Fortune’s Most Admired Companies for over a decade. Through innovation, the Company brings together the physical and digital world to tackle some of the toughest societal and business problems – making the world a more productive, safe, and sustainable place.\n\nThe business is organized into five primary groups: Aerospace, Buildings, Performance Materials and Technologies, Safety and Productivity Solutions, and the Connected Enterprise. Honeywell specializes in things that are critically connected - beyond smart phones and laptops, we make the kinds of connections that keep cities working, planes flying, plants running, and workers safe. Our unique capabilities, over a century in the making, bring together data, expertise, and technology to connect people, processes, and assets.\n\nHoneywell International is building a world that’s safer and more secure, more comfortable and energy efficient, more innovative and productive. For more information, please visit Honeywell.com or follow us @HoneywellNow.\n\nWe’re looking for a new team member who is motivated by cracking tough challenges with data, trained in problem solving, and with an unending thirst for learning.\n\nAs a Advanced Data Scientist, you will join a high-performing, global team, and be responsible for designing, developing, and implementing data driven solutions for all Honeywell business groups and functions. You will work closely with application architects to integrate results into operational platforms, including Hadoop and NoSQL architectures.\n\nThe Advanced Data Scientist role is expected to work within Honeywell to identify opportunities for new growth and efficiency based on data analyses.\n\nYou will also be expected to actively participate in defining and governing our analytics strategy for Honeywell, as well as begin a strong leader in executing data science driven projects as we build out capabilities and our architecture.\n\nYou will report to the Data Science Site Leader in the Honeywell Industrial Analytics organization, part of the Connected Enterprise.\n\nSpecific Responsibilities:\n\nDevelop data modeling, mining, pattern analysis, data visualization and machine learning solutions to address customer needs\n\nFoster relationships with business team members by being proactive, displaying a thorough understanding of the business processes and by recommending innovative solutions\n\nCommunicate project output in terms of customer value, business objectives, and product opportunity\n\nPromote data science methods and processes across functions\n\nWork with our businesses and infrastructure teams to develop a strategy that will clearly outline how our enterprise platforms can enable business growth & productivity',
#  'Honeywell is an equal opportunity employer. Qualified applicants will be considered without regard to age, race, creed, color, national origin, ancestry, marital status, affectional or sexual orientation, gender identity or expression, disability, nationality, sex, or veteran status.',
#  'What you’ll be doing...\n',
#  'This position will drive profitable growth and business innovation by applying cutting edge machine learning techniques and AI technology. It will independently lead data science projects that drive product personalization, marketing effectiveness, channel optimization, better customer experience, and operation efficiency. You will work closely with a team of talented data scientists, Big Data engineers, and software developers and play a key role in developing and delivering the next generation AI/ML solutions to the business.',
#  '\nYou’ll create analytical models to predict customer behavior and business events. You’ll then present the results to various business partners such as marketing, finance, and our customer relationship management group.',
#  '\nWhat we’re looking for...\n',
#  'With an eye towards improving performance and predictability, you like the science of analytics. Developing resolutions to complex problems, using your sharp judgment to develop methods, techniques, and evaluation criteria enables you to deliver solutions that make a big impact. You’re able to communicate technical information to non-technical audiences, and you take pride in your ability to share your considerable knowledge with your peers.',
#  "\nYou'll need to have:",
#  '\nEven better if you have:',
#  '\nWhen you join Verizon...\n',
#  'You’ll be doing work that matters alongside other talented people, transforming the way people, businesses and things connect with each other. Beyond powering America’s fastest and most reliable network, we’re leading the way in broadband, cloud and security solutions, Internet of Things and innovating in areas such as, video entertainment. Of course, we will offer you great pay and benefits, but we’re about more than that. Verizon is a place where you can craft your own path to greatness. Whether you think in code, words, pictures or numbers, find your future at Verizon.',
#  '\nEqual Employment Opportunity\n',
#  "We're proud to be an equal opportunity employer- and celebrate our employees' differences, regardless of race, color, religion, sex, sexual orientation, gender identity, national origin, age, disability, or Veteran status. Different makes us better.",
#  'Data Scientist - Supply Chain Optimization',
#  'Join a growing Data Science and Advanced Analytics team at Norfolk Southern Corporation. The team is using latest cutting edge tools and technologies to develop analytics and solutions to solve business problems from various fields such as engineering, mechanical, communications, marketing & finance.',
#  'Principal Duties:',
#  'Job Related Experience:',
#  'Minimum Level: 2-3; Preferred Level: 3+ years of relevant experience (e.g. analysist, statistician, data scientist, team lead) or proven qualifications',
#  'Education:',
#  'Masters’ required, Ph.D. preferred in following fields:',
#  'Preferred Majors: Computer and Information Sciences, Electrical Engineering, Engineering – Statistics, Engineering - Operations Research, Engineering - Systems Engineering, Mathematical Sciences - Applied Mathematics, Physics',
#  'Licenses / Certifications: Required: None listed, Preferred: None listed',
#  'Technical Skills:',
#  'Skills and Abilities:',
#  'Work Conditions\n',
#  'Norfolk Southern Corporation (NYSE: NSC) is one of the nation’s premier transportation companies. Its Norfolk Southern Railway Company subsidiary operates approximately 19,500 route miles in 22 states and the District of Columbia, serves every major container port in the eastern United States, and provides efficient connections to other rail carriers. Norfolk Southern operates the most extensive intermodal network in the East and is a major transporter of coal, automotive, and industrial products.\n\nWe are a team of more than 28,000 employees working together to maintain our reputation as "The Thoroughbred of Transportation". As an industry leader, Norfolk Southern offers a competitive salary and an excellent benefits package.',
#  'Norfolk Southern is an equal opportunity employer including veterans and disabled.',
#  'We know salary is a key component of your decision whether or not to apply for a job. So when the hiring company hasn’t provided a salary for a job, we look at salary data from related companies and locations to come up with a reasonable estimate for what you can expect.',
#  'With over 450,000,000 salaries collected from other jobs and employees, we use one of the biggest salary databases in the world to inform these estimates. And because we are continually adding feedback from users like you, we are able to keep refining our accuracy.',
#  'These salary estimates are not endorsed by the hiring companies and may vary from what’s actually offered, but we have a pretty great record of getting close enough for you to make an informed decision.',
#  'Is this your job listing? Send us feedback to correct an inaccurate salary estimate.',
#  'Cotiviti is looking for an industry leading Data Scientist to join a revolution in Healthcare and build a first-in-market analytics capability. This is a pioneering data scientist who will participate in expanding the new analytics backbone of the company. Cotiviti’s first-in-market analytics capability is powered by social networking technology and enables a more efficient experience for both healthcare providers and customers. As a Data Scientist at Cotiviti you will be given the opportunity to work directly with a team of healthcare professionals including analysts, clinicians, coding specialists, auditors and innovators to set aggressive goals and execute on them with the team. This is for an ambitious technologist with the guts, flexibility, and personal drive to succeed in a dynamic environment.',
#  '\nWho You Are',
#  'What You Will be Doing\n',
#  'You will build innovative tools to provide our clients with insights on how to improve their business. You will have responsibility for architecting and developing best-in-class analytics that create quantifiable value for our business. You will have responsibility for establishing and sustaining processes and practices that support big data and analytics solutions and applications in an open source environment. You should have a passion for creating solutions and driving innovation with an interest in collaborating with team members. This role demands time spent working independently and as part of a team. You will also focus on specific deadlines defined by the management team.',
#  'Requirements:',
#  'Preferred Qualifications:',
#  'Join a growing Data Science and Advanced Analytics team at Norfolk Southern Corporation. The team is using latest cutting edge tools and technologies to develop analytics and solutions to solve business problems from various fields such as engineering, mechanical, communications, marketing & finance.',
#  'Principal Duties:',
#  'Job Related Experience:',
#  'Minimum Level: 5+ years of relevant experience (e.g. analysist, statistician, data scientist, team lead) or proven qualifications',
#  'Education:',
#  'Masters’ required, Ph.D. preferred.',
#  'Preferred Majors: Computer and Information Sciences, Electrical Engineering, Engineering – Statistics, Engineering - Operations Research, Engineering - Systems Engineering, Mathematical Sciences - Applied Mathematics, Physics',
#  'Licenses / Certifications: Required: None listed, Preferred: None listed',
#  'Technical Skills:',
#  'Skills and Abilities:',
#  'Work Conditions\n',
#  'Norfolk Southern Corporation (NYSE: NSC) is one of the nation’s premier transportation companies. Its Norfolk Southern Railway Company subsidiary operates approximately 19,500 route miles in 22 states and the District of Columbia, serves every major container port in the eastern United States, and provides efficient connections to other rail carriers. Norfolk Southern operates the most extensive intermodal network in the East and is a major transporter of coal, automotive, and industrial products.\n\nWe are a team of more than 28,000 employees working together to maintain our reputation as "The Thoroughbred of Transportation". As an industry leader, Norfolk Southern offers a competitive salary and an excellent benefits package.',
#  'Norfolk Southern is an equal opportunity employer including veterans and disabled.',
#  'The position is for a full-time research faculty position in the Opto-Electronics (OE) Branch in the Electro-Optical Systems Innovation Division (EOSID) with the Electro-Optical Systems Laboratory (EOSL) at the Georgia Tech Research Institute (GTRI). The main responsibility will be providing expertise in the full imaging chain to conceptualize, design, analyze, build, and test optical systems that meet customer requirements and internal research goals. The job provides opportunities to develop advanced technology and publish research.',
#  'Duties and Responsibilities:',
#  'Basic Qualifications:',
#  'Minimum Qualifications:',
#  'To perform this job successfully, an individual must be able to perform each essential duty satisfactorily. The requirements listed above are representative of the knowledge, skill, and/or ability required. Reasonable accommodations may be made to enable individuals with disabilities to perform the essential functions.',
#  'The Data Management and Insights organization (‘DMI’) is building a best in-class data science team, focused on delivering enterprise-wide data driven insights based in both traditional and emerging analytical techniques. Our team supports the DMI service model by providing LOBs with machine learning and predictive analytic consulting and guidance.\n',
#  'Key Responsibilities Include :\n',
#  'All offers for employment with Wells Fargo are contingent upon the candidate having successfully completed a criminal background check. Wells Fargo will consider qualified candidates with criminal histories in a manner consistent with the requirements of applicable local, state and Federal law, including Section 19 of the Federal Deposit Insurance Act.\n\nRelevant military experience is considered for veterans and transitioning service men and women.\n\nWells Fargo is an Affirmative Action and Equal Opportunity Employer, Minority/Female/Disabled/Veteran/Gender Identity/Sexual Orientation.',
#  'Company Description:',
#  '\nWho is Intuitive Surgical? The numbers tell an amazing story. Learn more about our company.',
#  'As a Data Scientist, you would work closely with domain experts in health care in defining well thought and thorough solutions. You have a Ph.D./Master’s Degree in operations research, applied statistics, data mining, machine learning, physics or a related quantitative discipline. You have a deep understanding of statistical and predictive modeling concepts, machine-learning approaches, clustering and classification techniques, and recommendation and optimization algorithms. You would be involved in all phases of development like project scoping, team building, working with business leads and project managers, organizing sprints, managing deadlines, understanding and articulating priorities, architecting solutions, coding and delivering high quality results. This position reports to the Engineering Manager and has high level of visibility to functional managers worldwide.',
#  'Responsibilities:',
#  'Qualifications Required: Ph.D./Master’s Degree in operations research, applied statistics, data mining, machine learning, physics or a related quantitative discipline Experience (Years): 8-12 years Technologies required:  * DB and computing technology: SQL databases, Hadoop, Spark  * Programming Language: Java  * Scripting Technology: Javascript  * ETL Technology: SSIS, Talend, TSql  * BI Technology: SSAS, Tableau, PowerBI  * Machine learning tools: R, Azure ml, MLib, for time series analysis, clustering, classification, validation',
#  'Skills:  * Candidates applying for this position need to have a strong software development background with a very good systems perspective.  * Prior experience in interactions with Hadoop / Spark / MapReduce / Cascading / HDFS  * Experience with large database interactions (Postgres is desired)  * Experience with highly scalable systems  * Experience working in healthcare domain, exposure to operational and clinical data  * Ability to learn and apply new technologies quickly  * Excellent understanding of machine learning techniques and algorithms, such as k-NN, Naive Bayes, SVM, Decision Forests, etc.  * Experience with common data science toolkits, such as R, Azure ml, NumPy, etc . Excellence in at least R and azure ml is highly desirable  * Great communication skills  * Experience with data visualization tools, such as Tableau, D3.js, PowerBI etc.  * Proficiency in using query languages such as SQL, Hive, Pig  * Experience with NoSQL databases, such as CouchDB, MongoDB.  * Good applied statistics skills, such as distributions, statistical testing, regression, etc.  * Good scripting and programming skills  * Ability to multi-task in a dynamic environment  * Experience with Python/Scala is a plus  * Ability to consider ethical, legal and societal aspects of handling personal health care data and confidential customer data  * Knowledge of semantics and semantic interoperability e.g. knowledge models, ontologies, terminologies, information models  * Leadership qualities to take initiatives  * Should be able to handle wide array of technical platform  * Have complete understanding of programming patterns and can implement them  * 8+ years of software engineering work experience  * At least 8 years of experience with data science  * At least 6 years working with R or any machine learning tools  * At least 8 years experience working on reporting and visualization tools.  * At least 3 years work experience with open source technology',
#  'Job Type: Full-time',
#  'Experience:',
#  'Education:',
#  'Location:',
#  'Apply Now',
#  '\n            Please review all application instructions before applying to Varian Medical Systems.',
#  '\n(function(){var a=window.indeed;\n            if(!a||!a.ia){\n            var b=window,\n                c=document.location,\n                e=document.getElementsByTagName("head")[0],\n                f=/^https:\\/\\//.test(c.href),\n                g=document.createElement("script"),\n                h=document.getElementById("indeed-apply-js").attributes["data-indeed-apply-qs"],\n                n=h&&h.value?h.value:"";\n            b.indeed=b.indeed||{};b.indeed.ia=b.indeed.ia||{};\n            g.src=(f?\n        "https://apply.indeed.com/indeedapply/env?https=1&iip=1&":"https://apply.indeed.com/indeedapply/env?iip=1&")+"ms="+ +new Date+(n?"&"+n:"");e.appendChild(g)};})();',
#  'This job is for a full-time research faculty position in the Electro-Optical Systems Innovation Division (EOSID) with the Electro-Optical Systems Laboratory (EOSL) at the Georgia Tech Research Institute (GTRI). The main responsibility will be providing expertise in the full imaging chain to conceptualize, design, analyze, build, and test optical systems that meet customer requirements and internal research goals.The job provides opportunities to develop advanced technology and publish research.',
#  '\nEOSID’s research is performed in the areas of Intelligence, Surveillance, and Reconnaissance (ISR), Intelligent Sensors and Imaging Systems (ISIS), and Active Electro-Optic Systems. Our team designs, builds, and tests the hardware in the entire imaging chain. Key technical areas include Hyperspectral and Multispectral Imaging Processing; EO System and Component Analysis and Characterization; Optical Imaging and Tagging; and Airborne Lidar System Design, Construction, and Operation for real-time topography, FOPEN, and bathymetry.',
#  '\nWe offer a flexible work environment allowing each researcher to pursue his or her interests and strengths, integrated with the overall mission of the branch and the lab. If you have aspirations for an advanced degree, all the better. Because GTRI is a research unit within Georgia Tech, you can get your graduate school paid for and pursue an additional engineering, science or math degree you desire from a world class research institution. We highly encourage our research developers to pursue advanced technical degrees and professional development courses.',
#  'Research Engineer/Scientist I',
#  'Research Engineer/Scientist II',
#  '\nDuties related to this position are listed below with the estimated amount of time spent at each task:',
# ...
#  '\nWe offer a flexible work environment allowing each researcher to pursue his or her interests and strengths, integrated with the overall mission of the branch and the lab. If you have aspirations for an advanced degree, all the better. Because GTRI is a research unit within Georgia Tech, you can get your graduate school paid for and pursue an additional engineering, science or math degree you desire from a world class research institution. We highly encourage our research developers to pursue advanced technical degrees and professional development courses.',
#  'Senior Research Engineer/Scientist',
#  '\nQualified candidates at all degree levels (Bachelors, Masters, PhD) will be considered. Candidates should have education, experience, and/or expertise in one or more of the following:',
#  '\nAdditionally, candidates should have experience working with one or more of the following:',
#  'Due to our research contracts with the US federal government, candidates for this position are required to be US Citizens.',
#  'Ability to obtain Secret Clearance upon hire',
#  "Georgia Tech Research Institutes's (GTRI) Trusted Microelectronics Program Office (TMPO) seeks a junior computer scientist or engineer with interest in the development of novel cutting-edge software tools to support microelectronics security research.",
#  '\nTMPO researches microelectronic applications, tools, architectures, and materials to evaluate the security, trust, and reliability of microelectronic devices and the critical systems which rely upon them. TMPO develops tools and techniques in the areas of assurance, anti-tamper, and reliability for FPGAs, ASICs, SoCs, microcontrollers, leveraging custom and formal methods.',
#  '\nJunior Researchers in this posting will be responsible for the research and development of software infrastructure to support and enable exploration and implementation of security and trust mechanisms within microelectronic systems. Potential research opportunities include enhancing reconfigurable computing device design via custom software to support analysis, design, testing, and emulation of microelectronics (e.g., FPGAs); leveraging and extending conventional EDA/CAD tools to provide security enhancements to designs; developing custom EDA/CAD tools and exploring novel synthesis, implementation, and place & route algorithms for ASICs and FPGA designs; and researching and implementing novel HW/SW co-designs for root-of-trust systems.',
#  'Research Engineer/Scientist I',
#  'Research Engineer/Scientist II',
#  'Due to our research contracts with the US federal government, candidates for this position are required to be US Citizens.',
#  'Ability to obtain Secret Clearance upon hire',
#  'Senior Data Scientist with strong proficiency in predictive modeling, machine learning and data mining using Python or R sought by major media company to provide insight into audience consumption and behavior that will inform programming and content decisions. Ideal candidate should have a deep background in predictive analytics, market research statistics (e.g., cluster-based customer segmentation, etc.), forecasting and have a strong interest in media. Position is based in Atlanta, GA',
#  'Requirements:',
#  'Keywords: data science, machine learning, marketing science, predictive analytics, forecasting, media, audience insights',
#  'Refer to Job #23147 – and send MS Word attached resume to Howard Fishman, howard@analyticrecruiting.com',
#  'Apply Now',
#  'Indeed will send your application to howard@analyticrecruiting.com.',
#  '\n            Please review all application instructions before applying to Analytic Recruiting.',
#  '\n(function(){var a=window.indeed;\n            if(!a||!a.ia){\n            var b=window,\n                c=document.location,\n                e=document.getElementsByTagName("head")[0],\n                f=/^https:\\/\\//.test(c.href),\n                g=document.createElement("script"),\n                h=document.getElementById("indeed-apply-js").attributes["data-indeed-apply-qs"],\n                n=h&&h.value?h.value:"";\n            b.indeed=b.indeed||{};b.indeed.ia=b.indeed.ia||{};\n            g.src=(f?\n        "https://apply.indeed.com/indeedapply/env?https=1&iip=1&":"https://apply.indeed.com/indeedapply/env?iip=1&")+"ms="+ +new Date+(n?"&"+n:"");e.appendChild(g)};})();',
#  "Known for being a great place to work and build a career, KPMG provides audit, tax and advisory services for organizations in today's most important industries. Our growth is driven by delivering real results for our clients. It's also enabled by our culture, which encourages individual development, embraces an inclusive environment, rewards innovative excellence and supports our communities. With qualities like those, it's no wonder we're consistently ranked among the best companies to work for by Fortune Magazine, Consulting Magazine, Working Mother Magazine, Diversity Inc. and others. If you're as passionate about your future as we are, join our team.",
#  '\nKPMG is currently seeking a Temporary Big Data Software Engineer to join our Advanced Analytics Organization.',
#  '\nResponsibilities:',
#  '\nQualifications:',
#  '\nKPMG LLP (the U.S. member firm of KPMG International) offers a comprehensive compensation and benefits package. KPMG is an equal opportunity employer. All qualified applicants are considered for employment without regard to race, color, creed, religion, age, sex/gender, national origin, ancestry, citizenship status, marital status, sexual orientation, gender identity or expression, disability, physical or mental handicap unrelated to ability, pregnancy, veteran status, unfavorable discharge from military service, genetic information, personal appearance, family responsibility, matriculation or political affiliation, or other legally protected status. KPMG maintains a drug-free workplace. KPMG will consider for employment qualified applicants with criminal histories in a manner consistent with the requirements of applicable local, state or federal law (including San Francisco Ordinance number 131192). No phone calls or agencies please.',
#  "Known for being a great place to work and build a career, KPMG provides audit, tax and advisory services for organizations in today's most important industries. Our growth is driven by delivering real results for our clients. It's also enabled by our culture, which encourages individual development, embraces an inclusive environment, rewards innovative excellence and supports our communities. With qualities like those, it's no wonder we're consistently ranked among the best companies to work for by Fortune Magazine, Consulting Magazine, Working Mother Magazine, Diversity Inc. and others. If you're as passionate about your future as we are, join our team.",
#  '\nKPMG is currently seeking a Temporary Big Data SW Engineer to join our Advanced Analytics Organization',
#  '\nResponsibilities:',
#  '\nQualifications:',
#  '\nKPMG LLP (the U.S. member firm of KPMG International) offers a comprehensive compensation and benefits package. KPMG is an equal opportunity employer. All qualified applicants are considered for employment without regard to race, color, creed, religion, age, sex/gender, national origin, ancestry, citizenship status, marital status, sexual orientation, gender identity or expression, disability, physical or mental handicap unrelated to ability, pregnancy, veteran status, unfavorable discharge from military service, genetic information, personal appearance, family responsibility, matriculation or political affiliation, or other legally protected status. KPMG maintains a drug-free workplace. KPMG will consider for employment qualified applicants with criminal histories in a manner consistent with the requirements of applicable local, state or federal law (including San Francisco Ordinance number 131192). No phone calls or agencies please.',
#  'We know salary is a key component of your decision whether or not to apply for a job. So when the hiring company hasn’t provided a salary for a job, we look at salary data from related companies and locations to come up with a reasonable estimate for what you can expect.',
#  'With over 450,000,000 salaries collected from other jobs and employees, we use one of the biggest salary databases in the world to inform these estimates. And because we are continually adding feedback from users like you, we are able to keep refining our accuracy.',
#  'These salary estimates are not endorsed by the hiring companies and may vary from what’s actually offered, but we have a pretty great record of getting close enough for you to make an informed decision.',
#  'Is this your job listing? Send us feedback to correct an inaccurate salary estimate.',
#  "Georgia Tech Research Institutes's (GTRI) Trusted Microelectronics Program Office (TMPO) seeks a hardware/FPGA researcher and/or digital design engineer with interest in the development of novel cutting-edge hardware designs and performing digital hardware analysis to support microelectronics security research.",
#  '\nTMPO researches microelectronic applications, tools, architectures, and materials to evaluate the security, trust, and reliability of microelectronic devices and the critical systems which rely upon them. TMPO develops tools and techniques in the areas of assurance, anti-tamper, and reliability for FPGAs, ASICs, SoCs, microcontrollers, and other devices, to include novel hardware-oriented security and trust protections.',
#  '\nJunior Researchers in this posting will be responsible for all aspects of FPGA hardware development to include simulation, testing, and troubleshooting of designs, including bench testing and debugging hardware using test equipment. Researchers will have the opportunity to develop FPGA code to control hardware in real time and support complex experimentation. Researchers in this position will also be given the opportunity to perform low (gate and RTL) level analysis of hardware designs in order to identify and characterize security concerns and design and implement mechanisms to enhance the security of hardware designs.',
#  'Research Engineer/Scientist I',
#  'Research Engineer/Scientist II',
#  'Due to our research contracts with the US federal government, candidates for this position are required to be US Citizens.',
#  'Ability to obtain Secret Clearance upon hire',
#  'The Senior Machine Learning Researcher will perform and supervise basic and applied research on sponsored programs targeted at integrating machine learning and network defense and/or intelligence analysis, and participating in internal R&D (IRAD) associated with advanced AI and machine learning techniques to solve cyber security and/or intelligence analysis problems. The Machine Learning Researcher will be expected to identify potential sponsored research opportunities, support conferences, sponsor briefings, participate in delivering content associated with short courses and CIPHER’s education initiatives and other activities in support of our outreach activities.',
#  'Senior Research Engineer/Scientist/Technologist/Associate',
#  'Principal Research Engineer/Scientist/Technologist/Associate',
#  'Due to our research contracts with the US federal government, candidates for this position are required to be US Citizens.',
#  'Ability to obtain Top Secret Clearance upon hire.',
#  'Job Description:',
#  'Bank of America’s Alternative Modeling Group is looking for a Senior Quantitative Financial Analyst. The group’s work centers on asset quality and credit loss forecasting, in both consumer and commercial products. The position will involve model building. Although work in the group is typically collaborative, researchers are often given control over substantial projects: all researchers are expected to be intellectually independent self-starters.',
#  '\nEssential:',
#  'Desirable:',
#  'Shift:',
#  'Hours Per Week:',
#  "Georgia Tech Research Institute's (GTRI) Trusted Microelectronics Program Office (TMPO) seeks a computer scientist or engineer with interest in the development of novel cutting-edge software tools to support research in embedded systems hardware security. The candidate will work in a collaborative environment with a premier team of researchers and will be offered interesting and varied work on a variety of novel projects, including employee suggested and lead research projects. The candidate may also work with other units within the Georgia Tech community to perform interdisciplinary research in embedded system security.",
#  '\nTMPO researchers regularly attend and publish at leading conferences and enjoy great benefits and flexible working hours. GTRI also provides financial support to its employees in their pursuit of higher education, and gives access to other opportunities for self-improvement and learning.',
#  '\nResearch Areas:',
#  'Senior Research Engineer/Scientist',
#  'Due to our research contracts with the US federal government, candidates for this position are required to be US Citizens.',
#  'Ability to obtain Top Secret Clearance upon hire',
#  'This job is for a full time research faculty position in the Methods and Analysis Development Branch (MADB), part of the Systems Engineering Research Division (SERD).',
#  '\nTHE GROUP:\nOur research group is predominantly focused on the research, development, and application of new systems engineering tools and methods for decision support, concept of employment analysis, systems architecture, and conceptual design for complex systems.',
#  '\nWe create systems models (both qualitative and quantitative) that aid our sponsors in the early stages of systems design to determine the best architecture to achieve a desired operational capability.',
#  '\nIn addition to systems design, we provide capability-based strategic decision making and portfolio planning expertise to aid a variety of customers in mapping their high level goals and objectives to a set of both feasible and viable, actionable alternatives.',
#  '\nTHE POSITION:\nExperience with modeling and simulation of complex systems (e.g., agent-based modeling, discrete event simulation, DEVS, systems dynamics).',
#  "\nSystems engineering experience but a background in research, design and analysis in any science or engineering related field accepted. Proficient in the use of SAS JMP, R, or Python's numeric and data analytics, and simulation libraries (e.g., numpy, scipy, pandas, tensorflow, luigi, simpy, mesa).",
#  'Research Engineer/Scientist I',
#  'Research Engineer/Scientist II',
#  "Applicants should have some experience with some of the following: modeling and simulation of complex systems (e.g., agent-based modeling, discrete event simulation, DEVS, systems dynamics), numerical optimization, statistical analysis, uncertainty quantification, tradespace exploration. Experience in systems engineering with a background in research, design and analysis in a field of science or engineering if strongly preferred. Proficiency in the use of SAS JMP, R, or Python's numeric and data analytics, and simulation libraries (e.g., numpy, scipy, pandas, tensorflow, luigi, simpy, mesa) are considered strong benefits.",
#  'Due to our research contracts with the US federal government, candidates for this position are required to be US Citizens.',
#  'Ability to obtain Secret Clearance upon hire',
#  'This position supports system and software test of embedded and Windows software for Department of Defense aircraft improvement programs.',
#  '\nAs a Test Engineer you will need to:',
#  'Research Engineer/Scientist I',
#  'Due to our research contracts with the US federal government, candidates for this position are required to be US Citizens.',
#  'Ability to obtain Secret Clearance upon hire']

# %%
pd.DataFrame(list_of_para).to_csv('Paragraphs', index=False)

# %%
pd.read_csv('Paragraphs')
# Out:
#                                                      0
# 0    Truck IT, LLC ("Truck IT"), (Headquartered in ...
# 1    Data is the driver for our future at Truck IT....
# 2                                                 ROLE
# 3    Working within a dynamic and fast paced team e...
# 4                                       ABOUT THE TEAM
# 5    The Big Data and Machine Learning team is resp...
# 6                                 WHAT’S IN IT FOR YOU
# 7                                                FOCUS
# 8                              Required Qualifications
# 9                             Preferred Qualifications
# 10                                 Job Type: Full-time
# 11                                           Location:
# 12                        Required work authorization:
# 13                                           Apply Now
# 14   \n            Please review all application in...
# 15   \n(function(){var a=window.indeed;\n          ...
# 16                                 Job Number: 18230\n
# 17                                   Position Title:\n
# 18                             External Description:\n
# 19                                     City: Atlanta\n
# 20   Location_formattedLocationLong: Atlanta, Georg...
# 21                                    State: Georgia\n
# 22       Community / Marketing Title: Data Scientist\n
# 23                                  Company Profile:\n
# 24                     Requisition Number: J00067915\n
# 25   EEO Employer Verbiage: <p>Equifax is an Equal ...
# 26                 DEPARTMENT: HOPE Research Institute
# 27                    POSITION LOCATIONS: Atlanta, GA.
# 28   ACCOUNTABILITY:  Senior VP, HOPE Research Inst...
# 29   For 25 years Operation HOPE has been dedicated...
# ..                                                 ...
# 584  Due to our research contracts with the US fede...
# 585  Ability to obtain Top Secret Clearance upon hire.
# 586                                   Job Description:
# 587  Bank of America’s Alternative Modeling Group i...
# 588                                       \nEssential:
# 589                                         Desirable:
# 590                                             Shift:
# 591                                    Hours Per Week:
# 592  Georgia Tech Research Institute's (GTRI) Trust...
# 593  \nTMPO researchers regularly attend and publis...
# 594                                  \nResearch Areas:
# 595                 Senior Research Engineer/Scientist
# 596  Due to our research contracts with the US fede...
# 597   Ability to obtain Top Secret Clearance upon hire
# 598  This job is for a full time research faculty p...
# 599  \nTHE GROUP:\nOur research group is predominan...
# 600  \nWe create systems models (both qualitative a...
# 601  \nIn addition to systems design, we provide ca...
# 602  \nTHE POSITION:\nExperience with modeling and ...
# 603  \nSystems engineering experience but a backgro...
# 604                      Research Engineer/Scientist I
# 605                     Research Engineer/Scientist II
# 606  Applicants should have some experience with so...
# 607  Due to our research contracts with the US fede...
# 608       Ability to obtain Secret Clearance upon hire
# 609  This position supports system and software tes...
# 610             \nAs a Test Engineer you will need to:
# 611                      Research Engineer/Scientist I
# 612  Due to our research contracts with the US fede...
# 613       Ability to obtain Secret Clearance upon hire
#
# [614 rows x 1 columns]

# %%
Paragraphs = pd.read_csv('Paragraphs')

# %%
Paragraphs = Paragraphs.replace('\n','', regex=True)

# %%
Paragraphs
# Out:
#                                                      0
# 0    Truck IT, LLC ("Truck IT"), (Headquartered in ...
# 1    Data is the driver for our future at Truck IT....
# 2                                                 ROLE
# 3    Working within a dynamic and fast paced team e...
# 4                                       ABOUT THE TEAM
# 5    The Big Data and Machine Learning team is resp...
# 6                                 WHAT’S IN IT FOR YOU
# 7                                                FOCUS
# 8                              Required Qualifications
# 9                             Preferred Qualifications
# 10                                 Job Type: Full-time
# 11                                           Location:
# 12                        Required work authorization:
# 13                                           Apply Now
# 14               Please review all application inst...
# 15   (function(){var a=window.indeed;            if...
# 16                                   Job Number: 18230
# 17                                     Position Title:
# 18                               External Description:
# 19                                       City: Atlanta
# 20   Location_formattedLocationLong: Atlanta, Georg...
# 21                                      State: Georgia
# 22         Community / Marketing Title: Data Scientist
# 23                                    Company Profile:
# 24                       Requisition Number: J00067915
# 25   EEO Employer Verbiage: <p>Equifax is an Equal ...
# 26                 DEPARTMENT: HOPE Research Institute
# 27                    POSITION LOCATIONS: Atlanta, GA.
# 28   ACCOUNTABILITY:  Senior VP, HOPE Research Inst...
# 29   For 25 years Operation HOPE has been dedicated...
# ..                                                 ...
# 584  Due to our research contracts with the US fede...
# 585  Ability to obtain Top Secret Clearance upon hire.
# 586                                   Job Description:
# 587  Bank of America’s Alternative Modeling Group i...
# 588                                         Essential:
# 589                                         Desirable:
# 590                                             Shift:
# 591                                    Hours Per Week:
# 592  Georgia Tech Research Institute's (GTRI) Trust...
# 593  TMPO researchers regularly attend and publish ...
# 594                                    Research Areas:
# 595                 Senior Research Engineer/Scientist
# 596  Due to our research contracts with the US fede...
# 597   Ability to obtain Top Secret Clearance upon hire
# 598  This job is for a full time research faculty p...
# 599  THE GROUP:Our research group is predominantly ...
# 600  We create systems models (both qualitative and...
# 601  In addition to systems design, we provide capa...
# 602  THE POSITION:Experience with modeling and simu...
# 603  Systems engineering experience but a backgroun...
# 604                      Research Engineer/Scientist I
# 605                     Research Engineer/Scientist II
# 606  Applicants should have some experience with so...
# 607  Due to our research contracts with the US fede...
# 608       Ability to obtain Secret Clearance upon hire
# 609  This position supports system and software tes...
# 610               As a Test Engineer you will need to:
# 611                      Research Engineer/Scientist I
# 612  Due to our research contracts with the US fede...
# 613       Ability to obtain Secret Clearance upon hire
#
# [614 rows x 1 columns]

# %%
pd.DataFrame(Paragraphs).to_csv('Paragraphs', index=False)

# %%
pd.DataFrame(list_of_li).to_csv('Bullets', index=False)

# %%
pd.read_csv('Bullets')
# Out:
#                                                       0
# 0     Location, Location, Location - 1372 Peachtree ...
# 1     Competitive compensation with incentive opport...
# 2     Benefits include: Medical, Dental, Vision and ...
# 3     Becoming an integral part of a winning team su...
# 4     Supportive leadership that recognizes and rewa...
# 5     Small company culture where everyone’s contrib...
# 6     Ability to participate in a constant offering ...
# 7              Casual work environment and team outings
# 8     Experience joining a company at a high-growth,...
# 9     Collaborate with product management and engine...
# 10    Able to identify customers' needs and desires ...
# 11    Deliver informative and effective findings, re...
# 12    Create dashboards of important statistics and ...
# 13    Develop and implement scalable and efficient m...
# 14    Develop predictive models to address various b...
# 15    MS or PhD degree in Computer Science or releva...
# 16    Proficient in one or more programming language...
# 17    Familiar with one or more machine learning or ...
# 18    Knowledge and experience of machine learning, ...
# 19    Knowledge and experience of relational databas...
# 20    Strong analytical and quantitative problem-sol...
# 21    Experience with big data techniques (such as H...
# 22    Knowledge of cloud platforms (such as AWS or A...
# 23                                    Atlanta, GA 30309
# 24                                        United States
# 25    Analyzing, processing, evaluating and document...
# 26    \nIdentifying/developing appropriate machine l...
# 27    \nPrototyping tools and techniques to solve co...
# 28    \nDeveloping data driven models to quantify th...
# 29    \nApplying, modifying and inventing algorithms...
# ...                                                 ...
# 1711  \nSenior Fpga Researcher salaries in Atlanta, ...
# 1712  A Bachelor's degree in Aerospace, Computer, El...
# 1713  A Master’s degree in Aerospace, Computer, Elec...
# 1714  A Doctoral degree in Aerospace, Computer, Elec...
# 1715            \nSystem Engineer jobs in Atlanta, GA\n
# 1716  \nJobs at Georgia Tech Research Institute in A...
# 1717        \nSystem Engineer salaries in Atlanta, GA\n
# 1718  Develop and update test plans, procedures and ...
# 1719  Execute developed test procedures and document...
# 1720  Technically coordinate with a cross-functional...
# 1721  Maintain and create test scripts, files and da...
# 1722  Work in an integrated product team and underst...
# 1723  Utilize existing system specifications, interf...
# 1724  Ensure that all technical work is performed an...
# 1725  Develop test estimates for proposed work and s...
# 1726  A Bachelor's degree in Computer Science, Elect...
# 1727  Experience in test engineering processes and m...
# 1728       Manual, ad hoc, black and white box testing.
# 1729  Strong collaboration, organization, teaming an...
# 1730  Ability to work well individually or in a grou...
# 1731  Ability to work under pressure and time constr...
# 1732  Ability to create and deliver technical presen...
# 1733              Python or similar scripting language.
# 1734  Experience with MIL-STD-1553 data bus, avionic...
# 1735  Experience with system security and safety eng...
# 1736  Experience with configuration management and r...
# 1737  Experience directing small teams of employees ...
# 1738              \nTest Engineer jobs in Atlanta, GA\n
# 1739  \nJobs at Georgia Tech Research Institute in A...
# 1740          \nTest Engineer salaries in Atlanta, GA\n
#
# [1741 rows x 1 columns]

# %%
Bullets = pd.read_csv('Bullets')

# %%
Bullets = Bullets.replace('\n','', regex=True)

# %%
Bullets
# Out:
#                                                       0
# 0     Location, Location, Location - 1372 Peachtree ...
# 1     Competitive compensation with incentive opport...
# 2     Benefits include: Medical, Dental, Vision and ...
# 3     Becoming an integral part of a winning team su...
# 4     Supportive leadership that recognizes and rewa...
# 5     Small company culture where everyone’s contrib...
# 6     Ability to participate in a constant offering ...
# 7              Casual work environment and team outings
# 8     Experience joining a company at a high-growth,...
# 9     Collaborate with product management and engine...
# 10    Able to identify customers' needs and desires ...
# 11    Deliver informative and effective findings, re...
# 12    Create dashboards of important statistics and ...
# 13    Develop and implement scalable and efficient m...
# 14    Develop predictive models to address various b...
# 15    MS or PhD degree in Computer Science or releva...
# 16    Proficient in one or more programming language...
# 17    Familiar with one or more machine learning or ...
# 18    Knowledge and experience of machine learning, ...
# 19    Knowledge and experience of relational databas...
# 20    Strong analytical and quantitative problem-sol...
# 21    Experience with big data techniques (such as H...
# 22    Knowledge of cloud platforms (such as AWS or A...
# 23                                    Atlanta, GA 30309
# 24                                        United States
# 25    Analyzing, processing, evaluating and document...
# 26    Identifying/developing appropriate machine lea...
# 27    Prototyping tools and techniques to solve comp...
# 28    Developing data driven models to quantify the ...
# 29    Applying, modifying and inventing algorithms t...
# ...                                                 ...
# 1711     Senior Fpga Researcher salaries in Atlanta, GA
# 1712  A Bachelor's degree in Aerospace, Computer, El...
# 1713  A Master’s degree in Aerospace, Computer, Elec...
# 1714  A Doctoral degree in Aerospace, Computer, Elec...
# 1715                System Engineer jobs in Atlanta, GA
# 1716  Jobs at Georgia Tech Research Institute in Atl...
# 1717            System Engineer salaries in Atlanta, GA
# 1718  Develop and update test plans, procedures and ...
# 1719  Execute developed test procedures and document...
# 1720  Technically coordinate with a cross-functional...
# 1721  Maintain and create test scripts, files and da...
# 1722  Work in an integrated product team and underst...
# 1723  Utilize existing system specifications, interf...
# 1724  Ensure that all technical work is performed an...
# 1725  Develop test estimates for proposed work and s...
# 1726  A Bachelor's degree in Computer Science, Elect...
# 1727  Experience in test engineering processes and m...
# 1728       Manual, ad hoc, black and white box testing.
# 1729  Strong collaboration, organization, teaming an...
# 1730  Ability to work well individually or in a grou...
# 1731  Ability to work under pressure and time constr...
# 1732  Ability to create and deliver technical presen...
# 1733              Python or similar scripting language.
# 1734  Experience with MIL-STD-1553 data bus, avionic...
# 1735  Experience with system security and safety eng...
# 1736  Experience with configuration management and r...
# 1737  Experience directing small teams of employees ...
# 1738                  Test Engineer jobs in Atlanta, GA
# 1739  Jobs at Georgia Tech Research Institute in Atl...
# 1740              Test Engineer salaries in Atlanta, GA
#
# [1741 rows x 1 columns]

# %%
pd.DataFrame(Bullets).to_csv('Bullets', index=False)
