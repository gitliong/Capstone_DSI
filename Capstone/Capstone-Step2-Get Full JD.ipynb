# %%
import requests
import bs4
from bs4 import BeautifulSoup
from time import sleep
import pandas as pd
import numpy as np

# %%
pd.read_csv('Capstone_v1')
# Out:
#      Unnamed: 0                                  location  \
# 0             0                               Atlanta, GA
# 1             1                               Atlanta, GA
# 2             2                               Atlanta, GA
# 3             3                         Atlanta, GA 30346
# 4             4                               Atlanta, GA
# 5             5      Atlanta, GA 30303 (Five Points area)
# 6             6         Atlanta, GA 30342 (Buckhead area)
# 7             7                     Johns Creek, GA 30097
# 8             8                               Atlanta, GA
# 9             9          Atlanta, GA 30309 (Midtown area)
# 10           10                               Atlanta, GA
# 11           11          Atlanta, GA 30309 (Midtown area)
# 12           12                               Atlanta, GA
# 13           13         Atlanta, GA 30301 (Buckhead area)
# 14           14                               Atlanta, GA
# 15           15                               Atlanta, GA
# 16           16                               Atlanta, GA
# 17           17                            Alpharetta, GA
# 18           18                               Atlanta, GA
# 19           19                      Alpharetta, GA 30005
# 20           20                               Atlanta, GA
# 21           21                               Atlanta, GA
# 22           22                               Atlanta, GA
# 23           23  Atlanta, GA 30308 (Old Fourth Ward area)
# 24           24  Atlanta, GA 30308 (Old Fourth Ward area)
# 25           25  Atlanta, GA 30308 (Old Fourth Ward area)
# 26           26      Atlanta, GA 30303 (Five Points area)
# 27           27                               Atlanta, GA
# 28           28                               Atlanta, GA
# 29           29          Atlanta, GA 30309 (Midtown area)
# ..          ...                                       ...
# 435         435         Atlanta, GA 30305 (Buckhead area)
# 436         436         Atlanta, GA 30318 (Rockdale area)
# 437         437         Atlanta, GA 30318 (Rockdale area)
# 438         438         Atlanta, GA 30318 (Rockdale area)
# 439         439         Atlanta, GA 30318 (Rockdale area)
# 440         440         Atlanta, GA 30318 (Rockdale area)
# 441         441                               Atlanta, GA
# 442         442         Atlanta, GA 30318 (Rockdale area)
# 443         443                        Norcross, GA 30092
# 444         444         Atlanta, GA 30318 (Rockdale area)
# 445         445         Atlanta, GA 30318 (Rockdale area)
# 446         446         Atlanta, GA 30318 (Rockdale area)
# 447         447         Atlanta, GA 30318 (Rockdale area)
# 448         448                               Atlanta, GA
# 449         449         Atlanta, GA 30318 (Rockdale area)
# 450         450         Atlanta, GA 30318 (Rockdale area)
# 451         451                               Atlanta, GA
# 452         452         Atlanta, GA 30318 (Rockdale area)
# 453         453         Atlanta, GA 30318 (Rockdale area)
# 454         454         Atlanta, GA 30318 (Rockdale area)
# 455         455         Atlanta, GA 30318 (Rockdale area)
# 456         456         Atlanta, GA 30318 (Rockdale area)
# 457         457         Atlanta, GA 30326 (Buckhead area)
# 458         458         Atlanta, GA 30318 (Rockdale area)
# 459         459         Atlanta, GA 30318 (Rockdale area)
# 460         460                         Atlanta, GA 30328
# 461         461                         Atlanta, GA 30319
# 462         462         Atlanta, GA 30318 (Rockdale area)
# 463         463                               Atlanta, GA
# 464         464                              Norcross, GA
#
#                                                  title  \
# 0                                       Data Scientist
# 1                                       Data Scientist
# 2                               CASE IT Data Scientist
# 3                               CASE IT Data Scientist
# 4                             Marketing Data Scientist
# 5                                       Data Scientist
# 6                                       Data Scientist
# 7                      Data Scientist (PYTHON, HADOOP)
# 8                                       Data Scientist
# 9    Fall 2018 Data Scientist/Machine Learning Inte...
# 10                                      Data Scientist
# 11                                      Data Scientist
# 12                       Data Scientist (Optimization)
# 13                                      Data Scientist
# 14                            Associate Data Scientist
# 15                                      Data Scientist
# 16                                      Data Scientist
# 17                                      Data Scientist
# 18                                      Data Scientist
# 19                                      Data Scientist
# 20                               Senior Data Scientist
# 21                    Data Scientist, Keying & Linking
# 22                                      DATA SCIENTIST
# 23          Data Scientist - Supply Chain Optimization
# 24                                   Data Scientist IV
# 25                             Advanced Data Scientist
# 26                                        Data Analyst
# 27                   Managing Director, Data Scientist
# 28                     Data Scientist Manager -Atlanta
# 29                               Senior Data Scientist
# ..                                                 ...
# 435                                     Data Scientist
# 436        Senior Machine Learning Researcher - CIPHER
# 437              Imaging Scientist/Engineer Sr. - EOSL
# 438                              Test Engineer - ELSYS
# 439                             System Engineer- ELSYS
# 440                         Software Engineer - CIPHER
# 441               Senior Business Intelligence Analyst
# 442                    Senior FPGA Researcher - CIPHER
# 443                                  Software Engineer
# 444        Systems Engineer (Research focused) - ELSYS
# 445  Digital Simulation and Modeling - Jr. Engineer...
# 446              Signal Modeling - Jr. Engineer - EOSL
# 447              Optical Scientist/Engineer, Sr - EOSL
# 448                                     Radar Engineer
# 449              Signal Processing Engineer Jr. - EOSL
# 450             Test Engineer (Advanced Degree) -ELSYS
# 451  Team Lead – Informatics. Sensus USA Inc. Atlan...
# 452          System Engineer (Advanced Degree) - ELSYS
# 453  Missile Warning System (MWS)/Sensor System Ana...
# 454                Senior Software Researcher - CIPHER
# 455           Senior FPGA Hardware Researcher - CIPHER
# 456   Full Stack Developer - GC Insights, New Ventures
# 457  Implementation Engineer (Machine Learning/Data...
# 458                Electrical/Computer Engineer - EOSL
# 459  Systems Engineer (Research focused - Senior) -...
# 460                                     Data Scientist
# 461          Sr. Staff Enterprise Application Engineer
# 462               Signal Processing Engineer Sr - EOSL
# 463  Post-Doctoral Fellow- Medical Imaging, Machine...
# 464                       Software Engineer - Big Data
#
#                                  company  salary  \
# 0                         Cox Automotive     NaN
# 1                                Equifax     NaN
# 2                                Daimler     NaN
# 3                 Mercedes-Benz USA, LLC     NaN
# 4                  UNITED PARCEL SERVICE     NaN
# 5                         Operation HOPE     NaN
# 6                               GreenSky     NaN
# 7                      SoftVision - TAMS     NaN
# 8                             United Way     NaN
# 9                  Norfolk Southern Corp     NaN
# 10                             SalesLoft     NaN
# 11                 Norfolk Southern Corp     NaN
# 12                        Cox Automotive     NaN
# 13                 The Coca-Cola Company     NaN
# 14                        Inspire Brands     NaN
# 15                      Hiscox Insurance     NaN
# 16                            Hiscox Ltd     NaN
# 17                      Scientific Games     NaN
# 18                           Relus Cloud     NaN
# 19                              McKesson     NaN
# 20                              Cotiviti     NaN
# 21                               Equifax     NaN
# 22                       Interface, Inc.     NaN
# 23                                   NCR     NaN
# 24                             Honeywell     NaN
# 25                             Honeywell     NaN
# 26                        Operation HOPE     NaN
# 27                              SunTrust     NaN
# 28                             Capgemini     NaN
# 29                 Norfolk Southern Corp     NaN
# ..                                   ...     ...
# 435                     Kaizen Resources     NaN
# 436      Georgia Tech Research Institute     NaN
# 437      Georgia Tech Research Institute     NaN
# 438      Georgia Tech Research Institute     NaN
# 439      Georgia Tech Research Institute     NaN
# 440      Georgia Tech Research Institute     NaN
# 441                       The Home Depot     NaN
# 442      Georgia Tech Research Institute     NaN
# 443                   Intuitive Surgical     NaN
# 444      Georgia Tech Research Institute     NaN
# 445      Georgia Tech Research Institute     NaN
# 446      Georgia Tech Research Institute     NaN
# 447      Georgia Tech Research Institute     NaN
# 448                    Radiant Solutions     NaN
# 449      Georgia Tech Research Institute     NaN
# 450      Georgia Tech Research Institute     NaN
# 451                                Xylem     NaN
# 452      Georgia Tech Research Institute     NaN
# 453      Georgia Tech Research Institute     NaN
# 454      Georgia Tech Research Institute     NaN
# 455      Georgia Tech Research Institute     NaN
# 456                   McKinsey & Company     NaN
# 457                           eHire, LLC     NaN
# 458      Georgia Tech Research Institute     NaN
# 459      Georgia Tech Research Institute     NaN
# 460                     Matrix Resources     NaN
# 461                     General Electric     NaN
# 462      Georgia Tech Research Institute     NaN
# 463                     Emory University     NaN
# 464                CareerBuilder Careers     NaN
#
#                                                summary           age  \
# 0                The Data Scientist, Data Solutions...  12 hours ago
# 1                Manipulate large data sets, integr...   2 hours ago
# 2                CASE IT Data Scientist. Data/ Insi...    2 days ago
# 3    Data/ Insights/ Analytics. Identify the necess...    2 days ago
# 4                Proficient in Python, R, and SQL. ...   17 days ago
# 5                Able to understand various data st...  30+ days ago
# 6    Data Science, Data Engineer, IT security. Data...    7 days ago
# 7                3-5 years of experience building l...  30+ days ago
# 8                The Data Scientist will be a part ...  30+ days ago
# 9                You will have the opportunity of w...    7 days ago
# 10               We are looking for a Data Scientis...  30+ days ago
# 11               Analysist, statistician, data scie...  30+ days ago
# 12               Cox Automotive is hiring a Data Sc...  30+ days ago
# 13               Excellent data wrangling skills; S...  30+ days ago
# 14   Data cleansing/processing work with IT to crea...   26 days ago
# 15               .*What you’ll be doing as a Data S...   27 days ago
# 16               What you’ll be doing as a Data Sci...   24 days ago
# 17               The Data Scientist offers expertis...    4 days ago
# 18               Experience using Python and/or R. ...  30+ days ago
# 19   Data Scientist to deliver results. The Data Sc...  30+ days ago
# 20               This is a pioneering data scientis...   21 days ago
# 21   Data Scientist, Keying & Linking. The Data Sci...  30+ days ago
# 22               The Data Scientist will analyze bu...  30+ days ago
# 23   Data Scientist - Supply Chain Optimization. Da...  30+ days ago
# 24   Data mining (including data auditing, aggregat...   25 days ago
# 25               The Advanced Data Scientist role i...   14 days ago
# 26               Able to understand various data st...  30+ days ago
# 27               Leverage data to fulfill business ...   12 days ago
# 28               (Includes Data Modeler, Data Miner...  30+ days ago
# 29               Analysist, statistician, data scie...   17 days ago
# ..                                                 ...           ...
# 435              Expertise in Python, R Programming...   17 days ago
# 436              Experience with machine learning d...    8 days ago
# 437              Sensor data fusion. Programming la...    8 days ago
# 438  Python or similar scripting language. Experien...    8 days ago
# 439              Experience processing and analyzin...    8 days ago
# 440  Python, Java, C languages, R. Experience with ...    8 days ago
# 441              VBA, Python, R, SAS, .NET, C++, Ja...    9 days ago
# 442              Real-time data processing and disp...    8 days ago
# 443              Test and maintain large databases ...    3 days ago
# 444              Proficient in the use of SAS JMP, ...    8 days ago
# 445              Experience with Python computer la...    8 days ago
# 446              Experience with Python computer la...    8 days ago
# 447              Programming languages such as Pyth...    8 days ago
# 448              Ability to code algorithms in MatL...  30+ days ago
# 449              Programming/scripting in Matlab, P...    8 days ago
# 450  Python or similar scripting language. Experien...    8 days ago
# 451              Supervise 4-6 peer Data Scientists...   24 days ago
# 452              Experience processing and analyzin...    8 days ago
# 453              Experience with Python computer la...    8 days ago
# 454              Demonstrated experience with algor...    8 days ago
# 455              Design experience with high-speed ...    8 days ago
# 456              Expert in Python, Ruby, JavaScript...  30+ days ago
# 457              Developing plugin modules e.g. for...  30+ days ago
# 458              Programming/scripting in Matlab, P...    8 days ago
# 459              Proficient in the use of SAS JMP, ...    8 days ago
# 460              Experience with Python. A healthca...   11 days ago
# 461              Understanding of data concepts suc...  30+ days ago
# 462              Programming/scripting in Matlab, P...    8 days ago
# 463              Proficiency in programming using M...  30+ days ago
# 464              Experience with Python. Working wi...  30+ days ago
#
#                                                  slugs
# 0    /rc/clk?jk=c0618bda0bf8c511&fccid=7e465a3d521b...
# 1    /rc/clk?jk=359d80a34b608d3f&fccid=34c446722f3c...
# 2    /rc/clk?jk=9fee707bdf662376&fccid=b25343f021fb...
# 3    /rc/clk?jk=9a790788254969bd&fccid=33fa1494c1a3...
# 4    /rc/clk?jk=ef88de074a659510&fccid=fcf465e707df...
# 5    /company/Operation-Hope/jobs/Data-Scientist-a5...
# 6    /rc/clk?jk=de87370f2e4d08c3&fccid=03416f3f2828...
# 7    /rc/clk?jk=f346febd67aa1e7b&fccid=8e4ade64e8fe...
# 8    /rc/clk?jk=136fd5bfe081ef13&fccid=475449500ecd...
# 9    /rc/clk?jk=105f1bdc8b3513d3&fccid=2fc6cbacc711...
# 10   /rc/clk?jk=be06770fb79b4ce2&fccid=de4fd2d39ebd...
# 11   /rc/clk?jk=77f9a60cc7638509&fccid=2fc6cbacc711...
# 12   /rc/clk?jk=5d5f057a6251d7ab&fccid=7e465a3d521b...
# 13   /rc/clk?jk=1761018962b52cb3&fccid=681e47a680e0...
# 14   /rc/clk?jk=95accded62a0b1c6&fccid=1b082641b237...
# 15   /company/Hiscox-Insurance/jobs/Data-Scientist-...
# 16   /rc/clk?jk=c430f2244f15b3f8&fccid=9700fa012753...
# 17   /rc/clk?jk=fe8f5a93ffc0e62c&fccid=c84a7d17b9b1...
# 18   /rc/clk?jk=c9f6c48154ce1aab&fccid=72a09225e708...
# 19   /rc/clk?jk=564fdd48f94badc0&fccid=a7c503661840...
# 20   /rc/clk?jk=74e9c9246f6aea68&fccid=341483645418...
# 21   /rc/clk?jk=eb30d3c0023a2b32&fccid=34c446722f3c...
# 22   /rc/clk?jk=02e825cc6de11f7c&fccid=649907072be3...
# 23   /rc/clk?jk=cdbf7b45694e5fa7&fccid=50597ebf467e...
# 24   /rc/clk?jk=1b62f899d9d7a1e8&fccid=50208b5bf45e...
# 25   /rc/clk?jk=4e5ab824ffe5b9c2&fccid=50208b5bf45e...
# 26   /company/Operation-Hope/jobs/Data-Analyst-6866...
# 27   /rc/clk?jk=9b2f20f7dc5ff12d&fccid=131f8387a45b...
# 28   /rc/clk?jk=50a93a24ad24af5d&fccid=105ecfd0283f...
# 29   /rc/clk?jk=fdcfb95c09832170&fccid=2fc6cbacc711...
# ..                                                 ...
# 435  /rc/clk?jk=5e13bc19faf58976&fccid=85235510a36b...
# 436  /rc/clk?jk=cadabf21d9021246&fccid=db25687464a9...
# 437  /rc/clk?jk=8ddd1cb63bbb1a22&fccid=db25687464a9...
# 438  /rc/clk?jk=a5987b317f2f2971&fccid=db25687464a9...
# 439  /rc/clk?jk=3ad86f86a02d0830&fccid=db25687464a9...
# 440  /rc/clk?jk=77af9c4ac1e06c08&fccid=db25687464a9...
# 441  /rc/clk?jk=51f79014ccf5171c&fccid=82e58e9861d4...
# 442  /rc/clk?jk=2cea4f5d674449da&fccid=db25687464a9...
# 443  /rc/clk?jk=98feaaf96466e372&fccid=485155ca34f4...
# 444  /rc/clk?jk=8c8f9aa4c32828c5&fccid=db25687464a9...
# 445  /rc/clk?jk=380747de05497340&fccid=db25687464a9...
# 446  /rc/clk?jk=682497d57469e742&fccid=db25687464a9...
# 447  /rc/clk?jk=6873777ae9347be6&fccid=db25687464a9...
# 448  /rc/clk?jk=57b0a2b0ce059899&fccid=9ab933a50b7d...
# 449  /rc/clk?jk=8c8eaf1d8b95e3ef&fccid=db25687464a9...
# 450  /rc/clk?jk=4782840cb94d0988&fccid=db25687464a9...
# 451  /rc/clk?jk=4b217b5c630e09c8&fccid=68ec8a8ee6cf...
# 452  /rc/clk?jk=2203debe80b889d2&fccid=db25687464a9...
# 453  /rc/clk?jk=8b6989e904aa26e7&fccid=db25687464a9...
# 454  /rc/clk?jk=c8809d7ef3e5153b&fccid=db25687464a9...
# 455  /rc/clk?jk=6dd8dd885c22888a&fccid=db25687464a9...
# 456  /rc/clk?jk=70f80d98b46888b9&fccid=6576e7250aa7...
# 457  /rc/clk?jk=49923a6dabff2511&fccid=2d05fe1a595c...
# 458  /rc/clk?jk=9f2b4f2db9957544&fccid=db25687464a9...
# 459  /rc/clk?jk=501a8c129ff45082&fccid=db25687464a9...
# 460  /rc/clk?jk=ae86cea979aa8597&fccid=22b65342d3dd...
# 461  /rc/clk?jk=1b3ca80cb3a624ea&fccid=53c1573dc4db...
# 462  /rc/clk?jk=a7b2787a758b56c5&fccid=db25687464a9...
# 463  /rc/clk?jk=6d8c755b3a8a4572&fccid=efe5e2d22a1d...
# 464  /rc/clk?jk=914d2d48aa6dc162&fccid=0d56ca7b1c76...
#
# [465 rows x 8 columns]

# %%
df = pd.read_csv('Capstone_v1')

# %%
slugs = df['slugs']

# %%
slugs[:10]
# Out:
# 0    /rc/clk?jk=c0618bda0bf8c511&fccid=7e465a3d521b...
# 1    /rc/clk?jk=359d80a34b608d3f&fccid=34c446722f3c...
# 2    /rc/clk?jk=9fee707bdf662376&fccid=b25343f021fb...
# 3    /rc/clk?jk=9a790788254969bd&fccid=33fa1494c1a3...
# 4    /rc/clk?jk=ef88de074a659510&fccid=fcf465e707df...
# 5    /company/Operation-Hope/jobs/Data-Scientist-a5...
# 6    /rc/clk?jk=de87370f2e4d08c3&fccid=03416f3f2828...
# 7    /rc/clk?jk=f346febd67aa1e7b&fccid=8e4ade64e8fe...
# 8    /rc/clk?jk=136fd5bfe081ef13&fccid=475449500ecd...
# 9    /rc/clk?jk=105f1bdc8b3513d3&fccid=2fc6cbacc711...
# Name: slugs, dtype: object

# %%
extended_descriptions = []

list_of_dicts = []

# %%
for r in slugs[:10]:
    new_url = 'http://www.indeed.com' + r
    print('Requesting content from ' + new_url) # you can add + '...' 
    res = requests.get(new_url)
    # print('Converting content from the res object.')
    soup = BeautifulSoup(res.content, 'lxml')
    extended_descriptions.append(soup)
    sleep(3)
    print('Appending soup...')
# Out:
# Requesting content from http://www.indeed.com/rc/clk?jk=c0618bda0bf8c511&fccid=7e465a3d521b3ac3&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=359d80a34b608d3f&fccid=34c446722f3cf576&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=9fee707bdf662376&fccid=b25343f021fb51d7&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=9a790788254969bd&fccid=33fa1494c1a3ee87&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=ef88de074a659510&fccid=fcf465e707df52fb&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/company/Operation-Hope/jobs/Data-Scientist-a5c0540250e41a45?fccid=63e09b63b5df262b&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=de87370f2e4d08c3&fccid=03416f3f2828f00b&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=f346febd67aa1e7b&fccid=8e4ade64e8feb2ea&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=136fd5bfe081ef13&fccid=475449500ecde065&vjs=3
# Appending soup...
# Requesting content from http://www.indeed.com/rc/clk?jk=105f1bdc8b3513d3&fccid=2fc6cbacc7119b63&vjs=3
# Appending soup...

# %%
list_of_dicts
# Out:
# []

# %%
len(extended_descriptions)
# Out:
# 10

# %%
for each in extended_descriptions:
    print(type(each))
# Out:
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.BeautifulSoup'>

# %%
for page in extended_descriptions:
    for each in page.find_all('b'):
        print(each.get_text())
# Out:
# Data Scientist
# Description
#
# Technology We Use:
#
# Your Role:
#
# Qualifications
# Required Experience (minimum):
#
# What We Look For (preferred):
#
# About Cox Automotive
#
# Organization:
# Primary Location:
# Employee Status:
# Job Level:
# Shift:
# Travel:
# Schedule:
# Unposting Date:
# Data Scientist
# Job Number:
# Position Title:
# External Description:
# Desired Skills and Experience:
# Preferred Skills and Experience:
# Primary Location:
# Function:
# Schedule:
# City:
# Location_formattedLocationLong:
# State:
# Community / Marketing Title:
# Company Profile:
# Requisition Number:
# EEO Employer Verbiage:
# CASE IT Data Scientist
#
# About Us
#
# Job Overview
#
#
# Responsibilities:
#
#
#
# Education
#
# Bachelor’s Degree (accredited school)
# or equivalent work experience with emphasis in:
#
# Must have
# 5 + years (total)
#  of experience in the following:
#
# Additional Skills
#
# Additional Information
# EEO Statement
# CASE IT Data Scientist
# Aufgaben
# Qualifikationen
# Marketing Data Scientist
# Data Scientist
# DEPARTMENT
# POSITION LOCATIONS
# :
# ACCOUNTABILITY
# :
# JOB SUMMARY
# DUTIES AND RESPONSIBILITIES
# REQUIRED SKILLS AND EDUCATION
# EEO
# STATEMENT
# Data Scientist
# Job Description:
# We strongly encourage Armed Forces Veterans to apply
# Data Scientist (PYTHON, HADOOP)
# Data Scientist
#
# Essential Duties:
# Qualifications
# Fall 2018 Data Scientist/Machine Learning Internship
# A Day in the Life of an Operations Research Intern
# What Makes a Successful Co-Op/Intern?
# Education/Experience
# Compensation
# Company Overview

# %%
for page in extended_descriptions:
    for each in page.find_all('p'):
        print(each.get_text())
# Out:
# About Cox Automotive
#
# Cox Automotive is transforming the way the world buys, sells and owns cars with industry-leading digital marketing, retail, financial and wholesale solutions for consumers, dealers, manufacturers and the overall automotive ecosystem worldwide. The Cox Automotive family includes Autotrader®, Dealer.com®, Dealertrack®, Kelley Blue Book®, Manheim®, NextGear Capital®, vAuto®, VinSolutions®, Xtime®, incadea®, and a host of other brands. With a complete and connected view of the automotive ecosystem, Cox Automotive is a global company connecting people, cars and capabilities with services that link the automotive value chain. Cox Automotive is a subsidiary of Cox Enterprises. For more information about Cox Automotive, visit www.coxautoinc.com.
#
# Cox is an Equal Employment Opportunity employer - All qualified applicants/employees will receive consideration for employment without regard to that individual’s age, race, color, religion or creed, national origin or ancestry, sex (including pregnancy), sexual orientation, gender, gender identity, physical or mental disability, veteran status, genetic information, ethnicity, citizenship, or any other characteristic protected by law.
# CASE IT Data Scientist
#
# About Us
# Mercedes-Benz USA, headquartered in Atlanta, GA is responsible for the sales, marketing and service of all Mercedes-Benz and Maybach products in the United States. In our people, you will find tremendous commitment to our corporate values: 'PRIDE = Passion, Respect, Integrity, Discipline, and Execution'. Our products and employees reflect this dedication. We are looking for diverse top-notch individuals to join the Mercedes-Benz Team and uphold these hallmarks.
# EEO Statement
# Mercedes-Benz USA is committed to fostering an inclusive environment that appreciates and leverages the diversity of our team. We provide equal employment opportunity (EEO) to all qualified applicants and employees without regard to race, color, ethnicity, gender, age, national origin, religion, marital status, veteran status, physical or other disability, sexual orientation, gender identity or expression, or any other characteristic protected by federal, state or local law.
# We know salary is a key component of your decision whether or not to apply for a job. So when the hiring company hasn’t provided a salary for a job, we look at salary data from related companies and locations to come up with a reasonable estimate for what you can expect.
# With over 450,000,000 salaries collected from other jobs and employees, we use one of the biggest salary databases in the world to inform these estimates. And because we are continually adding feedback from users like you, we are able to keep refining our accuracy.
# These salary estimates are not endorsed by the hiring companies and may vary from what’s actually offered, but we have a pretty great record of getting close enough for you to make an informed decision.
# Is this your job listing? Send us feedback to correct an inaccurate salary estimate.
# DEPARTMENT: HOPE Research Institute
# POSITION LOCATIONS: Atlanta, GA.
# ACCOUNTABILITY:  Senior VP, HOPE Research Institute
# For 25 years Operation HOPE has been dedicated to empowering underserved communities through financial literacy, now our work encompasses more than financial education. Our work is about instilling knowledge and confidence in those we serve so they can experience, sometimes for the first time in their lives, financial dignity.
# JOB SUMMARY
# Operation HOPE is currently in need of a Data Scientist to join our fast-growing team. The ideal candidate will use his/her analytical, statistical and programming skills to collect, analyze and interpret Operation HOPEâ€™s data sets to help drive improved product performance, increase customer satisfaction and reduce cost of operation. The data scientist will be intricately involved in analyzing programmatic data to inform operational practices, conducting analytical experiments in a methodical manner, and will regularly evaluate alternate models via theoretical approaches.
# The Data Scientist is responsible to help understand operational needs, working with the field supervisors, head of quality and other department leaders as required. Using that knowledge, this position will drive a data-driven solution to solving broad and complex inefficiencies. Additionally, the Data Scientist may be called on to help cross-functional efforts to model large data sets and will work with other technical departments to enhance process control both internally and externally. This is the perfect opportunity for the successful candidate to become a part of an innovative non-profit team that develops analysis tools that will change the world and uplift underserved communities.
# DUTIES AND RESPONSIBILITIES
# REQUIRED SKILLS AND EDUCATION
# EEOSTATEMENT
# Operation HOPE is an Equal Opportunity Employer, all qualified applicants will receive consideration for employment without regard to race, color, religion, sex, age, national origin, protected veteran status, disability status, sexual orientation, gender identity or expression, marital status, genetic information or any other characteristic protected by law.
# Job Type: Full-time
# Experience:
# Education:
# Location:
# Required work authorization:
# Apply Now
#
#             Please review all application instructions before applying to Operation HOPE.
#
# (function(){var a=window.indeed;
#             if(!a||!a.ia){
#             var b=window,
#                 c=document.location,
#                 e=document.getElementsByTagName("head")[0],
#                 f=/^https:\/\//.test(c.href),
#                 g=document.createElement("script"),
#                 h=document.getElementById("indeed-apply-js").attributes["data-indeed-apply-qs"],
#                 n=h&&h.value?h.value:"";
#             b.indeed=b.indeed||{};b.indeed.ia=b.indeed.ia||{};
#             g.src=(f?
#         "https://apply.indeed.com/indeedapply/env?https=1&iip=1&":"https://apply.indeed.com/indeedapply/env?iip=1&")+"ms="+ +new Date+(n?"&"+n:"");e.appendChild(g)};})();
# GreenSky is a leading company in the consumer finance marketplace specializing in Home Improvement, Retail and Health Care Credit.
#
# Since 2006, our company’s people, process and technology solutions have played a critical role in transforming business and consumer credit, enabling more affordable and pervasive access to financing. We have built relationships with dealers, retailers and merchants in all 50 states by providing their customers loans through our bank partnerships. We service our bank partners’ portfolios through an exceptional loan servicing organization, which is SSAE 16 Type II compliant. Our corporate headquarters is located in Atlanta, Georgia with a second operational facility in Covington, Kentucky.
#
# GreenSky is looking for a Data Scientist to join the Consumer and Brand Protection Team within our Corporate Security Organization. The ideal candidate has the mind of hacker and the heart of a teacher. Do you enjoy approaching difficult problems using the scientific method and statistical methods? Do you get excited about reproducible results? If so keep reading!
#
# As a Data Scientist on the GS Security team you will collect, curate and analyze data from a large number of sources to investigate user behavior and to detect outliers symptomatic of malicious activity. Develop, maintain and deploy machine learning models based on said data to catch bad actors in real time. Stay current with modern machine learning methods by researching white papers and look for innovative ways to help us stop bad user behavior and detect process gaps.
#
# The successful candidate will be an expert in developing mathematical models, have a strong mathematical background. Be familiar with building and scoring efficacy of machine learning models, Linux command line and distributed systems such as Hadoop.
#
# Duties & Responsibilities:
#
#
# Required Experience:
#
#
# Core Qualifications:
#
# We are looking for a candidate with 5+ years of combined experience in analytics, scripting and applied mathematics who has attained a Bachelor’s degree or higher in Computer Science, Mathematics or Physics.
#
# Desirable Qualifications:
#
#
#
# We strongly encourage Armed Forces Veterans to apply
#
# Keyword: Data Science, Data Engineer, IT security
# From: GreenSky
# Apply Now
#
#             Please review all application instructions before applying to GreenSky.
#
# (function(){var a=window.indeed;
#             if(!a||!a.ia){
#             var b=window,
#                 c=document.location,
#                 e=document.getElementsByTagName("head")[0],
#                 f=/^https:\/\//.test(c.href),
#                 g=document.createElement("script"),
#                 h=document.getElementById("indeed-apply-js").attributes["data-indeed-apply-qs"],
#                 n=h&&h.value?h.value:"";
#             b.indeed=b.indeed||{};b.indeed.ia=b.indeed.ia||{};
#             g.src=(f?
#         "https://apply.indeed.com/indeedapply/env?https=1&iip=1&":"https://apply.indeed.com/indeedapply/env?iip=1&")+"ms="+ +new Date+(n?"&"+n:"");e.appendChild(g)};})();
# The Data Scientist will be a part of the data management and integration team to analyze public, proprietary and collaborative data sets and develop data-driven solutions to business challenges. The data scientist will work closely with the Community Engagement team, including Community Investment, Strategy and Knowledge, Partner Engagement, and Monitoring and Evaluation, to develop data models, perform data mining, visualize data and generate reports and dashboard to convey United Way of Greater Atlanta's CWB strategies and accomplishments to our stakeholders.
#
# Essential Duties:
# Qualifications
# Requisition 10254: Fall 2018 - Operations Research/Data Scientist
# Posting Start Date: 06/12/2018
# Posting End Date: 08/01/2018
# A Day in the Life of an Operations Research Intern
#
# As a Data Scientist/Machine Learning Intern, you will be working with a team of Data Science professionals who apply various cutting edge machine learning and statistical techniques to real-life use-cases and provide actionable insights to the business. You will have the opportunity of working with Norfolk Southern’s big data analytics platform and mine massive amounts of data using various toolsets like R, Python, Spark, TensorFlow, Keras, OpenCV, Hive, etc.
# What Makes a Successful Co-Op/Intern?
# Education/Experience
#
# Compensation
# Norfolk Southern Corporation (NYSE: NSC) is one of the nation’s premier transportation companies. Its Norfolk Southern Railway Company subsidiary operates approximately 19,500 route miles in 22 states and the District of Columbia, serves every major container port in the eastern United States, and provides efficient connections to other rail carriers. Norfolk Southern operates the most extensive intermodal network in the East and is a major transporter of coal, automotive, and industrial products.
#
# We are a team of more than 28,000 employees working together to maintain our reputation as "The Thoroughbred of Transportation". As an industry leader, Norfolk Southern offers a competitive salary and an excellent benefits package.
# Norfolk Southern is an equal opportunity employer including veterans and disabled.

# %%
for page in extended_descriptions:
    for each in page.find_all('li'):
        print(each.get_text())
# Out:
# Develop a deep understanding of the primary Cox Automotive data assets—Consumer, Client, and Vehicle—and work with business and product stakeholders to extract value from them.
#
# Interpret business problems and develop effective solutions using data analysis, statistics, data mining, and machine learning techniques.
#
# Design large-scale models using Logistic Regression, Linear Models Family (Poisson models, Survival models, Hierarchical Models, Naïve-Bayesian estimators), Conjoint Analysis, Spatial Models, and Time-Series Models.
#
# Develop predictive and prescriptive models and decisions tools.
#
# Familimarity with AWS technologies such as EMR, Spark, and SageMaker.
#
# Experience deploying and maintaining models in production.
#
# Communicate findings to team members and leadership.
#
# 5+ years’ experience performing advanced quantitative analyses
#
# A strong passion for empirical research and for answering hard questions with data.
#
# Experience with the application of basic statistical techniques to real-world problems, including data sampling, distribution fitting, hypothesis testing, and linear regression.
#
# Ability to apply advanced statistical methodologies such as mixed model (random and fixed effects), simultaneous equations, ARIMA, neural networks, and multinomial discrete choice
#
# Ability to apply mathematical operations to such tasks as cluster analytics, sampling theory and design of experiments, analysis of variance, correlation techniques, and factor analysis
#
# Working knowledge of a statistical software package (e.g. SAS, R).
#
# Proficiency in Python or Scala.
#
# Intermediate to advanced SQL knowledge.
#
# A desire to learn new technologies and data science techniques.
#
# BS, MS, or P.D in computer science, engineering, math, statistics, operations research, or similar.
#
# Automotive industry domain knowledge preferable.
#
# Data Scientist jobs in Atlanta, GA
#
#
# Jobs at Cox Automotive in Atlanta, GA
#
#
# Data Scientist salaries in Atlanta, GA
#
#
# Data Scientist jobs in Atlanta, GA
#
#
# Jobs at Equifax in Atlanta, GA
#
#
# Data Scientist salaries in Atlanta, GA
#
#  Support the CASE (Connected, Autonomous, Shared, Electric) business departments monetize data and create Value from data. The focus is working with both IT and the business on identifying and implementing relevant use cases with customer impact to produce advanced analytics solution.
#  Identify the necessary data, undertake data acquisition and exploration, including data harmonization and normalization of CASE solutions for internal and external partners.
#
#  Recommend and develop their automated integration into result driven forms.
#  Enable the integration of analysis and prediction results to be used into relevant channels and applications (such as Next Best Action / Next Best Offer).
#  Utilize all the relevant and necessary tools (for example, R, Spark, Scala, Hadoop, Tableau, Alteryx, SQL) to configure, manipulate and design visual modules to support analysis.
#  Monitor performance and quality control plans to identify improvements.
#
#  Coordinate with CASE IT, the business and external partners to develop and implement data analysis, data collection systems and other strategies that optimize statistical efficiency and quality to drive business decisions.
#
#  Mathematics
#
#  Economics
#  Information Management
#  Statistics
#  Computer/Information Science
#  Information Technology
#  Data/ Insights/ Analytics
#
#  Extensive experience working with the relevant tools in the context of data integration, data analysis and predictive modeling
#  Familiar with DevOps and agile development
#  Comprehensive experience using SQL and scripting languages such as R, Python and Scala etc.
#  A deep understanding of machine learning models, mastering R and Python and have worked with tools like Azure ML, Spark ML, Mahout, Mllib, RapidMiner, MATLAB, etc.
#  Experiences with methods such as recommendation logic and contextual and behavioral targeting are optimal
#  Familiar with tools like Hadoop, MongoDB, BigQuery and Spark
#  Know-how on Insights visualization and insights storytelling (D3.js, JS Sharting Libraries) as well as actionable insights (prescriptive analytics)
#  Experience with Tableau
#  Comprehensive knowledge of Agile methods and agile project procedures
#  Relevant practice experience with data-based business models
#  Strong conceptual thinking ability
#  Strong analytical, problem-solving and decision-making capabilities with the ability to analyze situations, identify existing or potential problems and recommend solutions
#  Excellent leadership and influencing skills to drive adoption of consistent processes, methodology and practices throughout the IT department
#  Superior interpersonal skills including courtesy, professionalism and a cooperative attitude
#  Demonstrated outstanding level of professionalism in providing management support, including ability to exercise good judgment, discretion, tact and diplomacy
#  Succinct, direct and grammatically correct communication skills are a must
#  Outstanding presentation skills. Previous teaching or facilitation experience is a plus
#  Demonstrated ability to supervise and motivate a team to gain credibility within the organization
#  Customer-service driven
#  Energetic self-starter with a positive attitude and the ability to be resourceful
#  Thrive in a dynamic, fast-paced environment where you must take on multiple responsibilities and do what it takes to get things done
#  Excellent relationship building/partnering skills
#
# Case IT Data Scientist jobs in Atlanta, GA
#
#
# Jobs at Daimler in Atlanta, GA
#
#
# Case IT Data Scientist salaries in Atlanta, GA
#
# Support the CASE (Connected, Autonomous, Shared, Electric) business departments monetize data and create Value from data. The focus is working with both IT and the business on identifying and implementing relevant use cases with customer impact to produce advanced analytics solution.
# Identify the necessary data, undertake data acquisition and exploration, including data harmonization and normalization of CASE solutions for internal and external partners.
# Recommend and develop their automated integration into result driven forms.
# Enable the integration of analysis and prediction results to be used into relevant channels and applications (such as Next Best Action / Next Best Offer).
# Utilize all the relevant and necessary tools (for example, R, Spark, Scala, Hadoop, Tableau, Alteryx, SQL) to configure, manipulate and design visual modules to support analysis.
# Monitor performance and quality control plans to identify improvements.
# Coordinate with CASE IT, the business and external partners to develop and implement data analysis, data collection systems and other strategies that optimize statistical efficiency and quality to drive business decisions.
# Mathematics
# Economics
# Information Management
# Statistics
# Computer/Information Science
# Information Technology
# Data/ Insights/ Analytics
# Extensive experience working with the relevant tools in the context of data integration, data analysis and predictive modeling
# Familiar with DevOps and agile development
# Comprehensive experience using SQL and scripting languages such as R, Python and Scala etc.
# A deep understanding of machine learning models, mastering R and Python and have worked with tools like Azure ML, Spark ML, Mahout, Mllib, RapidMiner, MATLAB, etc.
# Experiences with methods such as recommendation logic and contextual and behavioral targeting are optimal
# Familiar with tools like Hadoop, MongoDB, BigQuery and Spark
# Know-how on Insights visualization and insights storytelling (D3.js, JS Sharting Libraries) as well as actionable insights (prescriptive analytics)
# Experience with Tableau
# Comprehensive knowledge of Agile methods and agile project procedures
# Relevant practice experience with data-based business models
# Strong conceptual thinking ability
# Strong analytical, problem-solving and decision-making capabilities with the ability to analyze situations, identify existing or potential problems and recommend solutions
# Excellent leadership and influencing skills to drive adoption of consistent processes, methodology and practices throughout the IT department
# Superior interpersonal skills including courtesy, professionalism and a cooperative attitude
# Demonstrated outstanding level of professionalism in providing management support, including ability to exercise good judgment, discretion, tact and diplomacy
# Succinct, direct and grammatically correct communication skills are a must
# Outstanding presentation skills. Previous teaching or facilitation experience is a plus
# Demonstrated ability to supervise and motivate a team to gain credibility within the organization
# Customer-service driven
# Energetic self-starter with a positive attitude and the ability to be resourceful
# Thrive in a dynamic, fast-paced environment where you must take on multiple responsibilities and do what it takes to get things done
# Excellent relationship building/partnering skills
#
# Case IT Data Scientist jobs in Atlanta, GA
#
#
# Jobs at Mercedes-Benz USA in Atlanta, GA
#
#
# Case IT Data Scientist salaries in Atlanta, GA
#
#
# Marketing Data Scientist jobs in Atlanta, GA
#
#
# Jobs at UNITED PARCEL SERVICE in Atlanta, GA
#
#
# Marketing Data Scientist salaries in Atlanta, GA
#
# Work with stakeholders in Quality Assurance and throughout the organization to identify opportunities for leveraging company data to drive services and process improvement solutions
# Provide meaningful data analyses and reports to field operations leadership to assist in service evaluation
# Mine and analyze data from company databases to drive optimization and improvement of product and process performance
# Assess the effectiveness and accuracy of new data sources and data gathering techniques
# Use predictive modeling to increase and optimize client experiences
# Coordinate with different teams to implement models and monitor outcomes
# Develop processes and tools to monitor and analyze model performance and data accuracy
# Initiate and participate in projects in the area of prediction, optimization, and processes using advanced statistical / mathematical approaches
# Implement most recent algorithms and approaches for machine learning in collaboration with our researchers
# Design best architecture and select the most appropriate modeling techniques and data visualization for big data analysis
# Iteratively test, refine and improve the models
# Conduct research and make recommendations on data mining products, protocols, services, and standards in support of procurement and development efforts.
# Learn quickly new mathematical or technical methods
# Ph.D. or MS in Computer Science, Engineering, Statistics, Applied Math or related quantitative topics
# Able to understand various data structures and common methods in data transformation
# Experience in statistical modeling, machine learning, or data mining practice
# Experience in SQL, relational databases, database concepts, dimensional modeling and database design
# Proficient in one or more programming languages such as Java, C++, Python, JavaScript
# Strong analytical and quantitative problem solving ability
# Excellent communication, relationship skills and a strong team player
# Experience with BI softwares
# Proficient in STATA
# STATA: 2 years
# Statistical modeling and data mining: 2 years
# BI softwares: 2 years
# SQL, relational databases, and database design: 2 years
# Programming languages such as Java, C++, Python, JavaScript: 2 years
# Master's
# Atlanta, GA
# United States
# Responsible for end to end data science program on a small agile data team
#
# Identify features that will be valuable for detection methods
#
# Clean and enhance data elements for analysis
#
# Develop and tune ML models on regular training cycles for constant improvement
#
# Utilize feedback of model performance to improve future models
#
# Research and innovate new methods and procedures (reading academic papers strongly encouraged)
#
# Perform ad-hoc investigations when new information is discovered
#
# Document data science programs from stem to stern, data collection to actionable alerts
#
# Report findings to officers at the executive level
#
# Participate in weekly standups
# Degree in Mathematics, Physics or Computer Science
#
# Linux command line
#
# Strong scripting in bash, python or similar
#
# Experience developing data pipelines
#
# Experience machine learning methods
#
# Strong mathematical background (linear algebra, probability and statistics, calculus)
#
# Basic database experience in any SQL-like language
#
# Data visualization methods
#
# Classification and regression
#
# Error analysis
#
# Graph analysis
#
# Correlation methods
#
# Excellent communication skills
# Distributed systems such as Hadoop, Ambari
#
# Distributed databases (Hive, Accumulo)
#
# Elastic search
#
# Experience with Java or Scala and JVM
#
# Docker
#
# sed, awk
# 5-7 years of Data Modeling and Machine Learning Experience
# 5-7 years of Python & R- Language Experience
# 5-7 years of HADOOP-BIGDATA experience
# Proficiency dealing with extraction and manipulation of relational databases (SQL)
# 3 -5 years of experience in advanced statistical techniques such as predictive statistical models, customer profiling, segmentation analysis survey design and analysis and data mining
# 3-5 years of experience of learning systems to analyze and filter continuous data flows.
# 3-5 years of experience of analyzing large data sets to develop custom models and algorithms to drive business solutions.
# 3-5 years of experience building large data sets from multiple sources to build algorithms for predicting future data characteristics.
# Experience developing custom data models to drive recommendations.
# Experience working in a cross-functional environment.
# Excellent Communication Skills
# Good Team Player
# Able to work independently with minimum guidance
#
# Data Scientist jobs in Johns Creek, GA
#
#
# Jobs at SoftVision in Johns Creek, GA
#
#
# Data Scientist salaries in Johns Creek, GA
#
#
# Serve as the primary data analyst for Community Engagement
# Work closely with the Community Engagement team, including Community Investment, Strategy and Knowledge, Partner Engagement, and Monitoring and Evaluation, to develop data models, perform data mining, visualize data and generate reports and dashboard
# Responds to requests and produces reports based on the needs and strategic priorities of Community Engagement
# Collaborate with stakeholders throughout the organization to identify opportunities for leveraging internal and external data to drive business solutions
# Mine and analyze both internal and external data to drive optimization and improvement of community engagement, donor engagement and overall Child Well-Being mission
# Develop reports and analysis that align with anticipated programmatic outcomes, grantee financial information and volunteer assessments
# Assess the effectiveness and accuracy of internal and external data sources and data gathering techniques
# Develop custom data models and algorithms to apply to data sets
# Use predictive modeling to increase and optimize customer experiences and business outcomes
# Develop processes and tools to monitor and analyze model performance and data accuracy
# Present intuitive results and solutions to key stakeholders, including Board of Directors, Leadership Councils and subcommittees
#
# Bachelor Degree in Computer Science, Statistics, Applied Math or related field
# Extensive experience with statistical computer languages (R, Python, etc.) and database querying language (SQL) to manipulate data and draw insights from large data sets
# Extensive background in statistical analysis and data mining
# Experience with various data structures and common methods in data transformation
# Excellent pattern recognition and predictive modeling skills
# Experience with Microsoft SQL Server and PowerBI
# Experience with applying machine learning methods to develop business insights
# Experience with geo-spatial analysis tools such as Esri ArcGIS Online
# Experience and understanding with programmatic, human and social sector data
# Demonstrated experience working with large academic, government and proprietary data sets
# Strong time management skills and the ability to work on multiple projects simultaneously
# Strong written and oral communications skills
#
# Data Scientist jobs in Atlanta, GA
#
#
# Jobs at United Way in Atlanta, GA
#
#
# Data Scientist salaries in Atlanta, GA
#
# Proven statistical/mathematical and analytical skills; coursework in Machine Learning and statistics
# Proficiency in R and/or Python
# Knowledge of a general programming language like C++ or Java is a plus
# Knowledge of one or more of the following: Gradient Boosting Machines, Random Forests, Neural Networks, or other classification or regression models
# Excellent communication and interpersonal skills
# Ability to work in a team environment as well as working independently
# Pursuing a Master’s/PhD Degree
# Preferred Degree Paths: Data Science, Operations Research, Computer Science, Management Science and Statistics, and majors in a similar field of study
#
# Preferred Degree Paths: Data Science, Operations Research, Computer Science, Management Science and Statistics, and majors in a similar field of study
# Freshman (27 or fewer credits) - $2,500/month
# Sophomore (28 to 59 credits) - $2,800/month
# Junior (60 to 89 credits) - $3,000 /month
# Senior (90 or more credits) - $3,300/month
# Graduate Student - $3,666/month
# Living stipend of $850/month is available to those who qualify.
#
# Jobs at Norfolk Southern in Atlanta, GA
