# %% [markdown]
# # Poe or Austen?
#
# This notebook scrapes *The Purloined Letter* by Edgar Allen Poe and *Pride and Prejudice* by Jane Austen, then cleans the text up a bit. It then uses a pipeline to test CountVectorizer and TfidfVectorizer, then investigates coefficients.

# %%
import re
import requests

import pandas as pd

from bs4 import BeautifulSoup
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer

from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline

# %%
# URLs
poe_url = 'http://www.gutenberg.org/files/2148/2148-0.txt'
austen_url = 'http://www.gutenberg.org/files/1342/1342-0.txt'

# %%
# get and set up austen
res = requests.get(austen_url)
assert str(res) == '<Response [200]>'
austen = res.content.decode("utf-8-sig")

# %%
# clean austen
austen = austen[austen.find('By Jane Austen'):austen.find('End of the Project Gutenberg EBook of Pride and Prejudice')]
austen_list = austen.replace('\r', '').split('\n')
austen_list = [each for each in austen_list if each != '']
austen_df = pd.DataFrame(austen_list, columns=['text'])
austen_df['author'] = 'Austen'
austen_df.head()
# Out:
#                                                 text  author
# 0                                     By Jane Austen  Austen
# 1                                          Chapter 1  Austen
# 2  It is a truth universally acknowledged, that a...  Austen
# 3      of a good fortune, must be in want of a wife.  Austen
# 4  However little known the feelings or views of ...  Austen

# %%
# get and set up poe
res = requests.get(poe_url)
assert str(res) == '<Response [200]>'
poe = res.content.decode("utf-8-sig")

# %%
# clean poe
poe = poe[poe.find('The Purloined Letter'):poe.find('End of Project Gutenberg')]
poe_list = poe.replace('\r', '').split('\n')
poe_list = [each for each in poe_list if each != '']
poe_df = pd.DataFrame(poe_list, columns=['text'])
poe_df['author'] = 'Poe'
poe_df.head()
# Out:
#                                                 text author
# 0                               The Purloined Letter    Poe
# 1       The Thousand-and-Second Tale of Scheherazade    Poe
# 2                       A Descent into the Maelström    Poe
# 3                     Von Kempelen and his Discovery    Poe
# 4                                Mesmeric Revelation    Poe

# %%
# merge
df = pd.concat([austen_df, poe_df], axis=0)

# %%
df
# Out:
#                                                    text  author
# 0                                        By Jane Austen  Austen
# 1                                             Chapter 1  Austen
# 2     It is a truth universally acknowledged, that a...  Austen
# 3         of a good fortune, must be in want of a wife.  Austen
# 4     However little known the feelings or views of ...  Austen
# 5     first entering a neighbourhood, this truth is ...  Austen
# 6     of the surrounding families, that he is consid...  Austen
# 7              of some one or other of their daughters.  Austen
# 8     “My dear Mr. Bennet,” said his lady to him one...  Austen
# 9                     Netherfield Park is let at last?”  Austen
# 10                  Mr. Bennet replied that he had not.  Austen
# 11    “But it is,” returned she; “for Mrs. Long has ...  Austen
# 12                               told me all about it.”  Austen
# 13                           Mr. Bennet made no answer.  Austen
# 14    “Do you not want to know who has taken it?” cr...  Austen
# 15    “_You_ want to tell me, and I have no objectio...  Austen
# 16                          This was invitation enough.  Austen
# 17    “Why, my dear, you must know, Mrs. Long says t...  Austen
# 18    by a young man of large fortune from the north...  Austen
# 19    down on Monday in a chaise and four to see the...  Austen
# 20    delighted with it, that he agreed with Mr. Mor...  Austen
# 21    is to take possession before Michaelmas, and s...  Austen
# 22            be in the house by the end of next week.”  Austen
# 23                                  “What is his name?”  Austen
# 24                                           “Bingley.”  Austen
# 25                           “Is he married or single?”  Austen
# 26    “Oh! Single, my dear, to be sure! A single man...  Austen
# 27    five thousand a year. What a fine thing for ou...  Austen
# 28                    “How so? How can it affect them?”  Austen
# 29    “My dear Mr. Bennet,” replied his wife, “how c...  Austen
# ...                                                 ...     ...
# 8356  be a moderate estimate. Thus, if they had been...     Poe
# 8357  years ago, we might still see them to-day by t...     Poe
# 8358  from their surfaces 20 or 1000 years in the pa...     Poe
# 8359  we see daily are really extinct, is not imposs...     Poe
# 8360                                   Notes--Maelstrom     Poe
# 8361  (*1) See Archimedes, “_De Incidentibus in Flui...     Poe
# 8362                           Notes--Island of the Fay     Poe
# 8363  (*1) Moraux is here derived from moeurs, and i...     Poe
# 8364       “fashionable” or more strictly “of manners.”     Poe
# 8365  (*2) Speaking of the tides, Pomponius Mela, in...     Poe
# 8366  Orbis,” says “either the world is a great anim...     Poe
# 8367  (*3) Balzac--in substance--I do not remember t...     Poe
# 8368  (*4) Florem putares nare per liquidum aethera....     Poe
# 8369                         Notes -- Domain of Arnheim     Poe
# 8370  (*1) An incident, similar in outline to the on...     Poe
# 8371  not very long ago, in England. The name of the...     Poe
# 8372  Thelluson. I first saw an account of this matt...     Poe
# 8373  Puckler Muskau, who makes the sum inherited _n...     Poe
# 8374  and justly observes that “in the contemplation...     Poe
# 8375  the services to which it might be applied, the...     Poe
# 8376  the sublime.” To suit the views of this articl...     Poe
# 8377  Prince’s statement, although a grossly exagger...     Poe
# 8378  in fact, the commencement of the present paper...     Poe
# 8379  ago--previous to the issue of the first number...     Poe
# 8380  Errant_, which may possibly have been suggeste...     Poe
# 8381                                           account.     Poe
# 8382                                    Notes--Berenice     Poe
# 8383  (*1) For as Jove, during the winter season, gi...     Poe
# 8384  warmth, men have called this element and tempe...     Poe
# 8385                     beautiful Halcyon--_Simonides_     Poe
#
# [19106 rows x 2 columns]

# %%
# use .find() to set up indices for the string
austen.find('By Jane Austen')
# Out:
# 0

# %%
austen.find('End of the Project Gutenberg EBook of Pride and Prejudice')
# Out:
# -1

# %%
X = df['text']
y = df['author']

X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
pipe = Pipeline([
    ('cv', CountVectorizer()),
    ('lr', LogisticRegression())
])

pipe.fit(X_train, y_train)
pipe.score(X_train, y_train)
# Out:
# 0.9651755181799149

# %%
pipe.score(X_test, y_test)
# Out:
# 0.8932384341637011

# %%
test_report = pd.DataFrame({'sent': X_test, 'actual': y_test, 'preds': pipe.predict(X_test)})

# %%
test_report.head()
# Out:
#       actual   preds                                               sent
# 1103  Austen  Austen             “Oh! yes--I understand you perfectly.”
# 4368  Austen  Austen  quest of this wonder; It was two ladies stoppi...
# 4056  Austen  Austen  She wrote again when the visit was paid, and s...
# 4414  Austen  Austen  they were to expect, that the sight of such ro...
# 6109  Austen  Austen  scheme, of which Lydia had given them a hint a...

# %%
pipe.predict_proba(X_test)
# Out:
# array([[6.90782880e-01, 3.09217120e-01],
#        [5.64030668e-01, 4.35969332e-01],
#        [9.99977825e-01, 2.21753537e-05],
#        ...,
#        [6.33776841e-01, 3.66223159e-01],
#        [8.60081047e-01, 1.39918953e-01],
#        [9.98916520e-01, 1.08348019e-03]])

# %%
test_report[test_report['actual'] != test_report['preds']]
# Out:
#       actual   preds                                               sent
# 7588  Austen     Poe  a first interview with its object, and even be...
# 7194  Austen     Poe  hastily rejected. Neither had anything occurre...
# 3741  Austen     Poe  yourself or me, that selfishness is prudence, ...
# 1976     Poe  Austen  at present is a very different one indeed. I a...
#
# [510 rows x 3 columns]

# %%
pipe = Pipeline([
    ('tf', TfidfVectorizer()),
    ('lr', LogisticRegression())
])

pipe.fit(X_train, y_train)
pipe.score(X_train, y_train)
# Out:
# 0.9278386488938516

# %%
pipe.score(X_test, y_test)
# Out:
# 0.8903077245132929

# %%
coefs = pipe.named_steps['tf'].get_feature_names()
values = pipe.named_steps['lr'].coef_[0]

# %%
pd.DataFrame({'coefs': coefs, 'values': values}).sort_values('values').head(20)
# Out:
#            coefs    values
# 9262         she -8.077755
# 5065         her -7.226897
# 3533   elizabeth -6.809754
# 6801          mr -4.773352
# 2671       darcy -4.642335
# 11547       your -4.482881
# 11542        you -4.447601
# 5853        jane -4.276804
# 10326     though -4.169499
# 6802         mrs -4.135591
# 1809     chapter -3.908777
# 1326     bingley -3.874131
# 5086     herself -3.618019
# 11367    wickham -3.536094
# 1275      bennet -3.433758
# 6325       lydia -3.385621
# 7160          on -3.380743
# 11543      young -3.267154
# 6661        miss -3.256056
# 10300       they -3.168534

# %%
pd.DataFrame({'coefs': coefs, 'values': values}).sort_values('values', ascending=False).head(20)
# Out:
#             coefs    values
# 10931        upon  4.708163
# 10272         the  4.440622
# 10371        thus  3.033704
# 5844          its  2.704613
# 651      although  2.502863
# 652    altogether  2.340826
# 2710        death  2.284301
# 3399        dupin  2.261263
# 10976    valdemar  2.063224
# 10897       until  2.033268
# 210            _p  2.022587
# 277            _v  2.016893
# 1344        black  1.991699
# 6842           my  1.944096
# 11395      wilson  1.881029
# 4160         feet  1.864743
# 4164         fell  1.837329
# 11205        wall  1.819260
# 7149          old  1.779161
# 10299       these  1.754927

# %%
ps = PorterStemmer()

# %%
ps.stem('cats')
# Out:
# 'cat'

# %%
def to_words(raw_text):
    
    letters_only = re.sub("[^a-zA-Z]", " ", raw_text)
    
    words = letters_only.lower().split()
    
    stops = set(stopwords.words('english'))
    
    meaningful_words = [w for w in words if not w in stops]
    
    stemmed_words = [ps.stem(w) for w in words if not w in stops]
    #
    # 6. Join the words back into one string separated by space, 
    # and return the result.
    return(" ".join(stemmed_words))

# %%
pipe = Pipeline([
    ('cv', CountVectorizer(preprocessor=to_words)),
    ('nb', MultinomialNB())
])

# %%
pipe.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('cv', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1),
#         preprocessor=<function to_words at 0x11642d9d8>, stop_words=None,
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)), ('nb', MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True))])

# %%
pipe.score(X_train, y_train)
# Out:
# 0.9265824551608626

# %%
pipe.score(X_test, y_test)
# Out:
# 0.8890517060916894

# %%
pipe = Pipeline([
    ('cv', CountVectorizer(preprocessor=to_words)),
    ('nb', MultinomialNB())
])

params = {
    'cv__preprocessor': [None, to_words]
}

gs = GridSearchCV(pipe, params)
gs.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=None, error_score='raise',
#        estimator=Pipeline(memory=None,
#      steps=[('cv', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1),
#         prepro...enizer=None, vocabulary=None)), ('nb', MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True))]),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'cv__preprocessor': [None, <function to_words at 0x11642d9d8>]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
gs.best_score_
# Out:
# 0.8870821411124293

# %%
gs.score(X_test, y_test)
# Out:
# 0.9041239271509316

# %%
gs.best_estimator_
# Out:
# Pipeline(memory=None,
#      steps=[('cv', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)), ('nb', MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True))])
